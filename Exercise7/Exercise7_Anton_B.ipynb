# %% [markdown]
# # Sequence labeling (POS tagging) with MLP
#
# This notebook builds upon the [classification with MLP notebook](https://github.com/TurkuNLP/intro-to-nlp/blob/master/mlp_imdb_hf_dset_and_trainer.ipynb) and shows how to implement a basic sequence labeling method.

# %% [markdown]
# ---
#
# # Setup
#
# Install the required Python packages using [pip](https://en.wikipedia.org/wiki/Pip):
#
# * [`transformers`](https://huggingface.co/docs/transformers/index) is a popular deep learning package primarily on top of torch
# * [`datasets`](https://huggingface.co/docs/datasets/) provides support for loading, creating, and manipulating datasets
# * [`evaluate`](https://huggingface.co/docs/evaluate/index) is a library of performance metrics (like accuracy etc)

# %%
# !pip3 install --upgrade transformers[torch]
# !pip3 install -q evaluate
# Out:
# Requirement already satisfied: transformers[torch] in /home/asteer/data/lib/python3.12/site-packages (5.5.4)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /home/asteer/data/lib/python3.12/site-packages (from transformers[torch]) (1.7.2)
# Requirement already satisfied: numpy>=1.17 in /home/asteer/data/lib/python3.12/site-packages (from transformers[torch]) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /home/asteer/data/lib/python3.12/site-packages (from transformers[torch]) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/asteer/data/lib/python3.12/site-packages (from transformers[torch]) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /home/asteer/data/lib/python3.12/site-packages (from transformers[torch]) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/asteer/data/lib/python3.12/site-packages (from transformers[torch]) (0.22.2)
# Requirement already satisfied: typer in /home/asteer/data/lib/python3.12/site-packages (from transformers[torch]) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/asteer/data/lib/python3.12/site-packages (from transformers[torch]) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /home/asteer/data/lib/python3.12/site-packages (from transformers[torch]) (4.67.3)
# Requirement already satisfied: torch>=2.4 in /home/asteer/data/lib/python3.12/site-packages (from transformers[torch]) (2.11.0)
# Requirement already satisfied: accelerate>=1.1.0 in /home/asteer/data/lib/python3.12/site-packages (from transformers[torch]) (1.13.0)
# Requirement already satisfied: filelock>=3.10.0 in /home/asteer/data/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/asteer/data/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /home/asteer/data/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/asteer/data/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/asteer/data/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (4.15.0)
# Requirement already satisfied: anyio in /home/asteer/data/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (4.12.1)
# Requirement already satisfied: certifi in /home/asteer/data/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/asteer/data/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.0.9)
# Requirement already satisfied: idna in /home/asteer/data/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/asteer/data/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.16.0)
# Requirement already satisfied: psutil in /home/asteer/data/lib/python3.12/site-packages (from accelerate>=1.1.0->transformers[torch]) (7.2.2)
# Requirement already satisfied: setuptools<82 in /home/asteer/data/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/asteer/data/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/asteer/data/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (3.6.1)
# Requirement already satisfied: jinja2 in /home/asteer/data/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (3.1.6)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/asteer/data/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.4->transformers[torch]) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/asteer/data/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /home/asteer/data/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /home/asteer/data/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /home/asteer/data/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/asteer/data/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /home/asteer/data/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /home/asteer/data/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.4->transformers[torch]) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/asteer/data/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.4->transformers[torch]) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/asteer/data/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.4->transformers[torch]) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/asteer/data/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.4->transformers[torch]) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/asteer/data/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.4->transformers[torch]) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/asteer/data/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.4->transformers[torch]) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/asteer/data/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.4->transformers[torch]) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/asteer/data/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.4->transformers[torch]) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/asteer/data/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.4->transformers[torch]) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/asteer/data/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.4->transformers[torch]) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/asteer/data/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.4->transformers[torch]) (13.0.85)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/asteer/data/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch>=2.4->transformers[torch]) (1.5.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/asteer/data/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.4->transformers[torch]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/asteer/data/lib/python3.12/site-packages (from jinja2->torch>=2.4->transformers[torch]) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /home/asteer/data/lib/python3.12/site-packages (from typer->transformers[torch]) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/asteer/data/lib/python3.12/site-packages (from typer->transformers[torch]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /home/asteer/data/lib/python3.12/site-packages (from typer->transformers[torch]) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/asteer/data/lib/python3.12/site-packages (from typer->transformers[torch]) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/asteer/data/lib/python3.12/site-packages (from rich>=12.3.0->typer->transformers[torch]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/asteer/data/lib/python3.12/site-packages (from rich>=12.3.0->typer->transformers[torch]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/asteer/data/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers[torch]) (0.1.2)

# %%
import datasets
import evaluate
import transformers

# %% [markdown]
# ---
#
# # Get and prepare data
#
# *   Let us work with the venerable, if somewhat dated [CoNLL'03 shared task](https://aclanthology.org/W03-0419.pdf) English data
# *   These are English news articles, and have annotation for POS, syntactic chunks, and named entities (in the IOB format)
#
# The data as originally distributed for the 2003 shared task has the following format:
#
# ```
# Only RB B-NP O
# France NNP I-NP B-LOC
# and CC I-NP O
# Britain NNP I-NP B-LOC
# backed VBD B-VP O
# Fischler NNP B-NP B-PER
# 's POS I-NP O
# proposal NN I-NP O
# . . O O
# ```
#
# Here, the four space-separated columns are token text, POS tag, chunk tag, and NER tag. The goal of the original task is to predict the NER tags using the other information as features, but the dataset can be used to study predicting the other columns too.
#
# The dataset happens to be in the HF datasets collection, so we can grab it from there

# %%
import torch
import transformers
import datasets

from pprint import pprint    # pretty-print

dataset = datasets.load_dataset("dany0407/conll2003")

print(dataset)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 14041
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3250
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3453
#     })
# })

# %%
pprint(dataset["train"][12])
# Out:
# {'chunk_tags': [11, 12, 12, 12, 21, 11, 11, 12, 0],
#  'id': '12',
#  'ner_tags': [0, 5, 0, 5, 0, 1, 0, 0, 0],
#  'pos_tags': [30, 22, 10, 22, 38, 22, 27, 21, 7],
#  'tokens': ['Only',
#             'France',
#             'and',
#             'Britain',
#             'backed',
#             'Fischler',
#             "'s",
#             'proposal',
#             '.']}

# %% [markdown]
# As you can see above, the various labels (POS, NER and chunk tags) are converted into IDs in this dataset. We can access the textual labels of these tags through the dataset `features`:

# %%
POS_TAG_NAMES = dataset['train'].features['pos_tags'].feature.names
NER_TAG_NAMES = dataset['train'].features['ner_tags'].feature.names
CHUNK_TAG_NAMES = dataset['train'].features['chunk_tags'].feature.names

# %% [markdown]
# We can then create mappings from names to IDs and back as Python dictionaries:

# %%
POS2ID = { n: i for i, n in enumerate(POS_TAG_NAMES) }
ID2POS = { i: n for i, n in enumerate(POS_TAG_NAMES) }

NER2ID = { n: i for i, n in enumerate(NER_TAG_NAMES) }
ID2NER = { i: n for i, n in enumerate(NER_TAG_NAMES) }

CHUNK2ID = { n: i for i, n in enumerate(CHUNK_TAG_NAMES) }
ID2CHUNK = { i: n for i, n in enumerate(CHUNK_TAG_NAMES) }

# %% [markdown]
# This is what these mappings look like:

# %%
print(NER2ID)
# Out:
# {'O': 0, 'B-PER': 1, 'I-PER': 2, 'B-ORG': 3, 'I-ORG': 4, 'B-LOC': 5, 'I-LOC': 6, 'B-MISC': 7, 'I-MISC': 8}

# %%
print(ID2NER)
# Out:
# {0: 'O', 1: 'B-PER', 2: 'I-PER', 3: 'B-ORG', 4: 'I-ORG', 5: 'B-LOC', 6: 'I-LOC', 7: 'B-MISC', 8: 'I-MISC'}

# %% [markdown]
# Let's also add in explanations from Penn Treebank for the POS tags:

# %%
# From the documentation page and from here https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

POS2DESCRIPTION = {
    "CC": "Coordinating conjunction",
    "CD": "Cardinal number",
    "DT": "Determiner",
    "EX": "Existential there",
    "FW": "Foreign word",
    "IN": "Preposition or subordinating conjunction",
    "JJ": "Adjective",
    "JJR": "Adjective, comparative",
    "JJS": "Adjective, superlative",
    "LS": "List item marker",
    "MD": "Modal",
    "NN": "Noun, singular or mass",
    "NNS": "Noun, plural",
    "NNP": "Proper noun, singular",
    "NNPS": "Proper noun, plural",
    "PDT": "Predeterminer",
    "POS": "Possessive ending",
    "PRP": "Personal pronoun",
    "PRP$": "Possessive pronoun",
    "RB": "Adverb",
    "RBR": "Adverb, comparative",
    "RBS": "Adverb, superlative",
    "RP": "Particle",
    "SYM": "Symbol",
    "TO": "to",
    "UH": "Interjection",
    "VB": "Verb, base form",
    "VBD": "Verb, past tense",
    "VBG": "Verb, gerund or present participle",
    "VBN": "Verb, past participle",
    "VBP": "Verb, non-3rd person singular present",
    "VBZ": "Verb, 3rd person singular present",
    "WDT": "Wh-determiner",
    "WP": "Wh-pronoun",
    "WP$": "Possessive wh-pronoun",
    "WRB": "Wh-adverb"
}

# %% [markdown]
# We can now try to make sense of the tags:

# %%
import tabulate

e = dataset["train"][12]    # work on the same example

table = []
for token, pos_id, chunk_id, ner_id in zip(e["tokens"], e["pos_tags"], e["chunk_tags"], e["ner_tags"]):
    ner_tag = ID2NER[ner_id]
    chunk_tag = ID2CHUNK[chunk_id]
    pos_tag = ID2POS[pos_id]
    pos_def = POS2DESCRIPTION.get(pos_tag,pos_tag)
    table.append([token, ner_tag, chunk_tag, pos_tag, pos_def])

print(tabulate.tabulate(table,headers=["Token", "NER", "Chunk", "POS", "POS definition"]))
# Out:
# Token     NER    Chunk    POS    POS definition
# --------  -----  -------  -----  ------------------------
# Only      O      B-NP     RB     Adverb
# France    B-LOC  I-NP     NNP    Proper noun, singular
# and       O      I-NP     CC     Coordinating conjunction
# Britain   B-LOC  I-NP     NNP    Proper noun, singular
# backed    O      B-VP     VBD    Verb, past tense
# Fischler  B-PER  B-NP     NNP    Proper noun, singular
# 's        O      B-NP     POS    Possessive ending
# proposal  O      I-NP     NN     Noun, singular or mass
# .         O      O        .      .

# %% [markdown]
# Note that the data is organized into sentences.

# %% [markdown]
# ---
#
# # Create features
#
# We'll define a simple function that takes a token sequence, the index of the focus token, and a window size and generates a few basic explicit features relevant to the task.
#
# (Note that as we'll be predicting the POS tag, we won't look at the chunk or NER tags, which would typically only be predicted _after_ predicting POS in a "traditional" NLP pipeline)

# %%
def token_features(tokens, index, window_size):
    # Generate features for token in position `index` in given list of tokens
    features = []

    # Context window start and end
    window_start = max(0, index-window_size)
    window_end = min(index+window_size+1, len(tokens))    # note +1 for range

    for i in range(window_start, window_end):
        offset = i - index    # relative position 
        features.append(f"token[{offset}]={tokens[i]}")

        #if offset != 0:

        #features.append(f"token[{index}]={tokens[index]}")f
        #break      

    # Example custom feature: does focus token start with an upper-case letter?
    if tokens[index][0].isupper():
        features.append("first-letter-capitalized")

    return features

# %% [markdown]
# PART A
#
# Added line to check if the feature is the focus word. If it is then it is not passed to the feature. This means that all of the features are purely context dependent.
#
# Modified the feature generation to only pass the original word as a feature. This means that the POS tagger is only memorizing the words.

# %% [markdown]
# We can call this function for all tokens in a sentence like so:

# %%
def add_features_to_sentence(sentence):
    # Collect lists of features for all tokens here
    all_features = []

    tokens = sentence["tokens"]
    for index in range(len(tokens)):
        all_features.append(" ".join(token_features(tokens, index, window_size=3)))

    return { "features": all_features}

# %%
for feats in add_features_to_sentence(dataset["train"][12])["features"]:
    print(feats)
# Out:
# token[0]=Only token[1]=France token[2]=and token[3]=Britain first-letter-capitalized
# token[-1]=Only token[0]=France token[1]=and token[2]=Britain token[3]=backed first-letter-capitalized
# token[-2]=Only token[-1]=France token[0]=and token[1]=Britain token[2]=backed token[3]=Fischler
# token[-3]=Only token[-2]=France token[-1]=and token[0]=Britain token[1]=backed token[2]=Fischler token[3]='s first-letter-capitalized
# token[-3]=France token[-2]=and token[-1]=Britain token[0]=backed token[1]=Fischler token[2]='s token[3]=proposal
# token[-3]=and token[-2]=Britain token[-1]=backed token[0]=Fischler token[1]='s token[2]=proposal token[3]=. first-letter-capitalized
# token[-3]=Britain token[-2]=backed token[-1]=Fischler token[0]='s token[1]=proposal token[2]=.
# token[-3]=backed token[-2]=Fischler token[-1]='s token[0]=proposal token[1]=.
# token[-3]=Fischler token[-2]='s token[-1]=proposal token[0]=.

# %% [markdown]
# The dataset is organized into sentences, so we can use the above function to add features to the entire dataset as follows.
#
# **Note**: unlike e.g. the Python`map` function, [`Dataset.map`](https://huggingface.co/docs/datasets/package_reference/main_classes.html#datasets.Dataset.map) function _updates_ its argument dataset, keeping existing values.

# %%
dataset = dataset.map(add_features_to_sentence)
# Out:
# Map:   0%|          | 0/14041 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3250 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3453 [00:00<?, ? examples/s]

# %% [markdown]
# Let's check that one more time:

# %%
pprint(dataset["train"][12])
# Out:
# {'chunk_tags': [11, 12, 12, 12, 21, 11, 11, 12, 0],
#  'features': ['token[0]=Only token[1]=France token[2]=and token[3]=Britain '
#               'first-letter-capitalized',
#               'token[-1]=Only token[0]=France token[1]=and token[2]=Britain '
#               'token[3]=backed first-letter-capitalized',
#               'token[-2]=Only token[-1]=France token[0]=and token[1]=Britain '
#               'token[2]=backed token[3]=Fischler',
#               'token[-3]=Only token[-2]=France token[-1]=and token[0]=Britain '
#               "token[1]=backed token[2]=Fischler token[3]='s "
#               'first-letter-capitalized',
#               'token[-3]=France token[-2]=and token[-1]=Britain '
#               "token[0]=backed token[1]=Fischler token[2]='s token[3]=proposal",
#               'token[-3]=and token[-2]=Britain token[-1]=backed '
#               "token[0]=Fischler token[1]='s token[2]=proposal token[3]=. "
#               'first-letter-capitalized',
#               'token[-3]=Britain token[-2]=backed token[-1]=Fischler '
#               "token[0]='s token[1]=proposal token[2]=.",
#               "token[-3]=backed token[-2]=Fischler token[-1]='s "
#               'token[0]=proposal token[1]=.',
#               "token[-3]=Fischler token[-2]='s token[-1]=proposal token[0]=."],
#  'id': '12',
#  'ner_tags': [0, 5, 0, 5, 0, 1, 0, 0, 0],
#  'pos_tags': [30, 22, 10, 22, 38, 22, 27, 21, 7],
#  'tokens': ['Only',
#             'France',
#             'and',
#             'Britain',
#             'backed',
#             'Fischler',
#             "'s",
#             'proposal',
#             '.']}

# %% [markdown]
# ---
#
# # Flatten dataset
#
# The MLP code that we introduced previously expects each of the `train`, `validation` and `test` subsets of the data to consist of simple sequences of examples.
#
# Now that we have run the feature generation, we no longer need the sentence structure and can "flatten" the data, i.e. remove the "sentence" level of granularity.

# %%
def flatten(subset):
    # Keys for values to flatten
    keys = ["tokens", "pos_tags", "chunk_tags", "ner_tags", "features"]

    # Initialize to empty lists of tokens etc.
    flattened = { k: [] for k in keys }

    # Concatenate per-sentence lists of tokens etc.
    for sentence in subset:
        for key in keys:
            flattened[key].extend(sentence[key])

    # Return as Dataset object
    return datasets.Dataset.from_dict(flattened)

# %% [markdown]
# Call `flatten` for each of the subsets and make a new `DatasetDict` containing the flattened subsets:

# %%
flattened_dict = {
    "train": flatten(dataset["train"]),
    "validation": flatten(dataset["validation"]),
    "test": flatten(dataset["test"]),
}

flat_dataset = datasets.DatasetDict(flattened_dict)

# %% [markdown]
# Check that the new dataset looks OK:

# %%
flat_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'pos_tags', 'chunk_tags', 'ner_tags', 'features'],
#         num_rows: 203621
#     })
#     validation: Dataset({
#         features: ['tokens', 'pos_tags', 'chunk_tags', 'ner_tags', 'features'],
#         num_rows: 51362
#     })
#     test: Dataset({
#         features: ['tokens', 'pos_tags', 'chunk_tags', 'ner_tags', 'features'],
#         num_rows: 46435
#     })
# })

# %%
for i in range(10):
    token = flat_dataset["train"]["tokens"][i]
    pos_tag = ID2POS[flat_dataset["train"]["pos_tags"][i]]
    description = POS2DESCRIPTION.get(pos_tag, pos_tag)
    features = flat_dataset["train"]["features"][i]
    print(f"{token}\t{pos_tag}\t{description}\t{features}")
# Out:
# EU	NNP	Proper noun, singular	token[0]=EU token[1]=rejects token[2]=German token[3]=call first-letter-capitalized
# rejects	VBZ	Verb, 3rd person singular present	token[-1]=EU token[0]=rejects token[1]=German token[2]=call token[3]=to
# German	JJ	Adjective	token[-2]=EU token[-1]=rejects token[0]=German token[1]=call token[2]=to token[3]=boycott first-letter-capitalized
# call	NN	Noun, singular or mass	token[-3]=EU token[-2]=rejects token[-1]=German token[0]=call token[1]=to token[2]=boycott token[3]=British
# to	TO	to	token[-3]=rejects token[-2]=German token[-1]=call token[0]=to token[1]=boycott token[2]=British token[3]=lamb
# boycott	VB	Verb, base form	token[-3]=German token[-2]=call token[-1]=to token[0]=boycott token[1]=British token[2]=lamb token[3]=.
# British	JJ	Adjective	token[-3]=call token[-2]=to token[-1]=boycott token[0]=British token[1]=lamb token[2]=. first-letter-capitalized
# lamb	NN	Noun, singular or mass	token[-3]=to token[-2]=boycott token[-1]=British token[0]=lamb token[1]=.
# .	.	.	token[-3]=boycott token[-2]=British token[-1]=lamb token[0]=.
# Peter	NNP	Proper noun, singular	token[0]=Peter token[1]=Blackburn first-letter-capitalized

# %% [markdown]
# Note that this is now a single long dataset of tokens without sentence boundaries.

# %% [markdown]
# # Tokenization
#
# Tokenization needs a bit of thinking, so that we can keep things as simple as possible. We need to turn the strings of features into tokens so that we can then plug them into our MLP.
#
# This would be perfectly doable with the standard tokenizer if only we could convince it to simply tokenize on whitespace and leave everything else untouched.
#
# We cannot use the approach from the MLP lecture, because the pretrained tokenizers tend to modify the data in various ways. We need more control, i.e. we need to make our own tokenizer. Luckily, this is easier than it sounds.

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordLevel
from tokenizers.trainers import WordLevelTrainer
from tokenizers.pre_tokenizers import WhitespaceSplit
from transformers import PreTrainedTokenizerFast

def build_whitespace_tokenizer(dataset, vocab_size=None, min_frequency=2):
    tokenizer = Tokenizer(WordLevel(unk_token="[UNK]"))

    # Use pure whitespace splitting, no normalization or subwording
    tokenizer.normalizer = None #This is a step which happens before tokenization, we want nothing done. So setting to None.
    tokenizer.pre_tokenizer = WhitespaceSplit() #This is a pre-tokenization step, we want to strictly only use whitespace.

    # List [PAD] first, so it gets index 0
    special_tokens = ["[PAD]","[UNK]"]

    # WordLevelTrainer builds a word-level tokenizer, i.e. no subwords are used, no BPE algorithm, simply full words
    # Words that do not fit into the vocabulary will be replaced by [UNK], which is fine for our purposes
    trainer = WordLevelTrainer(
        vocab_size=vocab_size,
        min_frequency=min_frequency, #only consider tokens which appear this many times
        special_tokens=special_tokens,
    )
    # This is where the actual training happens
    iterator = (example["features"] for example in dataset)
    tokenizer.train_from_iterator(iterator, trainer=trainer)
    print(tokenizer)

    # And this then turns the tokenizer into something we can use
    hf_tokenizer = PreTrainedTokenizerFast(
        tokenizer_object=tokenizer,

        unk_token="[UNK]",
        pad_token="[PAD]",
    )

    return hf_tokenizer
tokenizer = build_whitespace_tokenizer(flat_dataset["train"], vocab_size=15000)
# Out:
# Tokenizer(version="1.0", truncation=None, padding=None, added_tokens=[{"id":0, "content":"[PAD]", "single_word":False, "lstrip":False, "rstrip":False, ...}, {"id":1, "content":"[UNK]", "single_word":False, "lstrip":False, "rstrip":False, ...}], normalizer=None, pre_tokenizer=WhitespaceSplit(), post_processor=None, decoder=None, model=WordLevel(vocab={"[PAD]":0, "[UNK]":1, "first-letter-capitalized":2, "token[0]=.":3, "token[1]=.":4, ...}, unk_token="[UNK]"))

# %%
tokenizer.vocab
# Out:
# {'token[2]=sent': 4117,
#  'token[-3]=de': 3217,
#  'token[1]=during': 1489,
#  'token[-2]=still': 1390,
#  'token[2]=freed': 13777,
#  'token[-3]=Thursday': 584,
#  'token[0]=Khan': 5556,
#  'token[1]=14': 1121,
#  'token[-1]=What': 11976,
#  'token[-3]=Seles': 13233,
#  'token[-3]=sent': 3934,
#  'token[-3]=invited': 9898,
#  'token[-3]=know': 5537,
#  'token[1]=blamed': 8890,
#  'token[0]=computer': 12428,
#  'token[0]=69': 1274,
#  'token[-3]=father': 13277,
#  'token[-1]=difficult': 8550,
#  'token[-2]=based': 5744,
#  'token[1]=things': 9485,
#  'token[-1]=island': 5717,
#  'token[-1]=With': 8531,
#  'token[0]=Romania': 4350,
#  'token[2]=interests': 13788,
#  'token[-1]=never': 6252,
#  'token[-3]=general': 3395,
#  'token[-2]=finally': 11268,
#  'token[2]=airports': 13746,
#  'token[-2]=bourse': 13105,
#  'token[0]=Glamorgan': 14687,
#  'token[1]=delivery': 11625,
#  'token[2]=eighth': 10148,
#  'token[1]=accident': 11606,
#  'token[-3]=levels': 7343,
#  'token[2]=LEAGUE': 3247,
#  'token[-3]=majority': 9902,
#  'token[-3]=57': 13192,
#  'token[-1]=We': 743,
#  'token[2]=dealers': 7135,
#  'token[0]=caused': 9374,
#  'token[-2]=debut': 13119,
#  'token[1]=board': 8337,
#  'token[-3]=Canadian': 12223,
#  'token[-2]=important': 6626,
#  'token[-3]=stop': 8743,
#  'token[2]=deficit': 7501,
#  'token[0]=majority': 9390,
#  'token[-1]=polls': 8570,
#  'token[-2]=town': 2238,
#  'token[0]=Hospital': 11458,
#  'token[1]=human': 5027,
#  'token[-2]=seed': 4598,
#  'token[1]=just': 1035,
#  'token[-2]=poll': 7305,
#  'token[-1]=passengers': 4732,
#  'token[1]=most': 1769,
#  'token[0]=Daniel': 10652,
#  'token[3]=Group': 13873,
#  'token[-3]=winning': 3670,
#  'token[-1]=OPEN': 5463,
#  'token[-1]=Police': 3268,
#  'token[-2]=minority': 14388,
#  'token[1]=Mark': 3157,
#  'token[0]=held': 1485,
#  'token[-1]=NEW': 1041,
#  'token[-1]=Arabia': 11083,
#  'token[-3]=best': 4188,
#  'token[-1]=charge': 7612,
#  'token[-1]=Mike': 10319,
#  'token[2]=half': 1442,
#  'token[3]=drew': 10238,
#  'token[-2]=few': 3289,
#  'token[-1]=212': 14002,
#  'token[3]=House': 6179,
#  'token[3]=close': 2271,
#  'token[-1]=Greek': 11937,
#  'token[3]=really': 9047,
#  'token[0]=rugby': 10019,
#  'token[0]=prison': 5167,
#  'token[-1]=home': 993,
#  'token[1]=42': 6097,
#  'token[2]=know': 6159,
#  'token[-3]=business': 4459,
#  'token[2]=down': 907,
#  'token[-3]=Sri': 3130,
#  'token[-2]=least': 4041,
#  'token[1]=Sittard': 14936,
#  'token[-2]=say': 2237,
#  'token[1]=free': 4228,
#  'token[-2]=doctors': 13125,
#  'token[-3]=currently': 9884,
#  'token[2]=paid': 8421,
#  'token[3]=A': 5423,
#  'token[0]=play': 1929,
#  'token[3]=senior': 6533,
#  'token[2]=losing': 8979,
#  'token[-1]=through': 1046,
#  'token[-1]=3.': 1195,
#  'token[-3]=owned': 10603,
#  'token[0]=based': 5809,
#  'token[2]=speech': 13826,
#  'token[1]=sale': 8370,
#  'token[-1]=because': 923,
#  'token[1]=Vienna': 14940,
#  'token[3]=leaders': 2925,
#  'token[3]=announced': 3435,
#  'token[-3]=six': 1229,
#  'token[-2]=ISS': 7655,
#  'token[0]=win': 1054,
#  'token[3]=finished': 10251,
#  'token[2]=sanctions': 12715,
#  'token[2]=weapons': 7524,
#  'token[-1]=heard': 12966,
#  'token[-2]=most': 1756,
#  'token[1]=member': 7880,
#  'token[-3]=secretary': 8740,
#  'token[-2]=president': 1333,
#  'token[0]=conditions': 5813,
#  'token[-2]=Jason': 11219,
#  'token[3]=Brazilian': 11814,
#  'token[1]=less': 6125,
#  'token[-3]=Government': 12229,
#  'token[1]=Securities': 8874,
#  'token[-2]=Tour': 12114,
#  'token[1]=leadership': 12581,
#  'token[2]=rather': 12711,
#  'token[-1]=final': 1872,
#  'token[-1]=lack': 12974,
#  'token[3]=important': 7178,
#  'token[1]=surgery': 10864,
#  'token[-2]=Benjamin': 14237,
#  'token[0]=later': 2983,
#  'token[0]=case': 3941,
#  'token[-2]=seeking': 10500,
#  'token[-3]=Swiss': 6657,
#  'token[0]=process': 5003,
#  'token[-1]=Rostock': 12906,
#  'token[3]=League': 4870,
#  'token[-1]=Huber': 11941,
#  'token[-3]=published': 9915,
#  'token[2]=prices': 2504,
#  'token[2]=win': 1291,
#  'token[0]=worth': 8311,
#  'token[1]=they': 401,
#  'token[-3]=led': 3782,
#  'token[3]=having': 6836,
#  'token[0]=output': 8830,
#  'token[-2]=community': 9194,
#  'token[1]=according': 6111,
#  'token[2]=if': 1222,
#  'token[3]=title': 5680,
#  'token[2]=always': 7917,
#  'token[1]=199': 14870,
#  'token[1]=major': 3524,
#  'token[1]=riots': 13664,
#  'token[-3]=ends': 14565,
#  'token[-2]=wounded': 9842,
#  'token[-3]=nuclear': 6987,
#  'token[1]=Paul': 2989,
#  'token[-1]=WESTERN': 8528,
#  'token[-3]=pct': 6989,
#  'token[0]=Three': 13413,
#  'token[-2]=PUK': 5978,
#  'token[-3]=PHILADELPHIA': 9866,
#  'token[-1]=turned': 6585,
#  'token[-3]=deficit': 7333,
#  'token[-2]=protest': 8143,
#  'token[-1]=stocks': 6904,
#  'token[-3]=states': 9925,
#  'token[3]=1': 121,
#  'token[0]=January': 7373,
#  'token[1]=filed': 10829,
#  'token[3]=increased': 9034,
#  'token[0]=Vienna': 14741,
#  'token[-2]=Hill': 12085,
#  'token[0]=add': 14748,
#  'token[1]=women': 2846,
#  'token[0]=arms': 7796,
#  'token[-3]=pitch': 14594,
#  'token[-2]=line': 7689,
#  'token[-2]=DIVISION': 3042,
#  'token[0]=de': 2901,
#  'token[-1]=many': 2801,
#  'token[0]=Adrian': 13346,
#  'token[-3]=admitted': 9875,
#  'token[-3]=put': 2302,
#  'token[-2]=charge': 8122,
#  'token[2]=democracy': 11742,
#  'token[-1]=P.': 8028,
#  'token[0]=1997': 3306,
#  'token[-2]=players': 2884,
#  'token[-3]=barrels': 14533,
#  'token[0]=November': 7785,
#  'token[1]=62': 3816,
#  'token[-2]=believe': 8119,
#  'token[1]=export': 10827,
#  'token[-3]=goals': 4463,
#  'token[2]=10,000': 10879,
#  'token[-3]=expected': 1093,
#  'token[3]=members': 5671,
#  'token[2]=51': 7902,
#  'token[3]=main': 4273,
#  'token[3]=International': 8447,
#  'token[2]=unrest': 10976,
#  'token[-2]=ROUND': 12106,
#  'token[1]=holiday': 5186,
#  'token[-1]=Afghan': 10287,
#  'token[-2]=PHILADELPHIA': 9778,
#  'token[-1]=---': 5685,
#  'token[0]=managed': 12459,
#  'token[-1]=Minnesota': 11953,
#  'token[3]=losses': 9617,
#  'token[-1]=policy': 5090,
#  'token[2]=lower': 2209,
#  'token[0]=PSV': 5152,
#  'token[2]=Alan': 12624,
#  'token[-2]=65': 3467,
#  'token[3]=goal': 7556,
#  'token[3]=wanted': 8486,
#  'token[-1]=minutes': 1787,
#  'token[-3]=interest': 4969,
#  'token[-1]=6': 476,
#  'token[2]=Park': 10902,
#  'token[1]=Irani': 13559,
#  'token[0]=Commission': 2755,
#  'token[-3]=able': 5769,
#  'token[-3]=single': 7351,
#  'token[2]=air': 7492,
#  'token[3]=world': 1380,
#  'token[2]=61': 7473,
#  'token[2]=claimed': 13758,
#  'token[-1]=James': 12887,
#  'token[1]=2': 128,
#  'token[2]=brought': 5204,
#  'token[2]=four': 935,
#  'token[3]=along': 10222,
#  'token[0]=who': 281,
#  'token[-1]=ball': 7608,
#  'token[3]=development': 10237,
#  'token[1]=delayed': 10063,
#  'token[1]=Interfax': 11584,
#  'token[-3]=play': 2025,
#  'token[2]=child': 8406,
#  'token[1]=responsible': 11658,
#  'token[1]=stock': 4511,
#  'token[-1]=This': 3192,
#  'token[1]=Democrats': 8860,
#  'token[3]=newspapers': 12818,
#  'token[3]=operating': 13961,
#  'token[3]=6-1': 1941,
#  'token[0]=percent': 405,
#  'token[-3]=profits': 7348,
#  'token[1]=&': 6406,
#  'token[1]=45': 5837,
#  'token[3]=bodies': 13909,
#  'token[2]=and': 59,
#  'token[2]=going': 2623,
#  'token[-1]=single': 6259,
#  'token[-3]=break': 6966,
#  'token[-1]=Colombo': 14022,
#  'token[0]=95': 7005,
#  'token[3]=evidence': 12800,
#  'token[-1]=30': 1517,
#  'token[-3]=van': 8750,
#  'token[3]=African': 4005,
#  'token[-2]=black': 6924,
#  'token[-2]=cuts': 13117,
#  'token[-3]=money': 4193,
#  'token[1]=approved': 10812,
#  'token[-3]=Spanish': 11370,
#  'token[1]=Kong': 2612,
#  'token[2]=0-0': 11678,
#  'token[1]=been': 316,
#  'token[3]=giving': 10253,
#  'token[-1]=Khan': 5695,
#  'token[1]=0-0': 6745,
#  'token[0]=of': 21,
#  'token[-3]=-': 124,
#  'token[-2]=break': 6927,
#  'token[1]=strong': 4378,
#  'token[0]=commander': 9980,
#  'token[0]=tournament': 2412,
#  'token[1]=Benjamin': 14880,
#  'token[1]=Bulgaria': 13539,
#  'token[-2]=picked': 11294,
#  'token[-2]=Peres': 11233,
#  'token[2]=pound': 5409,
#  'token[3]=6.0': 10987,
#  'token[-3]=things': 10622,
#  'token[-2]=concern': 9799,
#  'token[0]=compared': 6379,
#  'token[1]=remained': 7887,
#  'token[-3]=party': 1925,
#  'token[-2]=played': 810,
#  'token[1]=came': 3083,
#  'token[3]=OM': 13884,
#  'token[0]=show': 12477,
#  'token[-3]=farmers': 8199,
#  'token[-1]=Levy': 11949,
#  'token[-3]=St': 3053,
#  'token[2]=means': 13795,
#  'token[-1]=20': 1352,
#  'token[2]=Interfax': 12640,
#  'token[1]=3-6': 7052,
#  'token[0]=captain': 4990,
#  'token[0]=pct': 2311,
#  'token[-1]=show': 12045,
#  'token[-1]=similar': 6258,
#  'token[-2]=26': 5967,
#  'token[-1]=Croatia': 8503,
#  'token[-3]=no': 664,
#  'token[-1]=order': 4161,
#  'token[2]=led': 4521,
#  'token[0]=built': 14762,
#  'token[2]=determine': 13765,
#  'token[-2]=series': 6006,
#  'token[-2]=Net': 5739,
#  'token[2]=address': 11723,
#  'token[0]=special': 9403,
#  'token[-3]=fired': 11387,
#  'token[-2]=supply': 11308,
#  'token[0]=Fox': 12373,
#  'token[-1]=seventh': 9133,
#  'token[1]=Brazilian': 8855,
#  'token[3]=factions': 13929,
#  'token[3]=discuss': 7549,
#  'token[1]=winning': 3837,
#  'token[-1]=Deputy': 14027,
#  'token[0]=..': 14645,
#  'token[-2]=strike': 3915,
#  'token[2]=Greece': 12637,
#  'token[-2]=sector': 7694,
#  'token[-1]=Angeles': 6861,
#  'token[1]=seed': 4510,
#  'token[-2]=front': 12148,
#  'token[-1]=AG': 10286,
#  'token[3]=held': 1679,
#  'token[0]=8': 674,
#  'token[-1]=Gold': 11091,
#  'token[-3]=previous': 4469,
#  'token[-3]=minutes': 2542,
#  'token[-3]=20': 1951,
#  'token[0]=KONG': 8775,
#  'token[3]=charge': 7977,
#  'token[0]=Wayne': 8794,
#  'token[-2]=missing': 11288,
#  'token[-2]=ENGLISH': 7652,
#  'token[-1]=prevent': 12990,
#  'token[-2]=kill': 14379,
#  'token[1]=record': 2616,
#  'token[1]=claimed': 11616,
#  'token[2]=decision': 3538,
#  'token[3]=which': 375,
#  'token[0]=Soviet': 11483,
#  'token[-1]=Attendance': 2576,
#  'token[-1]=December': 7583,
#  'token[-3]=Saturday': 1921,
#  'token[-3]=of': 26,
#  'token[0]=media': 9392,
#  'token[-1]=walked': 9140,
#  'token[1]=thousands': 11666,
#  'token[-2]=towns': 14423,
#  'token[3]=presidential': 10263,
#  'token[-2]=And': 11200,
#  'token[-1]=markets': 4426,
#  'token[-1]=these': 3756,
#  'token[-3]=Banharn': 12220,
#  'token[1]=limited': 11646,
#  'token[-2]=are': 333,
#  'token[0]=1-0': 2973,
#  'token[-3]=67': 2744,
#  'token[-3]=including': 3057,
#  'token[-1]=Jordanian': 12889,
#  'token[-3]=can': 1821,
#  'token[0]=named': 5001,
#  'token[-2]=announced': 3205,
#  'token[1]=brief': 14957,
#  'token[3]=white': 11069,
#  'token[-2]=rebels': 2661,
#  'token[-2]=May': 2586,
#  'token[-1]=denied': 5944,
#  'token[2]=Bob': 12627,
#  'token[0]=coast': 12427,
#  'token[-2]=account': 12121,
#  'token[2]=peace': 1444,
#  'token[0]=Pedro': 12395,
#  'token[-3]=posted': 13301,
#  'token[-2]=Cofinec': 14245,
#  'token[0]=living': 13470,
#  'token[-2]=Bowling': 9755,
#  'token[3]=won': 842,
#  'token[-3]=2-1': 8161,
#  'token[1]=traffic': 8377,
#  'token[-3]=ended': 2671,
#  'token[-2]=talks': 1689,
#  'token[-3]=legal': 8730,
#  'token[-2]=night': 3909,
#  'token[-1]=Bosnian': 4286,
#  'token[0]=38': 8229,
#  'token[-3]=N.': 7319,
#  'token[3]=qualifier': 9628,
#  'token[-3]=73': 3919,
#  'token[-3]=Zealand': 3662,
#  'token[3]=plane': 4709,
#  'token[-2]=Results': 1362,
#  'token[0]=these': 3810,
#  'token[-2]=advertising': 14324,
#  'token[1]=close': 2063,
#  'token[-1]=separatist': 8575,
#  'token[0]=Younis': 5156,
#  'token[-1]=championship': 2728,
#  'token[-3]=plane': 4616,
#  'token[-2]=Daniel': 10425,
#  'token[-2]=too': 6010,
#  'token[2]=previously': 13808,
#  'token[-1]=standings': 4575,
#  'token[3]=aggregate': 6509,
#  'token[-2]=being': 1363,
#  'token[-1]=launched': 10367,
#  'token[2]=4-1': 12618,
#  'token[0]=plans': 3229,
#  'token[2]=fight': 10155,
#  'token[-1]=being': 1331,
#  'token[-3]=We': 745,
#  'token[-1]=1.': 1211,
#  'token[-2]=J.': 8604,
#  'token[0]=five': 946,
#  'token[-2]=Williams': 7671,
#  'token[0]=won': 639,
#  'token[0]=human': 4998,
#  'token[3]=Khartoum': 12755,
#  'token[-1]=Total': 5252,
#  'token[2]=continued': 7133,
#  'token[2]=a': 46,
#  'token[-2]=Monday': 730,
#  'token[0]=Halftime': 5554,
#  'token[2]=Bill': 8940,
#  'token[-3]=between': 778,
#  'token[-1]=the': 10,
#  'token[-3]=community': 9281,
#  'token[2]=different': 10933,
#  'token[0]=Slovakia': 4352,
#  'token[-2]=-': 116,
#  'token[0]=found': 2028,
#  'token[2]=could': 759,
#  'token[-3]=trading': 4199,
#  'token[-2]=Martin': 3283,
#  'token[-3]=seven': 1988,
#  'token[-2]=Mike': 12097,
#  'token[-3]=building': 10578,
#  'token[-1]=b': 1620,
#  'token[0]=dead': 6723,
#  'token[1]=billion': 1279,
#  'token[0]=lap': 9388,
#  'token[0]=African': 2545,
#  'token[0]=Detroit': 12367,
#  'token[-2]=Result': 6275,
#  'token[-1]=necessary': 14179,
#  'token[1]=next': 974,
#  'token[-1]=weaker': 11186,
#  'token[-1]=Dealers': 12871,
#  'token[-3]=Ukraine': 4773,
#  'token[-2]=described': 9802,
#  'token[3]=city': 2510,
#  'token[-1]=metres': 2335,
#  'token[-2]=Park': 9167,
#  'token[-3]=go': 2023,
#  'token[3]=Ahmed': 4123,
#  'token[0]=municipal': 7036,
#  'token[-3]=Melbourne': 11358,
#  'token[-2]=much': 3480,
#  'token[-2]=passenger': 11292,
#  'token[-1]=Results': 1355,
#  'token[0]=Yorkshire': 11490,
#  'token[1]=material': 13642,
#  'token[1]=concern': 8893,
#  'token[2]=father': 13773,
#  'token[-1]=hand': 8056,
#  'token[-2]=higher': 3291,
#  'token[-3]=William': 9268,
#  'token[-2]=released': 4447,
#  'token[-3]=two': 381,
#  'token[-2]=three': 562,
#  'token[3]=mostly': 11044,
#  'token[0]=fourth': 3946,
#  'token[-2]=target': 13175,
#  'token[2]=WORLD': 8398,
#  'token[2]=/': 530,
#  'token[-3]=traded': 8747,
#  'token[3]=snapped': 12838,
#  'token[-3]=cases': 13257,
#  'token[-2]=big': 5983,
#  'token[1]=emergency': 10824,
#  'token[-3]=Union': 3489,
#  'token[2]=director': 6793,
#  'token[1]=race': 2316,
#  'token[-3]=Andrea': 10524,
#  'token[3]=young': 6854,
#  'token[2]=send': 13822,
#  'token[-2]=were': 229,
#  'token[-1]=under': 677,
#  'token[-2]=Rose': 12108,
#  'token[0]=forward': 9386,
#  'token[2]=boat': 13753,
#  'token[1]=worked': 13689,
#  'token[0]=stages': 11551,
#  'token[2]=Yamaha': 12662,
#  'token[3]=left': 2072,
#  'token[-3]=called': 2298,
#  'token[-3]=Europe': 4767,
#  'token[3]=bad': 9019,
#  'token[0]=take': 1486,
#  'token[3]=strike': 4145,
#  'token[3]=free': 4270,
#  'token[0]=wickets': 3955,
#  'token[1]=father': 12568,
#  'token[1]=statement': 1058,
#  'token[3]=can': 2270,
#  'token[-3]=religious': 13308,
#  'token[2]=Chile': 12633,
#  'token[-1]=Oncins': 14072,
#  'token[0]=Colombo': 14670,
#  'token[-3]=Group': 9858,
#  'token[-3]=farm': 8724,
#  'token[1]=proposed': 10094,
#  'token[-1]=Shanghai': 11116,
#  'token[-2]=tonne': 8675,
#  'token[3]=Wimbledon': 6507,
#  'token[-1]=things': 9137,
#  'token[1]=what': 2158,
#  'token[0]=few': 3314,
#  'token[-1]=deputy': 8548,
#  'token[0]=No': 4069,
#  'token[-1]=control': 3746,
#  'token[-1]=WORLD': 8036,
#  'token[-3]=commission': 9280,
#  'token[0]=houses': 9998,
#  'token[-3]=Arab': 7313,
#  'token[-2]=prison': 5116,
#  'token[1]=win': 1060,
#  'token[3]=mln': 13956,
#  'token[1]=St': 5178,
#  'token[3]=support': 2217,
#  'token[3]=moved': 13958,
#  'token[3]=1997': 3546,
#  'token[3]=Chinese': 7958,
#  'token[2]=request': 13816,
#  'token[-2]=demand': 3206,
#  'token[-1]=Bill': 5455,
#  'token[-1]=provincial': 14191,
#  'token[0]=than': 711,
#  'token[0]=return': 3148,
#  'token[0]=hope': 8282,
#  'token[-1]=seed': 4430,
#  'token[3]=surgery': 11894,
#  'token[2]=blood': 11729,
#  'token[-2]=OPEN': 13073,
#  'token[-1]=exchange': 8054,
#  'token[-1]=6-1': 2795,
#  'token[0]=Houston': 14689,
#  'token[-3]=ST': 8700,
#  'token[-1]=Some': 6558,
#  'token[1]=production': 4232,
#  'token[0]=part': 1531,
#  'token[-2]=traffic': 8678,
#  'token[-2]=Extras': 10428,
#  'token[-3]=local': 2345,
#  'token[-3]=Van': 8706,
#  'token[0]=Shanghai': 11481,
#  'token[2]=62': 5613,
#  'token[-1]=here': 5716,
#  'token[2]=6-3': 1061,
#  'token[-1]=USDA': 12922,
#  'token[-1]=TOKYO': 9683,
#  'token[0]=last': 435,
#  'token[-1]=her': 618,
#  'token[3]=always': 10223,
#  'token[-2]=building': 9795,
#  'token[-1]=south': 5483,
#  'token[-3]=candidate': 13255,
#  'token[3]=Croft': 6822,
#  'token[3]=take': 1569,
#  'token[1]=There': 6422,
#  'token[0]=GERMAN': 9343,
#  'token[1]=effort': 14984,
#  'token[-1]=continue': 5711,
#  'token[-1]=than': 710,
#  'token[1]=fifth': 4664,
#  'token[0]=Tim': 9968,
#  'token[1]=though': 10866,
#  'token[-2]=should': 1525,
#  'token[1]=49': 10033,
#  'token[2]=statement': 1124,
#  'token[0]=buying': 11500,
#  'token[-1]=increase': 6574,
#  'token[-2]=October': 5494,
#  'token[2]=ban': 3989,
#  'token[-1]=sector': 6901,
#  'token[-1]=V': 9095,
#  'token[1]=Slovakia': 4368,
#  'token[0]=loss': 3073,
#  'token[-1]=Waugh': 11975,
#  'token[-3]=organisers': 14592,
#  'token[0]=high': 3805,
#  'token[0]=Teresa': 7018,
#  'token[-1]=And': 11082,
#  'token[2]=quoted': 3620,
#  'token[0]=19': 3067,
#  'token[2]=yen': 4867,
#  'token[0]=Coast': 11447,
#  'token[-1]=Yasser': 11978,
#  'token[3]=Medvedev': 11820,
#  'token[-2]=dollar': 2949,
#  'token[-1]=report': 2389,
#  'token[0]=player': 6733,
#  'token[-1]=kg': 14171,
#  'token[-1]=40': 3735,
#  'token[-2]=means': 13146,
#  'token[0]=public': 4358,
#  'token[-2]=Nicaraguan': 11228,
#  'token[1]=barter': 12547,
#  'token[-2]=off': 895,
#  'token[-2]=1991': 8089,
#  'token[-3]=in': 41,
#  'token[1]=hour': 10077,
#  'token[1]=Islamist': 12515,
#  'token[0]=Both': 13357,
#  'token[-3]=15': 1758,
#  'token[0]=11': 858,
#  'token[-2]=German': 1389,
#  'token[0]=own': 3682,
#  'token[3]=Williams': 9600,
#  'token[-1]=another': 2578,
#  'token[3]=result': 6198,
#  'token[-3]=industry': 5136,
#  'token[-2]=caused': 9189,
#  'token[-2]=President': 967,
#  'token[-2]=run': 2130,
#  'token[-3]=picked': 11410,
#  'token[2]=side': 3999,
#  'token[-3]=To': 9871,
#  'token[2]=voting': 8436,
#  'token[3]=said': 96,
#  'token[3]=final': 2038,
#  'token[2]=Games': 10889,
#  'token[1]=threatening': 13680,
#  'token[2]=pounds': 6486,
#  'token[-3]=Brazilian': 7711,
#  'token[-2]=daily': 4934,
#  'token[-3]=index': 3595,
#  'token[-3]=13': 2021,
#  'token[-1]=GAMES': 10303,
#  'token[-1]=giving': 9709,
#  'token[1]=customers': 14977,
#  'token[0]=cancelled': 14764,
#  'token[1]=Angeles': 7060,
#  'token[3]=bit': 12778,
#  'token[-2]=Schalke': 13084,
#  'token[2]=Mark': 3708,
#  'token[-1]=JOHANNESBURG': 11946,
#  'token[1]=movement': 7453,
#  'token[-2]=forced': 4590,
#  'token[2]=off': 874,
#  'token[-3]=resignation': 9305,
#  'token[1]=no': 632,
#  'token[0]=Democratic': 2680,
#  'token[-1]=Cofinec': 14020,
#  'token[-3]=EU': 6648,
#  'token[0]=battle': 8805,
#  'token[3]=treaty': 6851,
#  'token[2]=shares': 1563,
#  'token[0]=Martinez': 9351,
#  'token[-1]=Arantxa': 12859,
#  'token[3]=70': 1966,
#  'token[1]=debut': 12559,
#  'token[-2]=Croft': 8599,
#  'token[-2]=attempt': 8631,
#  'token[-3]=35': 13190,
#  'token[-2]=treaty': 6305,
#  'token[-1]=employee': 14143,
#  'token[-1]=groups': 4911,
#  'token[-1]=France': 805,
#  'token[0]=billions': 14759,
#  'token[-3]=hits': 3667,
#  'token[2]=Tennis': 12657,
#  'token[-1]=growing': 14158,
#  'token[-1]=Union': 2936,
#  'token[-1]=central': 2799,
#  'token[1]=visited': 8934,
#  'token[0]=Foreign': 2830,
#  'token[1]=John': 2839,
#  'token[2]=CITY': 13706,
#  'token[0]=investigators': 11531,
#  'token[1]=Sox': 10796,
#  'token[-1]=girls': 7239,
#  'token[-1]=freed': 12012,
#  'token[0]=newspaper': 2195,
#  'token[0]=been': 315,
#  'token[2]=lei': 13791,
#  'token[-3]=seed': 4783,
#  'token[-1]=JERUSALEM': 11097,
#  'token[-1]=)': 66,
#  'token[3]=open': 7186,
#  'token[0]=programme': 9397,
#  'token[-3]=view': 14635,
#  'token[0]=Reds': 13397,
#  'token[0]=final': 1728,
#  'token[0]=Armstrong': 14656,
#  'token[-3]=books': 11379,
#  'token[3]=interest': 4706,
#  'token[0]=much': 3509,
#  'token[-3]=;': 3295,
#  'token[-2]=That': 4746,
#  'token[-1]=against': 488,
#  'token[-1]=6-': 11912,
#  'token[-3]=official': 1253,
#  'token[-1]=big': 5938,
#  'token[-2]=more': 685,
#  'token[1]=call': 4821,
#  'token[0]=about': 591,
#  'token[2]=currently': 10931,
#  'token[3]=work': 3264,
#  'token[-1]=commission': 8045,
#  'token[-1]=found': 2010,
#  'token[-2]=Union': 3284,
#  'token[-3]=I': 397,
#  'token[-2]=Rangers': 11234,
#  'token[-1]=+44': 10280,
#  'token[2]=3': 176,
#  'token[3]=Toyota': 11837,
#  'token[0]=secret': 10732,
#  'token[0]=clocked': 14772,
#  'token[2]=described': 10932,
#  'token[1]=paper': 6127,
#  'token[2]=bill': 11727,
#  'token[-1]=Polish': 6555,
#  'token[0]=Ian': 6703,
#  'token[-1]=MILWAUKEE': 10314,
#  'token[3]=confirmed': 5662,
#  'token[0]=freed': 12445,
#  'token[-3]=Pakistan': 1759,
#  'token[-1]=ENGLISH': 7584,
#  'token[-2]=against': 489,
#  'token[-2]=short': 4761,
#  'token[2]=41': 9494,
#  'token[0]=Johan': 14692,
#  'token[0]=Craig': 10650,
#  'token[-2]=57': 8591,
#  'token[0]=1-1': 5790,
#  'token[-1]=Hampshire': 11938,
#  'token[0]=Beijing': 9936,
#  'token[-2]=1994': 4580,
#  'token[2]=vote': 4001,
#  'token[-3]=played': 821,
#  'token[2]=with': 147,
#  'token[1]=products': 7456,
#  'token[2]=computer': 12674,
#  'token[2]=expect': 8971,
#  'token[-2]=who': 279,
#  'token[0]=include': 11526,
#  'token[2]=Yankees': 13738,
#  'token[-1]=Athens': 11919,
#  'token[-3]=low': 6985,
#  'token[2]=DIVISION': 3004,
#  'token[2]=Hospital': 11699,
#  'token[0]=4': 199,
#  'token[-2]=training': 14425,
#  'token[0]=building': 9372,
#  'token[2]=trip': 5225,
#  'token[1]=League': 2416,
#  'token[-3]=Sampras': 9261,
#  'token[2]=OM': 12648,
#  'token[-1]=Inc': 2116,
#  'token[1]=rain': 7097,
#  'token[2]=PSV': 7485,
#  'token[-2]=Rica': 13082,
#  'token[3]=English': 7166,
#  'token[0]=risk': 7823,
#  'token[-3]=victims': 13332,
#  'token[0]=customers': 14780,
#  'token[-1]=stay': 7253,
#  'token[-3]=Hapoel': 11348,
#  'token[-2]=Spain': 1179,
#  'token[0]=jobs': 14813,
#  'token[-2]=6-2': 4168,
#  'token[-3]=1-0': 5761,
#  'token[-2]=the': 11,
#  'token[0]=you': 1732,
#  'token[-2]=draw': 4442,
#  'token[-3]=Japanese': 5124,
#  'token[-1]=house': 6245,
#  'token[-1]=Service': 8033,
#  'token[0]=OB': 12389,
#  'token[-2]=Turkey': 8111,
#  'token[3]=approved': 12773,
#  'token[-1]=committee': 6566,
#  'token[-2]=party': 1793,
#  'token[-1]=seek': 8574,
#  'token[-3]=Turkey': 8185,
#  'token[-1]=where': 1113,
#  'token[0]=Five': 14682,
#  'token[-2]=find': 7680,
#  'token[1]=Minnesota': 13572,
#  'token[-2]=Indonesia': 7656,
#  'token[-3]=guilders': 7743,
#  'token[0]=approved': 10690,
#  'token[-2]=American': 2178,
#  'token[-1]=probably': 8070,
#  'token[1]=winner': 6139,
#  'token[1]=existing': 14988,
#  'token[0]=second': 519,
#  'token[2]=7-6': 1774,
#  'token[2]=walked': 10193,
#  'token[-2]=Spanish': 11243,
#  'token[-3]=investigators': 13289,
#  'token[1]=pair': 8915,
#  'token[2]=300': 6140,
#  'token[0]=to': 32,
#  'token[-2]=Corp.': 14247,
#  'token[2]=Cyprus': 8943,
#  'token[-2]=refugees': 3050,
#  'token[-3]=up': 444,
#  'token[3]=Oval': 9010,
#  "token[1]='m": 5836,
#  'token[2]=possible': 4522,
#  'token[-1]=second': 521,
#  'token[0]=4-6': 7763,
#  'token[-1]=come': 4562,
#  'token[2]=measures': 9548,
#  'token[-2]=share': 3774,
#  'token[0]=champions': 4071,
#  'token[-2]=(': 53,
#  'token[-1]=economic': 2645,
#  'token[-2]=LOUIS': 10439,
#  'token[-3]=On': 3661,
#  'token[-2]=Wimbledon': 5742,
#  'token[0]=so': 1694,
#  'token[-1]=alleged': 12932,
#  'token[2]=investors': 7143,
#  'token[2]=questioned': 12708,
#  'token[-2]=Lauck': 11221,
#  'token[1]=including': 2843,
#  'token[2]=times': 5896,
#  'token[2]=ordered': 7513,
#  'token[0]=Feyenoord': 9943,
#  'token[-3]=beaten': 14534,
#  'token[1]=returned': 6129,
#  'token[-1]=husband': 8557,
#  'token[1]=score': 12599,
#  'token[2]=leave': 6161,
#  'token[2]=soon': 5223,
#  'token[3]=Exchange': 5652,
#  'token[1]=campaign': 3697,
#  'token[-1]=time': 794,
#  'token[1]=advantage': 13592,
#  'token[-2]=long-term': 12161,
#  'token[3]=b': 2790,
#  'token[-3]=figure': 12295,
#  'token[-3]=10th': 9234,
#  'token[-3]=stock': 5334,
#  'token[1]=basis': 9449,
#  'token[0]=goal': 6076,
#  "token[3]=n't": 1474,
#  'token[-2]=opening': 4592,
#  'token[-1]=expect': 7237,
#  'token[0]=saw': 7825,
#  'token[2]=announced': 3248,
#  'token[-2]=Ukraine': 3766,
#  'token[0]=ethnic': 7393,
#  'token[3]=church': 12780,
#  'token[-2]=South': 918,
#  'token[-1]=customers': 14135,
#  'token[-2]=Arabia': 13037,
#  'token[1]=battle': 8889,
#  'token[2]=leadership': 12698,
#  'token[-3]=shortly': 13312,
#  'token[-1]=evidence': 12009,
#  'token[0]=union': 7412,
#  'token[3]=ministry': 5240,
#  'token[0]=committed': 14773,
#  'token[-1]=China': 1166,
#  'token[-3]=entering': 12294,
#  'token[1]=plant': 7094,
#  'token[-1]=above': 12929,
#  'token[-3]=40': 6016,
#  'token[0]=team': 1299,
#  'token[-2]=retired': 14404,
#  'token[-1]=party': 1544,
#  'token[2]=agreed': 2559,
#  'token[-3]=GERMAN': 9252,
#  'token[-3]=Minister': 856,
#  'token[1]=Greece': 10778,
#  'token[-2]=Berlin': 9753,
#  'token[3]=companies': 5234,
#  'token[-2]=term': 6637,
#  'token[1]=57': 7843,
#  'token[-1]=51': 8491,
#  'token[0]=Results': 1370,
#  'token[2]=Paulo': 11708,
#  'token[-3]=changed': 14547,
#  'token[-2]=says': 1981,
#  'token[0]=Party': 2760,
#  'token[0]=30': 1337,
#  'token[-2]=stock': 4947,
#  'token[-2]=Newcastle': 14284,
#  'token[-2]=February': 8099,
#  'token[0]=Kenya': 4624,
#  'token[1]=Colombia': 10038,
#  'token[-2]=midfielder': 7690,
#  'token[1]=Bob': 10036,
#  'token[0]=400': 7004,
#  'token[-1]=Albanian': 9059,
#  'token[0]=Socialist': 11482,
#  'token[-3]=Deputy': 14460,
#  'token[-2]=Fox': 12081,
#  'token[2]=men': 3348,
#  'token[-3]=Islamic': 8173,
#  'token[-1]=car': 7610,
#  'token[-1]=3-1': 10283,
#  'token[-3]=Court': 8688,
#  'token[-2]=want': 2663,
#  'token[1]=walked': 9488,
#  'token[-1]=doctors': 12951,
#  'token[1]=west': 11672,
#  'token[-3]=service': 4620,
#  'token[1]=town': 2157,
#  'token[2]=black': 7494,
#  'token[0]=farm': 8816,
#  'token[0]=A': 541,
#  'token[0]=CYCLING': 10649,
#  'token[3]=exports': 5909,
#  'token[-3]=Grand': 6956,
#  'token[2]=largest': 8978,
#  'token[-1]=posted': 12988,
#  'token[3]=seed': 5675,
#  'token[0]=well': 1764,
#  'token[0]=Vicario': 13418,
#  'token[1]=stake': 10859,
#  'token[2]=appeared': 8960,
#  'token[3]=himself': 7557,
#  'token[-1]=de': 2871,
#  'token[1]=28': 2906,
#  'token[1]=lines': 11647,
#  'token[0]=Note': 14714,
#  'token[-1]=57': 8010,
#  'token[-1]=prime': 4032,
#  'token[-3]=verified': 7759,
#  'token[-1]=50': 1843,
#  'token[3]=county': 13919,
#  'token[1]=Moscow': 2363,
#  'token[-1]=Iraqi': 2385,
#  'token[-1]=stage': 5959,
#  'token[-3]=mixed': 14586,
#  'token[1]=whom': 12616,
#  'token[-3]=feed': 9290,
#  'token[-1]=capital': 1591,
#  'token[1]=last': 436,
#  'token[-1]=tabulated': 6583,
#  'token[-3]=Craig': 11334,
#  'token[2]=arrested': 2851,
#  'token[-2]=built': 14336,
#  'token[-2]=there': 910,
#  'token[-2]=changed': 12132,
#  'token[2]=Taiwan': 5396,
#  'token[-3]=right': 4619,
#  'token[-1]=so': 1684,
#  'token[-3]=hold': 3781,
#  'token[-3]=more': 732,
#  'token[1]=RESULT': 10048,
#  'token[0]=coach': 4636,
#  'token[1]=drove': 8900,
#  'token[0]=Ford': 12372,
#  'token[-1]=MONTREAL': 9672,
#  'token[-3]=both': 2297,
#  'token[3]=public': 4543,
#  'token[0]=Lebed': 3308,
#  'token[-2]=suffered': 8155,
#  'token[-2]=suspended': 13173,
#  'token[-2]=political': 1714,
#  'token[1]=expect': 7446,
#  'token[-1]=consecutive': 12945,
#  'token[-2]=noted': 11289,
#  'token[2]=training': 13836,
#  'token[-2]=led': 3770,
#  'token[2]=Clinton': 1535,
#  'token[-3]=relations': 8738,
#  'token[-1]=face': 4565,
#  'token[1]=negotiations': 7091,
#  'token[-2]=minute': 2289,
#  'token[-1]=delayed': 9699,
#  'token[1]=Hungary': 7853,
#  'token[3]=move': 9619,
#  'token[-2]=Israel': 2283,
#  'token[-1]=chairman': 5254,
#  'token[-2]=20': 1521,
#  'token[-1]=held': 1477,
#  'token[0]=died': 3803,
#  'token[-3]=Nations': 5527,
#  'token[3]=Jul': 13876,
#  'token[0]=Japanese': 4982,
#  ...}

# %%
print(flat_dataset["train"][0]["features"])
tokenizer(flat_dataset["train"][0]["features"])
# Out:
# token[0]=EU token[1]=rejects token[2]=German token[3]=call first-letter-capitalized
# {'input_ids': [6058, 1, 1896, 5233, 2], 'attention_mask': [1, 1, 1, 1, 1]}

# %%
def encode(examples):
    return tokenizer(examples['features'])

dset_tokenized = flat_dataset.map(encode,batched=True,num_proc=4)

for key,val in dset_tokenized["train"][0].items():
    print(key,":",val)
# Out:
# Map (num_proc=4):   0%|          | 0/203621 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/51362 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/46435 [00:00<?, ? examples/s]
# tokens : EU
# pos_tags : 22
# chunk_tags : 11
# ner_tags : 3
# features : token[0]=EU token[1]=rejects token[2]=German token[3]=call first-letter-capitalized
# input_ids : [6058, 1, 1896, 5233, 2]
# attention_mask : [1, 1, 1, 1, 1]

# %% [markdown]
# # Labels
#
# There are three tasks in this dataset (POS, chunks, NER). So we want to choose one of them and create the "labels" key used by the trainer. So let's pick the POS task.

# %% [markdown]
# PART B
#
# Instead let's choose the NER labels

# %%
def assign_labels(ex):
    return {"labels":ex["ner_tags"]}
dset_tokenized=dset_tokenized.map(assign_labels,batched=True)
# Out:
# Map:   0%|          | 0/203621 [00:00<?, ? examples/s]
# Map:   0%|          | 0/51362 [00:00<?, ? examples/s]
# Map:   0%|          | 0/46435 [00:00<?, ? examples/s]

# %%
dset_tokenized["train"][0]
# Out:
# {'tokens': 'EU',
#  'pos_tags': 22,
#  'chunk_tags': 11,
#  'ner_tags': 3,
#  'features': 'token[0]=EU token[1]=rejects token[2]=German token[3]=call first-letter-capitalized',
#  'input_ids': [6058, 1, 1896, 5233, 2],
#  'attention_mask': [1, 1, 1, 1, 1],
#  'labels': 3}

# %% [markdown]
# ---
#
# # MLP model
#
# With the data now ready, we'll build the MLP model. Note that this is _identical_ to the MLP model we used for text classification: the only difference between the two applications is in the data.
#
# The model class in its simplest form has `__init__()` which instantiates the layers and `forward()` which implements the actual computation. For more information on these, please see the [PyTorch turorial](https://pytorch.org/tutorials/beginner/introyt/modelsyt_tutorial.html).

# %%
# A Transformers library model wants a config,
# I can simply inherit from the base
# class for pretrained configs
# We don't really need to do anything very special
class MLPConfig(transformers.PretrainedConfig):
    pass

# This is the model
class MLP(transformers.PreTrainedModel):

    config_class=MLPConfig

    # In the initialization method, one instantiates the layers
    # these will be, for the most part the trained parameters of the model
    def __init__(self,config):
        super().__init__(config)
        self.all_tied_weights_keys = {} #Annoying bug in Transformers, must have this here or else we crash on saved model load
        #### HERE WE CREATE THE MODEL'S LAYERS:
        self.vocab_size=config.vocab_size #embedding matrix row count
        # Build and initialize embedding of vocab size x hidden size
        assert tokenizer.vocab["[PAD]"]==0 #let's make sure our assumption of pad==0 holds!

        self.embedding=torch.nn.Embedding(num_embeddings=self.vocab_size,embedding_dim=config.hidden_size,padding_idx=0)
        # Initialize the embeddings to random values
        # Note! This function is relatively clever and keeps the embedding for 0, the padding, pure zeros
        torch.nn.init.uniform_(self.embedding.weight.data,-0.001,0.001) #initialize the embeddings with small random values

        # This takes care of the lower half of the network, now the upper half
        # Output layer: hidden size x output size
        self.output=torch.nn.Linear(in_features=config.hidden_size,out_features=config.nlabels)
        # Now we have the parameters of the model
        self.loss=torch.nn.CrossEntropyLoss() #This loss is meant for classification, so let's use it


    # The computation of the model is put into the forward() function
    # it receives a batch of data and optionally the correct `labels`
    #
    # If given `labels` it returns (loss,output)
    # if not, then it returns (output,)
    def forward(self,input_ids,labels=None,**kwargs):
        #1) sum up the embeddings of the items
        embedded=self.embedding(input_ids) #(batch,ids)->(batch,ids,embedding_dim)
        # Since the Embedding keeps the first row of the matrix pure zeros, we don't need to worry about the padding
        # so next we sum the embeddings across the word dimension
        # (batch,ids,embedding_dim) -> (batch,embedding_dim)
        embedded_summed=torch.sum(embedded,dim=1)

        #2) apply non-linearity
        # (batch,embedding_dim) -> (batch,embedding_dim)
        projected=torch.tanh(embedded_summed) #Note how non-linearity is applied here and not when configuring the layer in __init__()
        # projected=embedded_summed ## If you need to bypass non-linearity, use this :)
        #3) and now apply the upper, output layer of the network
        # (batch,embedding_dim) -> (batch, num_of_classes i.e. 2 in our case)
        logits=self.output(projected)

        # ...and that's all there is to it!

        #print("input_ids.shape",input_ids.shape)
        #print("embedded.shape",embedded.shape)
        #print("embedded_summed.shape",embedded_summed.shape)
        #print("projected.shape",projected.shape)
        #print("logits.shape",logits.shape)

        # If we have labels, we ought to calculate the loss
        if labels is not None:

            # You run it as loss(model_output,correct_labels)
            return (self.loss(logits,labels),logits) #2-tuple, i.e. pair of values returned
        else:
            # No labels, so just return the logits
            return (logits,) #this weird syntax means 1-tuple

# %% [markdown]
# Configure the model

# %%
num_labels = len(NER2ID)

mlp_config = MLPConfig(
    vocab_size=len(tokenizer.vocab),
    hidden_size=20,
    nlabels=num_labels
)

print("mlp_config:", mlp_config)
# Out:
# mlp_config: MLPConfig {
#   "hidden_size": 20,
#   "nlabels": 9,
#   "transformers_version": "5.5.4",
#   "vocab_size": 15000
# }

# %% [markdown]
# ---
#
# # Train the model
#
# We will use the Hugging Face [Trainer](https://huggingface.co/docs/transformers/main_classes/trainer) class for training
#
# * Loads of arguments that control the training
# * Configurable metrics to evaluate performance
# * Data collator builds the batches
# * Early stopping callback stops when eval loss no longer improves
# * Model load/save
# * Good foundation for later deep learning course

# %% [markdown]
# First, let's create a [`TrainingArguments`](https://huggingface.co/docs/transformers/v4.17.0/en/main_classes/trainer#transformers.TrainingArguments) object to specify hyperparameters and various other settings for training.
#
# Printing this simple dataclass object will show not only the values we set, but also the defaults for all other arguments. Don't worry if you don't understand what all of these do! Many are not relevant to us here, and you can find the details in [`Trainer` documentation](https://huggingface.co/docs/transformers/main_classes/trainer) if you are interested.

# %%
trainer_args = transformers.TrainingArguments(
    "mlp_checkpoints", #save checkpoints here
    eval_strategy="steps",
    logging_strategy="steps",
    eval_steps=1000,
    logging_steps=1000,
    save_steps=1000,
    learning_rate=5e-4, #learning rate of the gradient descent
    max_steps=20000,
    load_best_model_at_end=True,
    per_device_train_batch_size=16
)

pprint(trainer_args)
# Out:
# TrainingArguments(
# accelerator_config={'split_batches': False, 'dispatch_batches': None, 'even_batches': True, 'use_seedable_sampler': True, 'non_blocking': False, 'gradient_accumulation_kwargs': None, 'use_configured_state': False},
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# average_tokens_across_devices=True,
# batch_eval_metrics=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_persistent_workers=False,
# dataloader_pin_memory=True,
# dataloader_prefetch_factor=None,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=False,
# enable_jit_checkpoint=False,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_do_concat_batches=True,
# eval_on_start=False,
# eval_steps=1000,
# eval_strategy=IntervalStrategy.STEPS,
# eval_use_gather_object=False,
# fp16=False,
# fp16_full_eval=False,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_v2': False, 'xla_fsdp_grad_ckpt': False},
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=False,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=None,
# hub_revision=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_for_metrics=[],
# include_num_input_tokens_seen=no,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=0.0005,
# length_column_name=length,
# liger_kernel_config=None,
# load_best_model_at_end=True,
# local_rank=-1,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=None,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=1000,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_kwargs=None,
# lr_scheduler_type=SchedulerType.LINEAR,
# max_grad_norm=1.0,
# max_steps=20000,
# metric_for_best_model=loss,
# neftune_noise_alpha=None,
# num_train_epochs=3.0,
# optim=OptimizerNames.ADAMW_TORCH_FUSED,
# optim_args=None,
# optim_target_modules=None,
# output_dir=mlp_checkpoints,
# parallelism_config=None,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=16,
# prediction_loss_only=False,
# project=huggingface,
# push_to_hub=False,
# remove_unused_columns=True,
# report_to=[],
# restore_callback_states_from_checkpoint=False,
# resume_from_checkpoint=None,
# run_name=None,
# save_on_each_node=False,
# save_only_model=False,
# save_steps=1000,
# save_strategy=SaveStrategy.STEPS,
# save_total_limit=None,
# seed=42,
# skip_memory_metrics=True,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torch_empty_cache_steps=None,
# trackio_space_id=trackio,
# train_sampling_strategy=random,
# use_cache=False,
# use_cpu=False,
# use_liger_kernel=False,
# warmup_ratio=None,
# warmup_steps=0,
# weight_decay=0.0,
# )

# %% [markdown]
# Next, let's create a metric for evaluating performance during and after training. We can use the convenience function [`load_metric`](https://huggingface.co/docs/datasets/about_metrics) to load one of many pre-made metrics and wrap this for use by the trainer.
#
# We can use the basic `accuracy` metric, defined as the proportion of correctly predicted labels out of all labels. This time, though, the data is not evenly split.

# %%
import numpy as np
import evaluate

accuracy = evaluate.load("accuracy")

def compute_accuracy(outputs_and_labels):
    outputs, labels = outputs_and_labels
    predictions = np.argmax(outputs, axis=-1) #pick the index of the "winning" label
    return accuracy.compute(predictions=predictions, references=labels)

# %% [markdown]
# We can then create the `Trainer` and train the model by invoking the [`Trainer.train`](https://huggingface.co/docs/transformers/main_classes/trainer#transformers.Trainer.train) function.
#
# In addition to the model, the settings passed in through the `TrainingArguments` object created above (`trainer_args`), the data, and the metric defined above, we create and pass the following to the `Trainer`:
#
# * [data collator](https://huggingface.co/docs/transformers/main_classes/data_collator): groups input into batches
# * [`EarlyStoppingCallback`](https://huggingface.co/docs/transformers/main_classes/callback#transformers.EarlyStoppingCallback): stops training when performance stops improving

# %%
# Make a new model
mlp = MLP(mlp_config)


# Argument gives the number of steps of patience before early stopping
# i.e. training is stopped when the evaluation loss fails to improve
# certain number of times
early_stopping = transformers.EarlyStoppingCallback(5)

trainer = transformers.Trainer(
    model=mlp,
    args=trainer_args,
    train_dataset=dset_tokenized["train"],
    eval_dataset=dset_tokenized["validation"].select(range(1000)),
    compute_metrics=compute_accuracy,
    data_collator=transformers.DataCollatorWithPadding(tokenizer),
    callbacks=[early_stopping]
)

trainer.train()
# Out:
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#     <div>
#
#       <progress value='20000' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20000/20000 00:54, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>0.934880</td>
#       <td>0.760141</td>
#       <td>0.775000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.497349</td>
#       <td>0.627391</td>
#       <td>0.795000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.419605</td>
#       <td>0.566483</td>
#       <td>0.811000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.361908</td>
#       <td>0.518037</td>
#       <td>0.838000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.317720</td>
#       <td>0.486171</td>
#       <td>0.848000</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.294810</td>
#       <td>0.444792</td>
#       <td>0.873000</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.253743</td>
#       <td>0.417137</td>
#       <td>0.879000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.249886</td>
#       <td>0.375772</td>
#       <td>0.897000</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.234768</td>
#       <td>0.356334</td>
#       <td>0.899000</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.212866</td>
#       <td>0.343024</td>
#       <td>0.900000</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.215888</td>
#       <td>0.320303</td>
#       <td>0.908000</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.208183</td>
#       <td>0.308207</td>
#       <td>0.909000</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.192437</td>
#       <td>0.301953</td>
#       <td>0.910000</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.174042</td>
#       <td>0.290289</td>
#       <td>0.914000</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.176066</td>
#       <td>0.282578</td>
#       <td>0.911000</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.166034</td>
#       <td>0.277887</td>
#       <td>0.914000</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.173636</td>
#       <td>0.273442</td>
#       <td>0.916000</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.169040</td>
#       <td>0.271028</td>
#       <td>0.917000</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.158909</td>
#       <td>0.269889</td>
#       <td>0.916000</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.166816</td>
#       <td>0.268469</td>
#       <td>0.916000</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/asteer/data/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# TrainOutput(global_step=20000, training_loss=0.278929362487793, metrics={'train_runtime': 54.9397, 'train_samples_per_second': 5824.567, 'train_steps_per_second': 364.035, 'total_flos': 2829396906.0, 'train_loss': 0.278929362487793, 'epoch': 1.571462245619549})

# %% [markdown]
# That's pretty poor performance for a task as simple as POS tagging where state-of-the-art accuracies are generally 97-99%. (The approach demonstrated in this notebook should be considered more of a teaching tool than a serious tagger implementation.)
#
# However, the result is certainly much better than random, so we can conclude that the model is learning something about the task.

# %% [markdown]
# PART A
#
# The training accuracy for the original model is 87,5%.
#
# The training accuracy without context of the original word is 60,5%. This is significantly worse than the original result.
#
# The training accuracy for memorization only is 68,1%. This is still worse than the original but it is better compared to the out of context model.

# %% [markdown]
# ---
#
# # What has the model learned?
#
# * The embeddings should have some meaning to them
# * Similar features should have similar embeddings

# %%
# Grab the embedding matrix out of the trained model
# and drop the first row (padding 0)
# then we can treat the embeddings as vectors

weights=mlp.embedding.weight.detach().cpu().numpy()

# %%
import sklearn
qry_idx=tokenizer.vocab["token[0]=in"]
idx2feat={v:k for k,v in tokenizer.vocab.items()}

#calculate the distance of the "in" embedding to all other embeddings
distance_to_qry=sklearn.metrics.pairwise.euclidean_distances(weights[qry_idx:qry_idx+1,:],weights)
nearest_neighbors=np.argsort(distance_to_qry) #indices of words nearest to "in"
for nearest in nearest_neighbors[0,:20]:
    print(idx2feat[nearest])
# Out:
# token[0]=in
# token[0]=more
# token[0]=(
# token[0]=reporters
# token[0]=is
# token[0]=four
# token[0]=opposition
# token[1]=billion
# token[0]=win
# token[0]=six
# token[1]=tonnes
# token[0]=under
# token[1]=minute
# token[0]=political
# token[0]=reported
# token[0]=five
# token[-1]=.
# token[0]=soccer
# token[0]=could
# token[0]=when

# %% [markdown]
# * The embeddings indeed seem to reflect the task and capture aspects of the meaning of words relevant to the task
# * But now we have many classes, so we should take that into account too
# * We can take the dot-product of the feature embeddings with the output layer weight of the class we care about
# * When you think how the information propagates in the network, this will give us a single number reflecting each feature w.r.t. the selected label
# * Technically speaking, it is the prediction of an example which only has that one feature, with respect to that one class
# * Here is how we can implement it (here we rely on the fact that the model is linear, since we didn't include a nonlinearity earlier in the model's `forward()`

# %%
import numpy

embedding_weights=weights    #shape (features, embedding-dim)
output_weights=mlp.output.weight.detach().cpu().numpy()    #shape (num-labels, embedding-dim)

# We just matrix-multiply these together, since this gives us all the dot-products
weights_by_label=numpy.matmul(numpy.tanh(embedding_weights), output_weights.T)
weights_by_label.shape
# Out:
# (15000, 9)

# %%
def get_most_important_features_for_and_against(label):
    label_idx = NER2ID[label]
    feature_weights = weights_by_label[:,label_idx] #pick the column that interests us

    #The shape of feature_weights is (feature_vocab_size,) i.e. it is a vector
    features_weight_idx = numpy.argsort(-feature_weights) #sort in descending order, this will be vector of indices
    features_for = [idx2feat[feature_idx] for feature_idx in features_weight_idx[:30]]
    features_against = [idx2feat[feature_idx] for feature_idx in features_weight_idx[-30:][::-1]]
    return features_for, features_against

for label in (NER_TAG_NAMES):
    dt_plus,dt_minus=get_most_important_features_for_and_against(label)
    print(f"Most important features *for* label {label}:")
    pprint("   ".join(dt_plus))
    print()
    print(f"Most important features *against* label {label}:")
    pprint("   ".join(dt_minus))
    print("\n------\n")
# Out:
# Most important features *for* label O:
# ('token[0]=0   token[0]=He   token[0]=a   token[0]="   token[0]=2   '
#  'token[0]=It   token[0]=3   token[0]=-   token[0]=said   token[0]=I   '
#  'token[0]=4   token[0]=The   token[0]=to   token[0]=AT   token[0]=But   '
#  'token[0]=1   token[0]=he   token[0]=was   token[0]=A   token[0]=In   '
#  'token[0]=his   token[0]=1996-08-28   token[0]=it   token[0]=who   '
#  'token[0]=.   token[0]=an   token[0]=Minister   token[0]=--   token[0]=We   '
#  'token[0]=has')
#
# Most important features *against* label O:
# ('first-letter-capitalized   token[0]=de   token[0]=U.S.   token[0]=&   '
#  'token[0]=Britain   token[0]=Germany   token[0]=China   token[0]=Iraq   '
#  'token[0]=Pakistan   token[0]=India   token[0]=Russia   token[-1]=Lloyd   '
#  'token[0]=France   token[1]=Oval   token[0]=South   token[0]=England   '
#  'token[0]=Japan   token[-1]=At   token[0]=Italy   token[0]=Australia   '
#  'token[-1]=President   token[1]=Co   token[0]=Israel   token[0]=van   '
#  'token[-1]=v   token[0]=London   token[0]=British   token[0]=Moscow   '
#  'token[1]=newsroom   token[1]=1996-08-26')
#
# ------
#
# Most important features *for* label B-PER:
# ('token[-1]=President   token[-1]=b   token[-1]=2.   token[0]=Mark   '
#  'token[-1]=3.   token[-1]=1.   token[0]=Clinton   token[-1]=Minister   '
#  'token[-1]=6.   token[0]=M.   token[0]=Paul   token[0]=John   token[-1]=5.   '
#  'token[-1]=4.   token[-1]=champion   token[2]=c   token[0]=Michael   '
#  'token[-1]=7.   token[0]=David   token[0]=A.   token[-1]=beat   '
#  'token[3]=Sweden   token[0]=Wasim   token[1]=Akram   token[0]=Arafat   '
#  'token[0]=Peter   token[1]=Ahmed   token[0]=Yeltsin   token[0]=Dutroux   '
#  'token[3]=France')
#
# Most important features *against* label B-PER:
# ('token[0]="   token[0]=He   token[0]=It   token[0]=The   token[0]=a   '
#  'token[0]=0   token[0]=I   token[0]=-   token[0]=he   token[0]=2   '
#  'token[0]=AT   token[0]=3   token[0]=said   token[0]=to   token[0]=In   '
#  'token[0]=who   token[0]=But   token[0]=it   token[0]=A   token[0]=4   '
#  'token[0]=an   token[0]=his   token[0]=which   token[0]=.   token[0]=We   '
#  'token[0]=was   token[0]=1996-08-28   token[0]=Minister   token[0]=has   '
#  'token[0]=President')
#
# ------
#
# Most important features *for* label I-PER:
# ('token[-2]=President   token[-2]=Minister   token[-1]=M.   token[-1]=John   '
#  'token[-1]=Mark   token[-1]=Paul   token[0]=Akram   token[0]=Ahmed   '
#  'token[-1]=Michael   token[-2]=beat   token[-1]=David   token[2]=Spain   '
#  'token[-1]=A.   token[-3]=Prime   token[-2]=champion   token[-2]=vs.   '
#  'token[1]=c   token[-1]=Waqar   token[-1]=Peter   token[-2]=1.   '
#  'token[-1]=Wasim   token[-1]=Robert   token[-1]=G.   token[-1]=Steve   '
#  'token[1]=through   token[-1]=Bill   token[-1]=Alexander   token[-1]=N.   '
#  'token[0]=Younis   token[-2]=leader')
#
# Most important features *against* label I-PER:
# ('token[-1]=the   token[0]=The   token[0]=He   token[0]=0   token[0]=a   '
#  'token[0]=said   token[0]="   token[0]=-   token[0]=3   token[0]=It   '
#  'token[0]=2   token[0]=to   token[0]=4   token[0]=I   token[0]=he   '
#  'token[0]=AT   token[0]=But   token[0]=was   token[0]=In   token[0]=it   '
#  'token[0]=by   token[0]=his   token[0]=1996-08-28   token[0]=has   '
#  'token[0]=--   token[-1]="   token[0]=.   token[0]=an   token[0]=with   '
#  'token[0]=who')
#
# ------
#
# Most important features *for* label B-ORG:
# ('token[0]=Reuters   token[-1]=v   token[1]=Newsroom   token[-1]=0   '
#  'token[0]=U.N.   token[0]=Ajax   token[-1]=told   first-letter-capitalized   '
#  'token[-1]=1   token[1]=v   token[0]=St   token[-1]=3   token[0]=EU   '
#  'token[-1]=2   token[3]=0   token[1]=0   token[0]=PSV   token[-1]=the   '
#  'token[0]=OSCE   token[0]=NATO   token[1]=Union   token[0]=CHICAGO   '
#  'token[3]=1   token[1]=YORK   token[-3]=v   token[1]=Corp   token[0]=SAN   '
#  'token[0]=PUK   token[0]=Interfax   token[1]=YR')
#
# Most important features *against* label B-ORG:
# ('token[0]=0   token[0]=2   token[0]=1   token[0]=He   token[0]=3   '
#  'token[0]=a   token[0]="   token[0]=It   token[0]=4   token[0]=-   '
#  'token[0]=I   token[0]=said   token[0]=to   token[0]=AT   token[0]=A   '
#  'token[0]=But   token[0]=The   token[0]=was   token[0]=he   token[0]=.   '
#  'token[0]=his   token[0]=who   token[0]=1996-08-28   token[0]=an   '
#  'token[0]=Minister   token[0]=it   token[0]=--   token[0]=5   token[0]=We   '
#  'token[0]=by')
#
# ------
#
# Most important features *for* label I-ORG:
# ('token[0]=Newsroom   token[0]=Inc   token[0]=YORK   token[-1]=St   '
#  'token[-1]=New   token[0]=Corp   token[-1]=NEW   token[0]=Party   '
#  'token[-1]=SAN   token[0]=Bank   token[0]=Co   token[1]=Inc   '
#  'token[-1]=South   token[-1]=National   token[0]=Union   token[0]=York   '
#  'token[1]=0   token[1]=Co   token[0]=Commission   token[-1]=West   '
#  'token[1]=3   token[-1]=United   token[0]=Ltd   token[0]=CITY   '
#  'token[-1]=San   token[1]=4   token[-1]=Hong   token[0]=Kong   '
#  'token[0]=Exchange   token[-1]=LOS')
#
# Most important features *against* label I-ORG:
# ('token[0]=0   token[0]=3   token[0]=2   token[0]=The   token[0]=a   '
#  'token[0]="   token[0]=-   token[0]=said   token[0]=He   token[0]=4   '
#  'token[0]=to   token[0]=It   token[0]=I   token[0]=1   token[0]=was   '
#  'token[0]=AT   token[0]=But   token[0]=he   token[0]=by   '
#  'token[0]=1996-08-28   token[0]=his   token[0]=has   token[0]=LONDON   '
#  'token[0]=--   token[-1]=in   token[0]=with   token[0]=it   token[0]=who   '
#  'token[0]=an   token[0]=In')
#
# ------
#
# Most important features *for* label B-LOC:
# ('token[0]=Britain   token[0]=England   token[0]=Germany   token[0]=U.S.   '
#  'token[0]=China   token[0]=Pakistan   token[1]=1996-08-27   '
#  'token[1]=1996-08-23   token[0]=Russia   token[0]=Italy   '
#  'token[1]=1996-08-28   token[0]=Iraq   token[1]=1996-08-29   '
#  'token[0]=LONDON   token[0]=Australia   token[0]=France   '
#  'token[1]=1996-08-26   token[1]=1996-08-22   token[1]=newsroom   '
#  'token[0]=Israel   token[0]=Sweden   token[1]=1996-08-25   token[0]=India   '
#  'token[1]=1996-08-24   token[0]=Belgium   token[0]=Japan   token[0]=Spain   '
#  'token[-1]=AT   token[-1]=At   token[1]=States')
#
# Most important features *against* label B-LOC:
# ('token[0]=He   token[0]=It   token[0]=a   token[0]=0   token[0]="   '
#  'token[0]=I   token[0]=2   token[0]=AT   token[0]=-   token[0]=said   '
#  'token[0]=But   token[0]=3   token[0]=4   token[0]=to   token[0]=A   '
#  'token[0]=In   token[0]=he   token[0]=.   token[0]=1   token[0]=1996-08-28   '
#  'token[0]=We   token[0]=his   token[0]=July   token[0]=Minister   '
#  'token[0]=was   token[0]=They   token[0]=it   token[0]=who   token[0]=an   '
#  'token[0]=Wednesday')
#
# ------
#
# Most important features *for* label I-LOC:
# ('token[-1]=New   token[-1]=South   token[0]=YORK   token[-1]=NEW   '
#  'token[0]=Africa   token[0]=States   token[0]=Kong   token[0]=Republic   '
#  'token[-1]=West   token[-1]=Hong   token[-1]=Sri   token[-1]=United   '
#  'token[0]=Lanka   token[-1]=Czech   token[0]=Zealand   token[0]=York   '
#  'token[-1]=SAN   token[0]=Cup   token[0]=Bank   token[-1]=Costa   '
#  'token[-1]=St   token[0]=City   token[0]=Inc   token[-1]=San   '
#  'token[0]=Rica   token[-1]=National   token[0]=CITY   token[-2]=AT   '
#  'token[0]=Newsroom   token[-2]=the')
#
# Most important features *against* label I-LOC:
# ('token[0]=He   token[0]=0   token[0]=a   token[0]="   token[0]=The   '
#  'token[0]=It   token[0]=said   token[0]=3   token[0]=2   token[0]=-   '
#  'token[0]=to   token[0]=4   token[0]=I   token[0]=AT   token[0]=But   '
#  'token[0]=was   token[0]=In   token[0]=he   token[0]=1996-08-28   '
#  'token[0]=his   token[0]=--   token[0]=it   token[0]=has   token[0]=an   '
#  'token[0]=Minister   token[0]=by   token[0]=who   token[0]=.   token[0]=We   '
#  'token[0]=with')
#
# ------
#
# Most important features *for* label B-MISC:
# ('token[0]=Russian   token[0]=German   token[0]=British   token[0]=Israeli   '
#  'token[0]=Australian   token[0]=French   token[0]=GMT   token[1]=Open   '
#  'token[0]=Dutch   token[0]=English   token[0]=Iraqi   token[0]=American   '
#  'token[0]=Olympic   token[0]=Japanese   token[1]=Cup   token[0]=European   '
#  'token[1]=LEAGUE   token[0]=Italian   token[0]=Bosnian   token[1]=League   '
#  'token[0]=Palestinian   token[0]=Moslem   token[2]=DIVISION   '
#  'token[0]=Chinese   token[0]=Belgian   token[1]=DIVISION   token[0]=Iranian   '
#  'token[0]=Cup   token[0]=Swiss   token[0]=Turkish')
#
# Most important features *against* label B-MISC:
# ('token[0]=He   token[0]=0   token[0]=a   token[0]="   token[0]=It   '
#  'token[0]=The   token[0]=2   token[0]=-   token[0]=I   token[0]=said   '
#  'token[0]=to   token[0]=3   token[0]=4   token[0]=AT   token[0]=But   '
#  'token[0]=was   token[0]=he   token[0]=his   token[0]=1996-08-28   '
#  'token[0]=.   token[0]=In   token[0]=who   token[0]=it   token[0]=an   '
#  'token[0]=We   token[0]=--   token[0]=A   token[0]=Minister   token[0]=1   '
#  'token[0]=has')
#
# ------
#
# Most important features *for* label I-MISC:
# ('token[0]=Cup   token[-1]=South   token[0]=Open   token[0]=League   '
#  'token[-1]=World   token[-1]=New   token[-1]=Sri   token[0]=DIVISION   '
#  'token[0]=African   token[-1]=West   token[-1]=Grand   token[-1]=NEW   '
#  'token[0]=YORK   token[0]=OPEN   token[1]=Cup   token[-2]=the   '
#  'token[0]=CUP   token[0]=Kong   token[-1]=National   token[-1]=Hong   '
#  'token[0]=LEAGUE   token[0]=German   token[0]=Africa   token[-1]=WESTERN   '
#  'token[-2]=AT   token[-1]=CENTRAL   token[-1]=Costa   token[-1]=St   '
#  'token[0]=Russian   token[0]=Republic')
#
# Most important features *against* label I-MISC:
# ('token[0]=The   token[0]=He   token[0]=said   token[0]=a   token[0]="   '
#  'token[0]=It   token[0]=-   token[-1]=1   token[0]=0   token[-1]=,   '
#  'token[-1]=0   token[0]=to   token[0]=3   token[-1]=3   token[0]=I   '
#  'token[0]=4   token[0]=AT   token[0]=2   token[-1]=2   token[0]=But   '
#  'token[0]=was   token[0]=In   token[0]=1996-08-28   token[0]=he   '
#  'token[-1]=(   token[-1]=--   token[0]=his   token[0]=--   token[1]=AT   '
#  'token[0]=Reuters')
#
# ------
