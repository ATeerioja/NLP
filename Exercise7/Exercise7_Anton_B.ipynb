# %% [markdown]
# # Sequence labeling (POS tagging) with MLP
#
# This notebook builds upon the [classification with MLP notebook](https://github.com/TurkuNLP/intro-to-nlp/blob/master/mlp_imdb_hf_dset_and_trainer.ipynb) and shows how to implement a basic sequence labeling method.

# %% [markdown]
# ---
#
# # Setup
#
# Install the required Python packages using [pip](https://en.wikipedia.org/wiki/Pip):
#
# * [`transformers`](https://huggingface.co/docs/transformers/index) is a popular deep learning package primarily on top of torch
# * [`datasets`](https://huggingface.co/docs/datasets/) provides support for loading, creating, and manipulating datasets
# * [`evaluate`](https://huggingface.co/docs/evaluate/index) is a library of performance metrics (like accuracy etc)

# %%
# !pip3 install --upgrade transformers[torch]
# !pip3 install -q evaluate
# Out:
# WARNING: Ignoring invalid distribution ~ransformers (/home/anton/venv/Data-Analysis/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/home/anton/venv/Data-Analysis/lib/python3.12/site-packages)
# Requirement already satisfied: transformers[torch] in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (5.5.4)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (1.7.2)
# Requirement already satisfied: numpy>=1.17 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (0.22.2)
# Requirement already satisfied: typer in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (4.67.3)
# Requirement already satisfied: torch>=2.4 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (2.10.0+cu126)
# Requirement already satisfied: accelerate>=1.1.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (1.13.0)
# Requirement already satisfied: filelock>=3.10.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (2026.1.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (4.15.0)
# Requirement already satisfied: anyio in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (4.12.1)
# Requirement already satisfied: certifi in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.0.9)
# Requirement already satisfied: idna in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.16.0)
# Requirement already satisfied: psutil in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from accelerate>=1.1.0->transformers[torch]) (7.2.2)
# Requirement already satisfied: setuptools in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (3.6.1)
# Requirement already satisfied: jinja2 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (1.11.1.6)
# Requirement already satisfied: triton==3.6.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from cuda-bindings==12.9.4->torch>=2.4->transformers[torch]) (1.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.4->transformers[torch]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from jinja2->torch>=2.4->transformers[torch]) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from typer->transformers[torch]) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from typer->transformers[torch]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from typer->transformers[torch]) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from typer->transformers[torch]) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from rich>=12.3.0->typer->transformers[torch]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from rich>=12.3.0->typer->transformers[torch]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers[torch]) (0.1.2)
# WARNING: Ignoring invalid distribution ~ransformers (/home/anton/venv/Data-Analysis/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/home/anton/venv/Data-Analysis/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/home/anton/venv/Data-Analysis/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/home/anton/venv/Data-Analysis/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/home/anton/venv/Data-Analysis/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/home/anton/venv/Data-Analysis/lib/python3.12/site-packages)

# %%
import datasets
import evaluate
import transformers

# %% [markdown]
# ---
#
# # Get and prepare data
#
# *   Let us work with the venerable, if somewhat dated [CoNLL'03 shared task](https://aclanthology.org/W03-0419.pdf) English data
# *   These are English news articles, and have annotation for POS, syntactic chunks, and named entities (in the IOB format)
#
# The data as originally distributed for the 2003 shared task has the following format:
#
# ```
# Only RB B-NP O
# France NNP I-NP B-LOC
# and CC I-NP O
# Britain NNP I-NP B-LOC
# backed VBD B-VP O
# Fischler NNP B-NP B-PER
# 's POS I-NP O
# proposal NN I-NP O
# . . O O
# ```
#
# Here, the four space-separated columns are token text, POS tag, chunk tag, and NER tag. The goal of the original task is to predict the NER tags using the other information as features, but the dataset can be used to study predicting the other columns too.
#
# The dataset happens to be in the HF datasets collection, so we can grab it from there

# %%
import torch
import transformers
import datasets

from pprint import pprint    # pretty-print

dataset = datasets.load_dataset("dany0407/conll2003")

print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 14041
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3250
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3453
#     })
# })

# %%
pprint(dataset["train"][12])
# Out:
# {'chunk_tags': [11, 12, 12, 12, 21, 11, 11, 12, 0],
#  'id': '12',
#  'ner_tags': [0, 5, 0, 5, 0, 1, 0, 0, 0],
#  'pos_tags': [30, 22, 10, 22, 38, 22, 27, 21, 7],
#  'tokens': ['Only',
#             'France',
#             'and',
#             'Britain',
#             'backed',
#             'Fischler',
#             "'s",
#             'proposal',
#             '.']}

# %% [markdown]
# As you can see above, the various labels (POS, NER and chunk tags) are converted into IDs in this dataset. We can access the textual labels of these tags through the dataset `features`:

# %%
POS_TAG_NAMES = dataset['train'].features['pos_tags'].feature.names
NER_TAG_NAMES = dataset['train'].features['ner_tags'].feature.names
CHUNK_TAG_NAMES = dataset['train'].features['chunk_tags'].feature.names

# %% [markdown]
# We can then create mappings from names to IDs and back as Python dictionaries:

# %%
POS2ID = { n: i for i, n in enumerate(POS_TAG_NAMES) }
ID2POS = { i: n for i, n in enumerate(POS_TAG_NAMES) }

NER2ID = { n: i for i, n in enumerate(NER_TAG_NAMES) }
ID2NER = { i: n for i, n in enumerate(NER_TAG_NAMES) }

CHUNK2ID = { n: i for i, n in enumerate(CHUNK_TAG_NAMES) }
ID2CHUNK = { i: n for i, n in enumerate(CHUNK_TAG_NAMES) }

# %% [markdown]
# This is what these mappings look like:

# %%
print(NER2ID)
# Out:
# {'O': 0, 'B-PER': 1, 'I-PER': 2, 'B-ORG': 3, 'I-ORG': 4, 'B-LOC': 5, 'I-LOC': 6, 'B-MISC': 7, 'I-MISC': 8}

# %%
print(ID2NER)
# Out:
# {0: 'O', 1: 'B-PER', 2: 'I-PER', 3: 'B-ORG', 4: 'I-ORG', 5: 'B-LOC', 6: 'I-LOC', 7: 'B-MISC', 8: 'I-MISC'}

# %% [markdown]
# Let's also add in explanations from Penn Treebank for the POS tags:

# %%
# From the documentation page and from here https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

POS2DESCRIPTION = {
    "CC": "Coordinating conjunction",
    "CD": "Cardinal number",
    "DT": "Determiner",
    "EX": "Existential there",
    "FW": "Foreign word",
    "IN": "Preposition or subordinating conjunction",
    "JJ": "Adjective",
    "JJR": "Adjective, comparative",
    "JJS": "Adjective, superlative",
    "LS": "List item marker",
    "MD": "Modal",
    "NN": "Noun, singular or mass",
    "NNS": "Noun, plural",
    "NNP": "Proper noun, singular",
    "NNPS": "Proper noun, plural",
    "PDT": "Predeterminer",
    "POS": "Possessive ending",
    "PRP": "Personal pronoun",
    "PRP$": "Possessive pronoun",
    "RB": "Adverb",
    "RBR": "Adverb, comparative",
    "RBS": "Adverb, superlative",
    "RP": "Particle",
    "SYM": "Symbol",
    "TO": "to",
    "UH": "Interjection",
    "VB": "Verb, base form",
    "VBD": "Verb, past tense",
    "VBG": "Verb, gerund or present participle",
    "VBN": "Verb, past participle",
    "VBP": "Verb, non-3rd person singular present",
    "VBZ": "Verb, 3rd person singular present",
    "WDT": "Wh-determiner",
    "WP": "Wh-pronoun",
    "WP$": "Possessive wh-pronoun",
    "WRB": "Wh-adverb"
}

# %% [markdown]
# We can now try to make sense of the tags:

# %%
import tabulate

e = dataset["train"][12]    # work on the same example

table = []
for token, pos_id, chunk_id, ner_id in zip(e["tokens"], e["pos_tags"], e["chunk_tags"], e["ner_tags"]):
    ner_tag = ID2NER[ner_id]
    chunk_tag = ID2CHUNK[chunk_id]
    pos_tag = ID2POS[pos_id]
    pos_def = POS2DESCRIPTION.get(pos_tag,pos_tag)
    table.append([token, ner_tag, chunk_tag, pos_tag, pos_def])

print(tabulate.tabulate(table,headers=["Token", "NER", "Chunk", "POS", "POS definition"]))
# Out:
# Token     NER    Chunk    POS    POS definition
# --------  -----  -------  -----  ------------------------
# Only      O      B-NP     RB     Adverb
# France    B-LOC  I-NP     NNP    Proper noun, singular
# and       O      I-NP     CC     Coordinating conjunction
# Britain   B-LOC  I-NP     NNP    Proper noun, singular
# backed    O      B-VP     VBD    Verb, past tense
# Fischler  B-PER  B-NP     NNP    Proper noun, singular
# 's        O      B-NP     POS    Possessive ending
# proposal  O      I-NP     NN     Noun, singular or mass
# .         O      O        .      .

# %% [markdown]
# Note that the data is organized into sentences.

# %% [markdown]
# ---
#
# # Create features
#
# We'll define a simple function that takes a token sequence, the index of the focus token, and a window size and generates a few basic explicit features relevant to the task.
#
# (Note that as we'll be predicting the POS tag, we won't look at the chunk or NER tags, which would typically only be predicted _after_ predicting POS in a "traditional" NLP pipeline)

# %%
def token_features(pos_tags, tokens, index, window_size):
    # Generate features for token in position `index` in given list of tokens
    features = []

    # Context window start and end
    window_start = max(0, index-window_size)
    window_end = min(index+window_size+1, len(tokens))    # note +1 for range

    for i in range(window_start, window_end):
          offset = i - index    # relative position
          features.append(f"token[{offset}]={tokens[i]}")

    # Example custom feature: does focus token start with an upper-case letter?
    if tokens[index][0].isupper():
        features.append("first-letter-capitalized")

    #Custom feature for NER tagging
    for i in range(window_start, window_end):
         offset = i - index
         features.append(f"pos[{offset}]={ID2POS[pos_tags[i]]}")

    return features

# %% [markdown]
# We can call this function for all tokens in a sentence like so:

# %%
def add_features_to_sentence(sentence):
    # Collect lists of features for all tokens here
    all_features = []

    pos_tags = sentence["pos_tags"]
    tokens = sentence["tokens"]
    for index in range(len(tokens)):
        all_features.append(" ".join(token_features(pos_tags, tokens, index, window_size=3)))

    return { "features": all_features}

# %%
for feats in add_features_to_sentence(dataset["train"][12])["features"]:
    print(feats)
# Out:
# token[0]=Only token[1]=France token[2]=and token[3]=Britain first-letter-capitalized pos[0]=RB pos[1]=NNP pos[2]=CC pos[3]=NNP
# token[-1]=Only token[0]=France token[1]=and token[2]=Britain token[3]=backed first-letter-capitalized pos[-1]=RB pos[0]=NNP pos[1]=CC pos[2]=NNP pos[3]=VBD
# token[-2]=Only token[-1]=France token[0]=and token[1]=Britain token[2]=backed token[3]=Fischler pos[-2]=RB pos[-1]=NNP pos[0]=CC pos[1]=NNP pos[2]=VBD pos[3]=NNP
# token[-3]=Only token[-2]=France token[-1]=and token[0]=Britain token[1]=backed token[2]=Fischler token[3]='s first-letter-capitalized pos[-3]=RB pos[-2]=NNP pos[-1]=CC pos[0]=NNP pos[1]=VBD pos[2]=NNP pos[3]=POS
# token[-3]=France token[-2]=and token[-1]=Britain token[0]=backed token[1]=Fischler token[2]='s token[3]=proposal pos[-3]=NNP pos[-2]=CC pos[-1]=NNP pos[0]=VBD pos[1]=NNP pos[2]=POS pos[3]=NN
# token[-3]=and token[-2]=Britain token[-1]=backed token[0]=Fischler token[1]='s token[2]=proposal token[3]=. first-letter-capitalized pos[-3]=CC pos[-2]=NNP pos[-1]=VBD pos[0]=NNP pos[1]=POS pos[2]=NN pos[3]=.
# token[-3]=Britain token[-2]=backed token[-1]=Fischler token[0]='s token[1]=proposal token[2]=. pos[-3]=NNP pos[-2]=VBD pos[-1]=NNP pos[0]=POS pos[1]=NN pos[2]=.
# token[-3]=backed token[-2]=Fischler token[-1]='s token[0]=proposal token[1]=. pos[-3]=VBD pos[-2]=NNP pos[-1]=POS pos[0]=NN pos[1]=.
# token[-3]=Fischler token[-2]='s token[-1]=proposal token[0]=. pos[-3]=NNP pos[-2]=POS pos[-1]=NN pos[0]=.

# %% [markdown]
# The dataset is organized into sentences, so we can use the above function to add features to the entire dataset as follows.
#
# **Note**: unlike e.g. the Python`map` function, [`Dataset.map`](https://huggingface.co/docs/datasets/package_reference/main_classes.html#datasets.Dataset.map) function _updates_ its argument dataset, keeping existing values.

# %%
dataset = dataset.map(add_features_to_sentence)
# Out:
# Map:   0%|          | 0/14041 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3250 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3453 [00:00<?, ? examples/s]

# %% [markdown]
# Let's check that one more time:

# %%
pprint(dataset["train"][12])
# Out:
# {'chunk_tags': [11, 12, 12, 12, 21, 11, 11, 12, 0],
#  'features': ['token[0]=Only token[1]=France token[2]=and token[3]=Britain '
#               'first-letter-capitalized pos[0]=RB pos[1]=NNP pos[2]=CC '
#               'pos[3]=NNP',
#               'token[-1]=Only token[0]=France token[1]=and token[2]=Britain '
#               'token[3]=backed first-letter-capitalized pos[-1]=RB pos[0]=NNP '
#               'pos[1]=CC pos[2]=NNP pos[3]=VBD',
#               'token[-2]=Only token[-1]=France token[0]=and token[1]=Britain '
#               'token[2]=backed token[3]=Fischler pos[-2]=RB pos[-1]=NNP '
#               'pos[0]=CC pos[1]=NNP pos[2]=VBD pos[3]=NNP',
#               'token[-3]=Only token[-2]=France token[-1]=and token[0]=Britain '
#               "token[1]=backed token[2]=Fischler token[3]='s "
#               'first-letter-capitalized pos[-3]=RB pos[-2]=NNP pos[-1]=CC '
#               'pos[0]=NNP pos[1]=VBD pos[2]=NNP pos[3]=POS',
#               'token[-3]=France token[-2]=and token[-1]=Britain '
#               "token[0]=backed token[1]=Fischler token[2]='s token[3]=proposal "
#               'pos[-3]=NNP pos[-2]=CC pos[-1]=NNP pos[0]=VBD pos[1]=NNP '
#               'pos[2]=POS pos[3]=NN',
#               'token[-3]=and token[-2]=Britain token[-1]=backed '
#               "token[0]=Fischler token[1]='s token[2]=proposal token[3]=. "
#               'first-letter-capitalized pos[-3]=CC pos[-2]=NNP pos[-1]=VBD '
#               'pos[0]=NNP pos[1]=POS pos[2]=NN pos[3]=.',
#               'token[-3]=Britain token[-2]=backed token[-1]=Fischler '
#               "token[0]='s token[1]=proposal token[2]=. pos[-3]=NNP "
#               'pos[-2]=VBD pos[-1]=NNP pos[0]=POS pos[1]=NN pos[2]=.',
#               "token[-3]=backed token[-2]=Fischler token[-1]='s "
#               'token[0]=proposal token[1]=. pos[-3]=VBD pos[-2]=NNP '
#               'pos[-1]=POS pos[0]=NN pos[1]=.',
#               "token[-3]=Fischler token[-2]='s token[-1]=proposal token[0]=. "
#               'pos[-3]=NNP pos[-2]=POS pos[-1]=NN pos[0]=.'],
#  'id': '12',
#  'ner_tags': [0, 5, 0, 5, 0, 1, 0, 0, 0],
#  'pos_tags': [30, 22, 10, 22, 38, 22, 27, 21, 7],
#  'tokens': ['Only',
#             'France',
#             'and',
#             'Britain',
#             'backed',
#             'Fischler',
#             "'s",
#             'proposal',
#             '.']}

# %% [markdown]
# ---
#
# # Flatten dataset
#
# The MLP code that we introduced previously expects each of the `train`, `validation` and `test` subsets of the data to consist of simple sequences of examples.
#
# Now that we have run the feature generation, we no longer need the sentence structure and can "flatten" the data, i.e. remove the "sentence" level of granularity.

# %%
def flatten(subset):
    # Keys for values to flatten
    keys = ["tokens", "pos_tags", "chunk_tags", "ner_tags", "features"]

    # Initialize to empty lists of tokens etc.
    flattened = { k: [] for k in keys }

    # Concatenate per-sentence lists of tokens etc.
    for sentence in subset:
        for key in keys:
            flattened[key].extend(sentence[key])

    # Return as Dataset object
    return datasets.Dataset.from_dict(flattened)

# %% [markdown]
# Call `flatten` for each of the subsets and make a new `DatasetDict` containing the flattened subsets:

# %%
flattened_dict = {
    "train": flatten(dataset["train"]),
    "validation": flatten(dataset["validation"]),
    "test": flatten(dataset["test"]),
}

flat_dataset = datasets.DatasetDict(flattened_dict)

# %% [markdown]
# Check that the new dataset looks OK:

# %%
flat_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'pos_tags', 'chunk_tags', 'ner_tags', 'features'],
#         num_rows: 203621
#     })
#     validation: Dataset({
#         features: ['tokens', 'pos_tags', 'chunk_tags', 'ner_tags', 'features'],
#         num_rows: 51362
#     })
#     test: Dataset({
#         features: ['tokens', 'pos_tags', 'chunk_tags', 'ner_tags', 'features'],
#         num_rows: 46435
#     })
# })

# %%
for i in range(10):
    token = flat_dataset["train"]["tokens"][i]
    pos_tag = ID2POS[flat_dataset["train"]["pos_tags"][i]]
    description = POS2DESCRIPTION.get(pos_tag, pos_tag)
    features = flat_dataset["train"]["features"][i]
    print(f"{token}\t{pos_tag}\t{description}\t{features}")
# Out:
# EU	NNP	Proper noun, singular	token[0]=EU token[1]=rejects token[2]=German token[3]=call first-letter-capitalized pos[0]=NNP pos[1]=VBZ pos[2]=JJ pos[3]=NN
# rejects	VBZ	Verb, 3rd person singular present	token[-1]=EU token[0]=rejects token[1]=German token[2]=call token[3]=to pos[-1]=NNP pos[0]=VBZ pos[1]=JJ pos[2]=NN pos[3]=TO
# German	JJ	Adjective	token[-2]=EU token[-1]=rejects token[0]=German token[1]=call token[2]=to token[3]=boycott first-letter-capitalized pos[-2]=NNP pos[-1]=VBZ pos[0]=JJ pos[1]=NN pos[2]=TO pos[3]=VB
# call	NN	Noun, singular or mass	token[-3]=EU token[-2]=rejects token[-1]=German token[0]=call token[1]=to token[2]=boycott token[3]=British pos[-3]=NNP pos[-2]=VBZ pos[-1]=JJ pos[0]=NN pos[1]=TO pos[2]=VB pos[3]=JJ
# to	TO	to	token[-3]=rejects token[-2]=German token[-1]=call token[0]=to token[1]=boycott token[2]=British token[3]=lamb pos[-3]=VBZ pos[-2]=JJ pos[-1]=NN pos[0]=TO pos[1]=VB pos[2]=JJ pos[3]=NN
# boycott	VB	Verb, base form	token[-3]=German token[-2]=call token[-1]=to token[0]=boycott token[1]=British token[2]=lamb token[3]=. pos[-3]=JJ pos[-2]=NN pos[-1]=TO pos[0]=VB pos[1]=JJ pos[2]=NN pos[3]=.
# British	JJ	Adjective	token[-3]=call token[-2]=to token[-1]=boycott token[0]=British token[1]=lamb token[2]=. first-letter-capitalized pos[-3]=NN pos[-2]=TO pos[-1]=VB pos[0]=JJ pos[1]=NN pos[2]=.
# lamb	NN	Noun, singular or mass	token[-3]=to token[-2]=boycott token[-1]=British token[0]=lamb token[1]=. pos[-3]=TO pos[-2]=VB pos[-1]=JJ pos[0]=NN pos[1]=.
# .	.	.	token[-3]=boycott token[-2]=British token[-1]=lamb token[0]=. pos[-3]=VB pos[-2]=JJ pos[-1]=NN pos[0]=.
# Peter	NNP	Proper noun, singular	token[0]=Peter token[1]=Blackburn first-letter-capitalized pos[0]=NNP pos[1]=NNP

# %% [markdown]
# Note that this is now a single long dataset of tokens without sentence boundaries.

# %% [markdown]
# # Tokenization
#
# Tokenization needs a bit of thinking, so that we can keep things as simple as possible. We need to turn the strings of features into tokens so that we can then plug them into our MLP.
#
# This would be perfectly doable with the standard tokenizer if only we could convince it to simply tokenize on whitespace and leave everything else untouched.
#
# We cannot use the approach from the MLP lecture, because the pretrained tokenizers tend to modify the data in various ways. We need more control, i.e. we need to make our own tokenizer. Luckily, this is easier than it sounds.

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordLevel
from tokenizers.trainers import WordLevelTrainer
from tokenizers.pre_tokenizers import WhitespaceSplit
from transformers import PreTrainedTokenizerFast

def build_whitespace_tokenizer(dataset, vocab_size=None, min_frequency=2):
    tokenizer = Tokenizer(WordLevel(unk_token="[UNK]"))

    # Use pure whitespace splitting, no normalization or subwording
    tokenizer.normalizer = None #This is a step which happens before tokenization, we want nothing done. So setting to None.
    tokenizer.pre_tokenizer = WhitespaceSplit() #This is a pre-tokenization step, we want to strictly only use whitespace.

    # List [PAD] first, so it gets index 0
    special_tokens = ["[PAD]","[UNK]"]

    # WordLevelTrainer builds a word-level tokenizer, i.e. no subwords are used, no BPE algorithm, simply full words
    # Words that do not fit into the vocabulary will be replaced by [UNK], which is fine for our purposes
    trainer = WordLevelTrainer(
        vocab_size=vocab_size,
        min_frequency=min_frequency, #only consider tokens which appear this many times
        special_tokens=special_tokens,
    )
    # This is where the actual training happens
    iterator = (example["features"] for example in dataset)
    tokenizer.train_from_iterator(iterator, trainer=trainer)
    print(tokenizer)

    # And this then turns the tokenizer into something we can use
    hf_tokenizer = PreTrainedTokenizerFast(
        tokenizer_object=tokenizer,

        unk_token="[UNK]",
        pad_token="[PAD]",
    )

    return hf_tokenizer
tokenizer = build_whitespace_tokenizer(flat_dataset["train"], vocab_size=15000)
# Out:
# Tokenizer(version="1.0", truncation=None, padding=None, added_tokens=[{"id":0, "content":"[PAD]", "single_word":False, "lstrip":False, "rstrip":False, ...}, {"id":1, "content":"[UNK]", "single_word":False, "lstrip":False, "rstrip":False, ...}], normalizer=None, pre_tokenizer=WhitespaceSplit(), post_processor=None, decoder=None, model=WordLevel(vocab={"[PAD]":0, "[UNK]":1, "first-letter-capitalized":2, "pos[0]=NNP":3, "pos[-1]=NNP":4, ...}, unk_token="[UNK]"))

# %%
tokenizer.vocab
# Out:
# {'token[0]=warned': 13821,
#  'token[0]=continue': 6098,
#  'token[1]=felt': 9760,
#  'token[-3]=declined': 8492,
#  'token[-3]=general': 3659,
#  'token[3]=will': 609,
#  'token[-1]=France': 1063,
#  'token[-2]=Nigeria': 5025,
#  'token[2]=23': 3510,
#  'token[-3]=weapons': 8522,
#  'token[-1]=growing': 14460,
#  'token[-1]=statement': 1304,
#  'token[-1]=33': 11375,
#  'token[1]=food': 7381,
#  'token[-2]=hits': 3918,
#  'token[-3]=party': 2189,
#  'token[0]=Government': 12674,
#  'token[2]=some': 928,
#  'token[0]=2-0': 4901,
#  'token[3]=mad': 12175,
#  'token[1]=west': 11971,
#  'token[-3]=Turkish': 6610,
#  'token[-3]=State': 5814,
#  'token[0]=Association': 6079,
#  'token[3]=launched': 13113,
#  'pos[-1]=EX': 1003,
#  'token[3]=never': 8288,
#  'token[3]=grand': 11326,
#  'token[0]=..': 14947,
#  'token[-1]=tabulated': 6877,
#  'token[-2]=LOS': 9460,
#  'token[-3]=visited': 9047,
#  'token[-2]=boost': 13405,
#  'token[-2]=Russia': 1929,
#  'token[-1]=One': 5184,
#  'token[2]=moment': 10467,
#  'token[-2]=situation': 10799,
#  'token[2]=IVAC': 14017,
#  'token[2]=city': 2764,
#  'token[0]=Tony': 13716,
#  'token[-2]=president': 1595,
#  'token[-2]=south': 6041,
#  'token[-1]=monitors': 13284,
#  'token[3]=appear': 14205,
#  'token[-2]=named': 6286,
#  'token[2]=set': 1733,
#  'token[-1]=Jason': 10606,
#  'token[0]=neighbouring': 13781,
#  'token[0]=passengers': 5085,
#  'pos[-2]=RBS': 4281,
#  'token[3]=those': 3374,
#  'token[0]=presence': 10308,
#  'pos[3]=POS': 283,
#  'token[-3]=long': 4892,
#  'token[3]=one': 742,
#  'token[-3]=index': 3859,
#  'token[0]=stronger': 12785,
#  'token[0]=And': 11741,
#  'token[1]=+31': 11861,
#  'token[-1]=48': 6506,
#  'token[-1]=Cleveland': 14321,
#  'token[-3]=Pakistan': 2022,
#  'token[2]=Doboj': 12936,
#  'token[2]=Arab': 7416,
#  'token[0]=flew': 13758,
#  'token[-1]=vs.': 2210,
#  'token[-3]=sell': 6631,
#  'token[2]=travel': 11271,
#  'token[1]=Democratic': 3033,
#  'token[1]=province': 7064,
#  'token[-1]=Seles': 12269,
#  'token[1]=504': 11059,
#  'token[1]=port': 9214,
#  'token[-3]=2-6': 13489,
#  'token[-2]=coach': 5214,
#  'token[-3]=flight': 6623,
#  'token[-2]=town': 2502,
#  'token[-3]=HOUSTON': 13514,
#  'token[-3]=having': 6626,
#  'token[-1]=play': 2176,
#  'token[2]=winners': 12097,
#  'token[-1]=played': 1065,
#  'token[-3]=between': 1036,
#  'token[-3]=question': 8511,
#  'token[-3]=Ministry': 4886,
#  'token[2]=problem': 6779,
#  'token[-1]=further': 4697,
#  'token[-1]=Hapoel': 10604,
#  'token[-3]=work': 3935,
#  'token[-1]=Indonesia': 6513,
#  'token[1]=condition': 8168,
#  'token[-1]=software': 12348,
#  'token[-1]=rule': 5547,
#  'token[3]=changed': 12147,
#  'token[3]=EU': 9880,
#  'token[2]=charges': 5490,
#  'token[-2]=Tsang': 12415,
#  'token[0]=light': 10298,
#  'token[1]=stay': 7756,
#  'token[0]=fighting': 3671,
#  'token[-2]=Madrid': 12394,
#  'token[0]=reached': 5861,
#  'token[-3]=little': 4738,
#  'token[3]=Russia': 2007,
#  'token[0]=will': 501,
#  'token[-2]=services': 6928,
#  'token[-2]=violence': 5801,
#  'token[3]=2': 364,
#  'token[2]=fans': 14073,
#  'token[2]=already': 3113,
#  'token[-2]=people': 866,
#  'token[2]=road': 5922,
#  'token[0]=KONG': 9071,
#  'token[-3]=another': 3480,
#  'token[-2]=fact': 9498,
#  'token[-2]=struck': 6042,
#  'token[3]=improved': 14245,
#  'token[0]=chief': 2948,
#  'token[0]=At': 1658,
#  'token[3]=10th': 8244,
#  'token[-1]=run': 2308,
#  'token[-3]=Israel': 2662,
#  'token[3]=how': 5721,
#  'token[-1]=helped': 11453,
#  'token[-2]=Tour': 12414,
#  'token[-1]=violence': 5554,
#  'token[2]=him': 1247,
#  'token[0]=declined': 8102,
#  'token[2]=arms': 8215,
#  'token[-3]=clear': 5818,
#  'token[2]=Teresa': 11210,
#  'token[1]=pay': 5471,
#  'token[1]=hits': 3787,
#  'token[0]=comment': 5848,
#  'token[1]=people': 848,
#  'token[1]=scored': 3792,
#  'token[0]=sixth': 8125,
#  'token[-2]=7': 988,
#  'token[3]=published': 11348,
#  'token[1]=way': 3353,
#  'token[-1]=supply': 10688,
#  'token[-2]=factions': 11566,
#  'token[3]=nearly': 6200,
#  'token[2]=may': 3515,
#  'token[2]=Thomas': 6427,
#  'token[-3]=company': 1178,
#  'token[-2]=Le': 8907,
#  'token[-2]=farm': 8939,
#  'token[-2]=body': 10766,
#  'token[3]=operating': 14263,
#  'token[0]=average': 4339,
#  'token[0]=Albanian': 9620,
#  'token[0]=approved': 10987,
#  'token[-1]=Stuttgart': 13218,
#  'token[-2]=power': 3746,
#  'token[-3]=Kurdish': 4885,
#  'token[0]=Philippoussis': 9080,
#  'token[-1]=issued': 11462,
#  'token[-2]=goals': 4309,
#  'token[1]=go': 2297,
#  'token[-3]=say': 2567,
#  'token[-2]=rights': 4176,
#  'token[0]=Dutch': 2671,
#  'token[1]=Honda': 8148,
#  'token[-2]=board': 8416,
#  'token[0]=arrested': 2947,
#  'token[3]=some': 961,
#  'token[-1]=day': 1393,
#  'token[3]=C': 13044,
#  'token[1]=326': 6703,
#  'token[-2]=dropped': 7589,
#  'token[-2]=AG': 11496,
#  'token[-3]=is': 365,
#  'token[-2]=fight': 10775,
#  'token[-2]=days': 2314,
#  'token[0]=kept': 6106,
#  'token[2]=senior': 6453,
#  'token[0]=Bucharest': 10234,
#  'token[0]=Interior': 14993,
#  'token[2]=promised': 14112,
#  'token[2]=percentage': 6450,
#  'token[2]=investigators': 12060,
#  'token[-3]=be': 469,
#  'token[1]=long-term': 12882,
#  'token[-1]=Interior': 14346,
#  'token[3]=victims': 11364,
#  'token[-3]=fourth': 5249,
#  'token[2]=hold': 4521,
#  'token[3]=million': 694,
#  'token[2]=increased': 8709,
#  'token[0]=centre': 6094,
#  'token[0]=Our': 12691,
#  'token[1]=form': 9198,
#  'token[2]=traffic': 9292,
#  'token[0]=1-0': 3237,
#  'token[-2]=OSCE': 6024,
#  'token[2]=nothing': 11247,
#  'token[2]=secret': 11258,
#  'token[3]=second': 800,
#  'token[1]=ethnic': 7741,
#  'token[2]=bought': 8216,
#  'token[-2]=Afghan': 10707,
#  'token[0]=end': 1900,
#  'token[3]=future': 4277,
#  'token[1]=account': 11906,
#  'token[3]=St': 9891,
#  'token[-1]=1.': 1472,
#  'token[-1]=Crawley': 12227,
#  'token[-2]=Craig': 10718,
#  'token[-2]=guilders': 7979,
#  'token[-3]=deal': 2728,
#  "token[0]='": 954,
#  'token[0]=SEATTLE': 6660,
#  'token[0]=7-1': 13644,
#  'token[-1]=movement': 7540,
#  'token[1]=5': 526,
#  'token[0]=stay': 7704,
#  'token[-3]=cooperation': 10878,
#  'token[-2]=home': 1429,
#  'token[2]=EU': 9795,
#  'token[2]=trading': 3697,
#  'token[-1]=Fortuna': 8316,
#  'token[-2]=country': 2497,
#  'token[-3]=Nations': 5811,
#  'token[0]=information': 11827,
#  'token[0]=Andrea': 10939,
#  'token[2]=Atlanta': 5898,
#  'token[-2]=Dole': 3307,
#  'token[-1]=90': 8789,
#  'token[1]=Newsroom': 2031,
#  'token[0]=Baseball': 9625,
#  'token[-3]=abandoned': 12573,
#  'token[1]=newsroom': 2329,
#  'token[-1]=Nigeria': 4830,
#  'token[2]=customs': 14065,
#  'token[-3]=performance': 12622,
#  'token[-3]=Under': 13541,
#  'token[-3]=yen': 9049,
#  'token[-1]=Information': 9961,
#  'token[0]=less': 6366,
#  'token[0]=Spanish': 11783,
#  'token[-2]=Peter': 6897,
#  'token[3]=1996-08-22': 9871,
#  'token[-2]=member': 8429,
#  'token[3]=against': 761,
#  'token[-2]=as': 372,
#  'token[0]=bit': 12723,
#  'token[0]=Reuters': 1774,
#  'token[0]=WIN': 9089,
#  'token[0]=Leeds': 10248,
#  'token[-2]=Sohail': 8404,
#  'token[-2]=Greg': 12384,
#  'token[0]=subject': 13807,
#  'token[-1]=before': 941,
#  'token[-1]=do': 1264,
#  'token[0]=distribution': 13746,
#  'token[1]=1997': 3677,
#  'token[-2]=Series': 7573,
#  'token[2]=banned': 11223,
#  'token[-1]=Fall': 9955,
#  'token[0]=one': 701,
#  'token[-3]=francs': 8496,
#  'token[1]=young': 7069,
#  'token[-1]=our': 2111,
#  'token[0]=strategic': 12784,
#  'token[-2]=An': 4304,
#  'token[1]=visited': 9230,
#  'token[-3]=Cofinec': 14758,
#  'token[-2]=Red': 7572,
#  'token[-1]=plan': 2709,
#  'token[-1]=White': 4004,
#  'token[3]=Ltd': 5514,
#  'token[1]=dead': 7051,
#  'token[-1]=Jewish': 9963,
#  'token[0]=Sydney': 3670,
#  'token[2]=policy': 5502,
#  'token[2]=health': 7091,
#  'token[3]=central': 3988,
#  "token[-3]='ll": 8002,
#  'token[-2]=immediate': 12453,
#  'token[-2]=bourse': 13407,
#  'token[-3]=very': 2613,
#  'token[2]=newspapers': 12069,
#  'token[-2]=cabinet': 9484,
#  'token[-1]=Eindhoven': 10598,
#  'token[0]=half': 1659,
#  'token[-3]=v': 3093,
#  'token[-2]=NOTE': 10748,
#  'token[3]=telephone': 9932,
#  'token[2]=46': 7409,
#  'token[0]=news': 1634,
#  'token[0]=gave': 2572,
#  'token[2]=rival': 9285,
#  'token[-1]=6-': 12212,
#  'token[-1]=letter': 6003,
#  'token[0]=ordered': 7334,
#  'token[-2]=world': 1476,
#  'token[-3]=tonnes': 1955,
#  'token[2]=traded': 8730,
#  'token[1]=passed': 12889,
#  'token[-1]=half': 1646,
#  'token[2]=PSV': 7781,
#  'token[1]=further': 4777,
#  'token[1]=options': 8179,
#  'token[-2]=said': 269,
#  'token[-3]=West': 2664,
#  'token[-1]=gold': 5754,
#  'token[-3]=needed': 6325,
#  'token[-1]=nation': 6871,
#  'token[3]=stock': 5962,
#  'token[0]=ATHLETICS': 12653,
#  'token[-1]=been': 538,
#  'token[3]=mostly': 11341,
#  'token[2]=leading': 3803,
#  'token[1]=Wayne': 9176,
#  'token[-1]=deputy': 8844,
#  'token[0]=captain': 5272,
#  'token[-3]=War': 10858,
#  'token[1]=47': 8137,
#  'token[2]=attempt': 9257,
#  'token[-1]=officials': 1089,
#  'token[2]=entering': 12045,
#  'pos[-2]=:': 216,
#  'token[0]=He': 776,
#  'token[-1]=Diana': 9953,
#  'token[1]=Sanchez': 8623,
#  'token[-1]=Catholic': 11384,
#  'token[1]=like': 3595,
#  'token[2]=week': 956,
#  'token[1]=nil': 11949,
#  'token[-2]=allowing': 7968,
#  'token[-3]=potential': 14897,
#  'token[-2]=Medvedev': 7954,
#  'token[3]=of': 123,
#  'token[-1]=dealer': 8343,
#  'token[-2]=proposed': 10124,
#  "token[-3]=O'Brien": 14795,
#  'token[1]=anything': 11108,
#  'token[-2]=Israeli': 2998,
#  'token[-3]=things': 10919,
#  'token[3]=Sri': 3814,
#  'token[1]=saw': 8187,
#  'token[2]=completed': 6168,
#  'token[2]=form': 9268,
#  'token[-1]=behind': 3459,
#  'token[-1]=71': 1805,
#  'token[0]=Brown': 10943,
#  'token[-1]=alleged': 13234,
#  'pos[-2]="': 221,
#  'token[-3]=cash': 4191,
#  'token[2]=security': 3442,
#  'token[3]=U.N.': 5154,
#  'token[-1]=51': 8787,
#  'token[3]=law': 5163,
#  'token[-2]=involving': 13443,
#  'token[-2]=additional': 14624,
#  'token[3]=qualifier': 9924,
#  'token[-2]=appointed': 14629,
#  'token[1]=failed': 4233,
#  'token[0]=Blackburn': 13657,
#  'token[-2]=Total': 6568,
#  'token[0]=saw': 8121,
#  'token[3]=WIN': 9308,
#  'token[1]=property': 10389,
#  'token[-2]=More': 8908,
#  'token[2]=political': 2004,
#  'token[2]=approved': 11222,
#  'token[-2]=It': 779,
#  'pos[-3]=NN': 16,
#  'token[0]=2000': 10228,
#  'token[-1]=tax': 7200,
#  'token[-2]=Yellow': 10755,
#  'token[-2]=Malta': 13373,
#  'token[-3]=States': 2860,
#  'token[1]=He': 9717,
#  'token[-2]=major': 3845,
#  'token[-2]=voters': 11609,
#  'token[2]=7': 727,
#  'token[3]=monitors': 14259,
#  'token[-1]=municipal': 7188,
#  'token[0]=city': 2620,
#  'token[-2]=off': 1154,
#  'token[0]=International': 5624,
#  'token[-2]=service': 4877,
#  'token[-1]=separatist': 8871,
#  'token[1]=three': 788,
#  'token[2]=born': 14058,
#  'token[3]=Canada': 4975,
#  'token[-3]=Hospital': 12535,
#  'token[-3]=City': 4606,
#  'token[2]=Ian': 12939,
#  'token[-1]=hospital': 4698,
#  'token[0]=74': 2731,
#  'token[-3]=most': 2058,
#  'token[0]=77': 6340,
#  'token[-2]=Old': 11529,
#  'token[0]=48': 5070,
#  'token[-2]=sanctions': 12477,
#  'token[0]=BONN': 7656,
#  'token[-1]=clashes': 13246,
#  'token[-1]=things': 9433,
#  'token[-2]=purchase': 12469,
#  'token[-2]=community': 9490,
#  'token[3]=filed': 12161,
#  'token[2]=just': 1369,
#  'token[-3]=percent': 696,
#  'pos[0]=RBR': 882,
#  'token[3]=58': 14153,
#  'token[-3]=resume': 13611,
#  'token[3]=road': 5957,
#  'token[-2]=Sudan': 6900,
#  'token[2]=areas': 6165,
#  'token[-2]=test': 3652,
#  'token[-1]=Austrian': 10588,
#  'token[2]=fourth': 4258,
#  'token[-1]=crashed': 14434,
#  'token[0]=small': 5089,
#  'token[-3]=S.': 6052,
#  'token[2]=major': 3805,
#  'token[-2]=become': 7577,
#  'token[-3]=level': 6065,
#  'token[0]=release': 8116,
#  'token[0]=Khartoum': 12682,
#  'token[-2]=battle': 8928,
#  'token[-3]=strong': 4899,
#  'token[0]=place': 2953,
#  'token[-1]=score': 12341,
#  'token[-2]=parties': 6925,
#  'token[1]=reported': 1541,
#  'token[1]=joined': 10376,
#  'token[-3]=rupiah': 12627,
#  'token[0]=past': 3774,
#  'pos[-2]=WP': 422,
#  'token[0]=paper': 6368,
#  'token[-3]=negotiations': 8506,
#  'token[-2]=Irani': 14571,
#  'token[3]=said': 257,
#  'pos[-2]=$': 505,
#  'token[-1]=also': 764,
#  'token[2]=faction': 14072,
#  'token[-3]=Paulo': 8019,
#  'token[-1]=need': 6543,
#  'token[-1]=far': 6866,
#  'token[0]=send': 13799,
#  'token[-3]=far': 7633,
#  'token[1]=champions': 4355,
#  'token[-1]=not': 410,
#  'token[0]=Peter': 4905,
#  'token[0]=/': 735,
#  'token[2]=soccer': 3981,
#  'token[3]=January': 7828,
#  'token[-3]=PSV': 5812,
#  'token[1]=%': 6697,
#  'pos[0]=DT': 29,
#  'token[-2]=join': 10781,
#  'token[-1]=officer': 8360,
#  'token[0]=event': 9676,
#  'token[-1]=Leverkusen': 13197,
#  'token[-1]=goals': 4013,
#  'token[1]=have': 455,
#  'token[-2]=early': 1857,
#  'token[-2]=Stich': 8917,
#  'token[3]=plane': 4987,
#  'token[3]=1-6': 11278,
#  'token[-3]=demanding': 9580,
#  'token[1]=ambassador': 12845,
#  'token[-1]=chance': 6859,
#  'token[-1]=convention': 5541,
#  "token[2]='ve": 11975,
#  'token[1]=ground': 6142,
#  'token[-1]=Khan': 5979,
#  'token[-1]=doing': 8347,
#  'token[2]=Louis': 10420,
#  'token[-3]=Michael': 3088,
#  'token[0]=starts': 10322,
#  'token[2]=17': 3431,
#  'token[0]=penalty': 6369,
#  'token[-3]=scattered': 14912,
#  'token[0]=ball': 8094,
#  'token[2]=Richard': 14033,
#  'token[1]=13': 1190,
#  'token[-2]=could': 969,
#  'token[3]=terms': 10569,
#  'token[-1]=island': 6001,
#  'token[-2]=treaty': 6597,
#  'token[2]=name': 9846,
#  'token[-3]=per': 2399,
#  'token[-1]=Newcastle': 14365,
#  'token[1]=Organisation': 13875,
#  'token[1]=discuss': 7376,
#  'token[3]=PCT': 7832,
#  'token[-3]=league': 3155,
#  'token[-1]=Andre': 13160,
#  'token[0]=plan': 2741,
#  'token[2]=fell': 3437,
#  'pos[0]=CC': 110,
#  'token[-1]=progress': 12334,
#  'token[-1]=Melbourne': 11402,
#  'token[-2]=deal': 2719,
#  'token[0]=Mohammad': 10969,
#  'token[3]=4-0': 14150,
#  'token[3]=visit': 2206,
#  'token[0]=Nicaraguan': 11771,
#  'token[-1]=debate': 11442,
#  'pos[1]=NN': 11,
#  'token[-3]=Richard': 8022,
#  'token[2]=across': 4518,
#  'token[1]="': 233,
#  'token[-2]=Iraq': 2281,
#  'token[3]=dangerous': 12151,
#  'token[2]=unq': 14140,
#  'token[0]=Tuesday': 771,
#  'token[3]=budget': 4680,
#  'token[0]=GERMAN': 9639,
#  'token[-2]=buying': 13409,
#  'token[-3]=draw': 4889,
#  'token[-2]=ordered': 7235,
#  'token[1]=last': 670,
#  'token[2]=eight': 2472,
#  'token[-1]=SYDNEY': 13212,
#  'token[3]=mark': 9334,
#  'token[-2]=Israel': 2547,
#  'token[-3]=published': 10211,
#  'token[-1]=most': 2015,
#  'token[0]=Police': 3573,
#  'token[-2]=set': 1694,
#  'token[0]=Warwickshire': 13722,
#  'token[0]=entering': 11813,
#  'token[-3]=Note': 14794,
#  'token[0]=president': 1465,
#  'token[-2]=Argentine': 10709,
#  'token[3]=live': 12172,
#  'token[3]=hour': 11330,
#  'token[0]=registration': 13792,
#  'token[-3]=Cyprus': 10146,
#  'token[-1]=Denmark': 8314,
#  'token[2]=ceasefire': 4256,
#  'token[1]=Yugoslav': 12841,
#  'token[-2]=ended': 2606,
#  'token[0]=barter': 12722,
#  'token[-2]=spoke': 13470,
#  'token[2]=Lebanon': 11191,
#  'token[-3]=defender': 8493,
#  'token[1]=question': 7753,
#  'token[-2]=private': 5039,
#  'token[-1]=strong': 4577,
#  'token[-1]=rose': 4574,
#  'token[3]=carrying': 7120,
#  'token[2]=drug': 7088,
#  'token[3]=when': 755,
#  'token[-1]=36': 8304,
#  'token[0]=blamed': 9102,
#  'token[3]=really': 9343,
#  'token[1]=wife': 6159,
#  'token[3]=immediately': 5345,
#  'pos[2]=UH': 12204,
#  'token[2]=forced': 5133,
#  'token[-1]=Chris': 7877,
#  'token[-2]=Sierra': 13389,
#  'token[2]=troops': 3982,
#  'token[-3]=said': 271,
#  'token[-2]=150': 14528,
#  'token[3]=80': 14157,
#  'token[3]=farm': 10541,
#  'token[3]=par': 9339,
#  'token[3]=does': 4682,
#  'token[0]=52': 6646,
#  'token[1]=Gaza': 9716,
#  'token[1]=International': 6710,
#  'token[-3]=probably': 8508,
#  'token[-2]=lending': 14684,
#  'token[-1]=men': 3207,
#  'token[1]=Lanka': 3957,
#  'token[-2]=afternoon': 13399,
#  'token[0]=employees': 12740,
#  'token[-3]=your': 9616,
#  'token[3]=recent': 4412,
#  'token[1]=Warsaw': 13890,
#  'token[-3]=showed': 5257,
#  'token[1]=percent': 640,
#  'token[3]=through': 1349,
#  'token[1]=polls': 9213,
#  'token[2]=walk': 12094,
#  'token[1]=King': 12819,
#  'token[3]=continue': 6808,
#  'token[-3]=Sheffield': 12560,
#  'token[3]=material': 14255,
#  'token[-1]=Berlin': 8792,
#  'token[0]=defeat': 7018,
#  'token[-2]=considering': 14647,
#  'token[1]=improve': 13933,
#  'token[-1]=white': 10700,
#  'token[0]=diplomats': 12736,
#  'token[-3]=Jones': 10844,
#  'token[-1]=brief': 14417,
#  'token[0]=religious': 11843,
#  'token[-2]=Hospital': 11516,
#  'token[0]=NEC': 11770,
#  'token[-3]=1992': 9531,
#  'token[3]=many': 3704,
#  'token[2]=feed': 10448,
#  'token[2]=stage': 6783,
#  'token[-3]=sign': 8051,
#  'token[3]=development': 10533,
#  'token[3]=pact': 13123,
#  'token[2]=denotes': 8705,
#  'token[-3]=seven': 2252,
#  'token[-2]=tough': 13480,
#  'token[3]=5.0': 13038,
#  'token[-1]=able': 5987,
#  'token[-1]=aircraft': 8831,
#  'token[0]=Milwaukee': 11768,
#  'token[-3]=/': 992,
#  'token[2]=announced': 3512,
#  'pos[0]=MD': 278,
#  'token[-1]=Slovenia': 14392,
#  'token[0]=Jordanian': 13684,
#  'token[-2]=L': 5208,
#  'token[2]=100': 2036,
#  'token[1]=16': 2746,
#  'token[3]=caught': 9900,
#  'token[1]=truck': 8674,
#  'token[-1]=did': 1276,
#  'token[-1]=firm': 6535,
#  'token[3]=quickly': 14272,
#  'token[3]=CUP': 7825,
#  'token[2]=operating': 14107,
#  'token[-2]=coming': 5568,
#  'token[0]=YR': 9659,
#  'token[0]=blood': 11795,
#  'token[-2]=M.': 3308,
#  'token[-1]=300': 6212,
#  'token[1]=battle': 9185,
#  'pos[3]=VBG': 198,
#  'token[-3]=Waqar': 10857,
#  'token[2]=Burundi': 12928,
#  'token[3]=late': 2835,
#  'token[-3]=joined': 10195,
#  'token[2]=1996-08-23': 7405,
#  'token[1]=Argentina': 5292,
#  'token[0]=while': 1518,
#  'token[3]=kept': 6817,
#  'pos[-1]=DT': 30,
#  'token[3]=west': 12203,
#  'token[3]=20': 1734,
#  'token[-3]=part': 1862,
#  'token[1]=north': 3598,
#  'token[0]=The': 285,
#  'token[-1]=jobs': 14472,
#  'token[3]=living': 14252,
#  'token[1]=point': 5114,
#  'token[1]=disease': 4357,
#  'token[2]=put': 2587,
#  'token[1]=Jose': 8150,
#  'token[1]=prefix': 6153,
#  'token[-1]=Major': 7883,
#  'token[-2]=MINNESOTA': 10742,
#  'token[-2]=grain': 12449,
#  'token[-1]=Singapore': 9977,
#  'token[2]=most': 2130,
#  'token[-1]=soccer': 2112,
#  'token[3]=Diana': 14171,
#  'token[-1]=strike': 3908,
#  'token[1]=singles': 2420,
#  'token[3]=impact': 11332,
#  'token[-1]=leader': 2235,
#  'token[3]=agreed': 3523,
#  'token[0]=passenger': 9690,
#  'token[3]=seventh': 9929,
#  'token[-2]=Women': 2605,
#  'token[-1]=Nantes': 13200,
#  'token[-2]=City': 4585,
#  'token[1]=Games': 11073,
#  'token[0]=protest': 7030,
#  'token[-3]=Tom': 11674,
#  'token[-2]=administration': 10758,
#  'token[0]=keep': 5855,
#  'token[2]=needed': 6775,
#  'token[0]=that': 333,
#  'token[3]=OPEN': 5940,
#  'token[1]=Diana': 12809,
#  'token[2]=father': 14075,
#  'token[1]=slightly': 10399,
#  'token[3]=executive': 6813,
#  'token[-3]=NOTE': 10849,
#  'token[-1]=European': 1589,
#  'token[-2]=is': 360,
#  'token[-1]=Israeli': 2986,
#  'token[2]=--': 1030,
#  'token[-1]=bill': 10639,
#  'token[-1]=working': 4023,
#  'token[3]=assault': 13075,
#  'token[-2]=more': 935,
#  'token[-2]=about': 832,
#  'token[1]=Slovakia': 4642,
#  'token[0]=tennis': 4489,
#  'token[-2]=levels': 6923,
#  'token[0]=flight': 6360,
#  'token[0]=George': 8539,
#  'token[-1]=companies': 5004,
#  'token[3]=56': 11281,
#  'token[2]=recent': 4261,
#  'token[-1]=protests': 10028,
#  'token[1]=8-6': 13834,
#  'token[3]=bottom': 14214,
#  'token[-2]=OB': 14591,
#  'token[1]=moved': 12886,
#  'token[-1]=change': 6226,
#  'token[-3]=seconds': 5256,
#  'token[-1]=crash': 14433,
#  'token[3]=be': 464,
#  'token[-3]=am': 9568,
#  'token[-1]=Russia': 1568,
#  'token[3]=options': 9917,
#  'token[-1]=soldiers': 8374,
#  'token[1]=nuclear': 5887,
#  'token[0]=rugby': 10315,
#  'token[-1]=rounds': 8370,
#  'token[0]=them': 1358,
#  'token[2]=short': 4670,
#  'token[0]=with': 322,
#  'token[1]=change': 6136,
#  'token[-1]=But': 918,
#  'token[-2]=come': 5034,
#  'token[-3]=Swiss': 6951,
#  'token[3]=join': 11334,
#  'token[-2]=1995': 4025,
#  'token[2]=debut': 12981,
#  'token[3]=Sweden': 2301,
#  'token[-3]=committee': 8491,
#  'token[-2]=released': 4721,
#  'token[0]=media': 9688,
#  'token[-3]=announcement': 10865,
#  'token[-2]=campaign': 5032,
#  'token[2]=settlement': 7450,
#  'token[1]=7-5': 2326,
#  'token[0]=45': 6076,
#  'token[1]=comment': 5876,
#  'token[-2]=35': 12364,
#  'token[-2]=stronger': 13471,
#  'token[-2]=Paris': 4162,
#  'token[-2]=Iraqi': 2656,
#  'token[-3]=Open': 2351,
#  'token[-2]=threatening': 13478,
#  'pos[-3]=WP$': 6496,
#  'token[1]=+44': 11052,
#  'token[3]=close': 2535,
#  'token[-2]=interview': 14677,
#  'token[-2]=sentenced': 14709,
#  'token[2]=ahead': 3360,
#  'token[-1]=Second': 9385,
#  'token[3]=South': 1613,
#  'token[2]=today': 5701,
#  'token[-1]=leaders': 2651,
#  'token[0]=monitors': 13779,
#  'token[-2]=Friday': 1265,
#  'token[-2]=UK': 13393,
#  'token[1]=FRANCISCO': 6387,
#  'token[3]=Iraqi': 3812,
#  'token[-1]=Greg': 11391,
#  'token[3]=done': 11320,
#  'token[0]=With': 9092,
#  'token[2]=told': 841,
#  'token[2]=Korea': 14021,
#  'token[1]=caught': 8165,
#  'token[-2]=fired': 11568,
#  'token[2]=battle': 9258,
#  'token[2]=farmers': 9835,
#  'token[2]=champion': 2162,
#  'token[1]=unchanged': 11167,
#  'token[3]=holiday': 5720,
#  'token[-2]=you': 1979,
#  'token[-3]=one': 737,
#  'token[3]=stop': 8775,
#  'token[0]=down': 1160,
#  'token[2]=towns': 14137,
#  'token[-2]=least': 4310,
#  'token[0]=General': 6995,
#  'token[3]=own': 4410,
#  'token[-2]=Ahmed': 4158,
#  'token[-3]=Although': 12514,
#  'token[2]=News': 14027,
#  'token[-1]=sentenced': 14505,
#  'token[0]=Commonwealth': 9634,
#  'token[-3]=then': 2450,
#  'token[-3]=Crawley': 12526,
#  'token[-1]=goal': 6233,
#  'token[2]=flight': 6439,
#  'token[-2]=workers': 5588,
#  'token[2]=Middle': 11192,
#  'token[1]=Algeria': 12799,
#  'token[2]=convention': 5682,
#  'token[-1]=full': 5997,
#  'token[-3]=Angeles': 8464,
#  'token[-1]=stocks': 7199,
#  'token[-1]=alliance': 13235,
#  'token[-3]=even': 6316,
#  'token[1]=Republican': 4776,
#  'token[1]=Sri': 3500,
#  'token[-2]=measures': 9505,
#  'token[0]=Andrei': 12656,
#  'token[1]=spending': 12909,
#  'token[-3]=services': 6981,
#  'token[-1]=operating': 13287,
#  'token[-1]=Inc.': 12243,
#  'token[2]=had': 424,
#  'token[3]=drugs': 7846,
#  'token[-2]=ninth': 6924,
#  'token[-3]=create': 14857,
#  'token[-1]=expressed': 13257,
#  'token[1]=less': 6410,
#  'token[2]=if': 1483,
#  'token[3]=46': 8738,
#  'token[3]=recently': 14276,
#  'pos[-1]="': 217,
#  'token[2]=Russian': 1912,
#  'token[2]=opposed': 14108,
#  'token[-3]=admitted': 10171,
#  'token[3]=analyst': 11310,
#  'token[3]=sets': 12187,
#  'token[2]=start': 2973,
#  'token[0]=Salim': 11777,
#  'token[2]=dead': 7429,
#  'token[3]=Olympic': 4678,
#  'token[1]=drugs': 7377,
#  'token[2]=win': 1553,
#  'token[2]=exports': 5684,
#  'token[-1]=Angeles': 7156,
#  'token[-3]=Alan': 13496,
#  'token[1]=process': 5314,
#  'token[-3]=1991': 8456,
#  'token[-3]=millions': 12616,
#  'token[-3]=join': 10893,
#  'token[-1]=read': 14497,
#  'token[-3]=vouch': 9615,
#  'token[2]=Serbs': 9805,
#  'token[-3]=caught': 9013,
#  'token[-3]=south': 6069,
#  'token[-2]=Spanish': 11542,
#  'token[-1]=unchanged': 10695,
#  'token[0]=Greece': 10956,
#  'token[-2]=presidential': 8437,
#  'token[1]=just': 1295,
#  'token[2]=Yellow': 11214,
#  'token[-1]=cannot': 13244,
#  'token[-1]=born': 13242,
#  'token[-3]=10,000': 13487,
#  'token[-3]=reports': 5255,
#  'token[1]=play': 2197,
#  'token[-3]=add': 14829,
#  'token[-3]=couple': 8032,
#  'token[-1]=Los': 7512,
#  'token[0]=1/2': 1657,
#  'token[3]=over': 697,
#  'token[2]=broke': 6761,
#  'token[-1]=offered': 7921,
#  'token[-1]=tour': 4156,
#  'token[2]=OF': 2822,
#  'token[-3]=got': 5416,
#  'token[3]=Co': 4394,
#  'token[-3]=Gore': 11645,
#  'token[0]=pct': 2575,
#  'token[3]=Chicago': 6463,
#  'token[0]=6.0': 10935,
#  'token[0]=prison': 5450,
#  'token[1]=double': 7739,
#  'token[1]=cow': 12855,
#  'token[0]=hijackers': 7329,
#  'token[1]=Exchange': 5650,
#  'token[-3]=Sampras': 9557,
#  'token[-2]=Brown': 10713,
#  'token[0]=Malta': 10965,
#  'token[1]=target': 11964,
#  'token[0]=Breda': 14965,
#  'token[0]=June': 1601,
#  'token[1]=1991': 6700,
#  'token[-2]=well': 2182,
#  'token[1]=(': 175,
#  'token[-2]=nil': 14694,
#  'token[-2]=support': 2395,
#  'token[-2]=decide': 14652,
#  'token[-2]=Rating': 14601,
#  'token[3]=.': 73,
#  'token[2]=lost': 1565,
#  'token[-1]=epidemic': 14447,
#  'token[1]=Brazilian': 9151,
#  'token[0]=was': 293,
#  'token[1]=threatening': 13982,
#  'token[2]=support': 2432,
#  'token[0]=mixed': 13777,
#  'token[1]=Syria': 11899,
#  'token[-1]=YR': 9394,
#  'token[-3]=information': 11696,
#  'token[-3]=Dealers': 13509,
#  'token[-3]=allegations': 12578,
#  'token[-2]=Pauli': 13378,
#  'token[-2]=sheep': 13467,
#  'token[2]=injury': 7437,
#  'token[-3]=she': 1478,
#  'token[0]=condition': 8101,
#  'token[-2]=show': 12479,
#  'token[3]=streets': 14290,
#  'token[2]=Japan': 1703,
#  'token[0]=Alexander': 6648,
#  'token[0]=Hanwha': 14990,
#  'token[2]=Sampras': 11205,
#  'token[1]=Albanian': 11871,
#  'token[-1]=struck': 5768,
#  'token[3]=analysts': 7465,
#  'token[-1]=account': 11427,
#  'token[-1]=heard': 13268,
#  'token[-3]=EU': 6942,
#  'token[1]=36': 7349,
#  'token[0]=May': 2568,
#  'token[2]=Mullally': 7079,
#  'token[0]=4': 381,
#  'token[-3]=options': 9030,
#  'token[-1]=Poland': 4831,
#  'token[1]=stocks': 7398,
#  'token[-1]=Centre': 13171,
#  'token[-2]=faces': 13431,
#  'token[-3]=Serb': 5595,
#  'token[1]=India': 2520,
#  "token[2]='S": 5896,
#  'token[3]=Khan': 7829,
#  'token[-2]=act': 10757,
#  'token[-1]=Ukraine': 3832,
#  'token[-2]=Moslem': 4713,
#  'token[2]=African': 3604,
#  'token[2]=Commission': 3357,
#  'token[-1]=7': 808,
#  'token[-3]=RTRS': 12555,
#  'token[2]=rupiah': 13014,
#  'token[0]=survey': 9138,
#  'token[-3]=seeking': 10910,
#  'token[2]=30': 1754,
#  'token[-1]=Le': 8809,
#  'token[3]=community': 9901,
#  'token[2]=Jamaica': 14019,
#  'token[-1]=business': 3719,
#  'token[0]=5': 513,
#  'token[-3]=Louis': 10156,
#  'token[-2]=believed': 5388,
#  'token[-2]=level': 5790,
#  'token[-1]=at': 312,
#  'token[2]=currently': 11228,
#  'token[-2]=father': 13432,
#  'token[-2]=shares': 1549,
#  'token[1]=involved': 7746,
#  'token[-2]=A$': 7944,
#  'token[1]=CHICAGO': 12805,
#  'token[-1]=approved': 10636,
#  'token[1]=peace': 1667,
#  'token[0]=violence': 5646,
#  'token[-2]=been': 539,
#  'token[-2]=industrial': 11577,
#  'token[-2]=title': 6044,
#  'token[-2]=has': 393,
#  'token[3]=played': 1673,
#  'token[-2]=provincial': 14699,
#  'token[-2]=Extras': 10725,
#  'token[-1]=fact': 9412,
#  'token[-1]=Warwickshire': 13228,
#  'token[1]=Crawley': 13846,
#  'token[-2]=thing': 12486,
#  'token[-3]=confirmed': 6618,
#  'token[2]=Malta': 14024,
#  'token[-2]=appeared': 8411,
#  'token[-2]=52': 7559,
#  'token[-3]=lack': 13594,
#  'token[0]=cow': 12730,
#  'token[2]=fired': 12048,
#  'token[-1]=Tom': 9983,
#  'token[-3]=Rostock': 14811,
#  'token[-2]=NEC': 11526,
#  'token[3]=26': 3520,
#  'token[-1]=followed': 10003,
#  'token[-2]=governor': 7978,
#  'token[1]=beat': 585,
#  'token[0]=Kansas': 13685,
#  'token[1]=AUGUST': 7353,
#  'token[-3]=Boston': 10143,
#  'token[-3]=because': 1185,
#  'token[3]=commander': 11316,
#  'token[0]=defeated': 11809,
#  'token[-2]=large': 10783,
#  'token[-1]=start': 2847,
#  'token[0]=commission': 8565,
#  'token[-2]=blamed': 8929,
#  'token[3]=third': 1502,
#  'token[2]=unrest': 11273,
#  'token[2]=sixth': 8725,
#  'token[-3]=office': 3664,
#  'token[-2]=television': 3651,
#  'token[0]=scored': 3776,
#  'token[-2]=6.': 2239,
#  'token[-1]=Socialist': 11416,
#  'token[-1]=soldier': 12349,
#  'token[-1]=like': 3539,
#  'token[-3]=their': 638,
#  ...}

# %%
print(flat_dataset["train"][0]["features"])
tokenizer(flat_dataset["train"][0]["features"])
# Out:
# token[0]=EU token[1]=rejects token[2]=German token[3]=call first-letter-capitalized pos[0]=NNP pos[1]=VBZ pos[2]=JJ pos[3]=NN
# {'input_ids': [6343, 1, 2160, 5516, 2, 3, 190, 42, 15], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1, 1]}

# %%
def encode(examples):
    return tokenizer(examples['features'])

dset_tokenized = flat_dataset.map(encode,batched=True,num_proc=4)

for key,val in dset_tokenized["train"][0].items():
    print(key,":",val)
# Out:
# Map (num_proc=4):   0%|          | 0/203621 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/51362 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/46435 [00:00<?, ? examples/s]
# tokens : EU
# pos_tags : 22
# chunk_tags : 11
# ner_tags : 3
# features : token[0]=EU token[1]=rejects token[2]=German token[3]=call first-letter-capitalized pos[0]=NNP pos[1]=VBZ pos[2]=JJ pos[3]=NN
# input_ids : [6343, 1, 2160, 5516, 2, 3, 190, 42, 15]
# attention_mask : [1, 1, 1, 1, 1, 1, 1, 1, 1]

# %% [markdown]
# # Labels
#
# There are three tasks in this dataset (POS, chunks, NER). So we want to choose one of them and create the "labels" key used by the trainer. So let's pick the POS task.

# %%
def assign_labels(ex):
    return {"labels":ex["ner_tags"]}
dset_tokenized=dset_tokenized.map(assign_labels,batched=True)
# Out:
# Map:   0%|          | 0/203621 [00:00<?, ? examples/s]
# Map:   0%|          | 0/51362 [00:00<?, ? examples/s]
# Map:   0%|          | 0/46435 [00:00<?, ? examples/s]

# %%
dset_tokenized["train"][0]
# Out:
# {'tokens': 'EU',
#  'pos_tags': 22,
#  'chunk_tags': 11,
#  'ner_tags': 3,
#  'features': 'token[0]=EU token[1]=rejects token[2]=German token[3]=call first-letter-capitalized pos[0]=NNP pos[1]=VBZ pos[2]=JJ pos[3]=NN',
#  'input_ids': [6343, 1, 2160, 5516, 2, 3, 190, 42, 15],
#  'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1, 1],
#  'labels': 3}

# %% [markdown]
# ---
#
# # MLP model
#
# With the data now ready, we'll build the MLP model. Note that this is _identical_ to the MLP model we used for text classification: the only difference between the two applications is in the data.
#
# The model class in its simplest form has `__init__()` which instantiates the layers and `forward()` which implements the actual computation. For more information on these, please see the [PyTorch turorial](https://pytorch.org/tutorials/beginner/introyt/modelsyt_tutorial.html).

# %%
# A Transformers library model wants a config,
# I can simply inherit from the base
# class for pretrained configs
# We don't really need to do anything very special
class MLPConfig(transformers.PretrainedConfig):
    pass

# This is the model
class MLP(transformers.PreTrainedModel):

    config_class=MLPConfig

    # In the initialization method, one instantiates the layers
    # these will be, for the most part the trained parameters of the model
    def __init__(self,config):
        super().__init__(config)
        self.all_tied_weights_keys = {} #Annoying bug in Transformers, must have this here or else we crash on saved model load
        #### HERE WE CREATE THE MODEL'S LAYERS:
        self.vocab_size=config.vocab_size #embedding matrix row count
        # Build and initialize embedding of vocab size x hidden size
        assert tokenizer.vocab["[PAD]"]==0 #let's make sure our assumption of pad==0 holds!

        self.embedding=torch.nn.Embedding(num_embeddings=self.vocab_size,embedding_dim=config.hidden_size,padding_idx=0)
        # Initialize the embeddings to random values
        # Note! This function is relatively clever and keeps the embedding for 0, the padding, pure zeros
        torch.nn.init.uniform_(self.embedding.weight.data,-0.001,0.001) #initialize the embeddings with small random values

        # This takes care of the lower half of the network, now the upper half
        # Output layer: hidden size x output size
        self.output=torch.nn.Linear(in_features=config.hidden_size,out_features=config.nlabels)
        # Now we have the parameters of the model
        self.loss=torch.nn.CrossEntropyLoss() #This loss is meant for classification, so let's use it


    # The computation of the model is put into the forward() function
    # it receives a batch of data and optionally the correct `labels`
    #
    # If given `labels` it returns (loss,output)
    # if not, then it returns (output,)
    def forward(self,input_ids,labels=None,**kwargs):
        #1) sum up the embeddings of the items
        embedded=self.embedding(input_ids) #(batch,ids)->(batch,ids,embedding_dim)
        # Since the Embedding keeps the first row of the matrix pure zeros, we don't need to worry about the padding
        # so next we sum the embeddings across the word dimension
        # (batch,ids,embedding_dim) -> (batch,embedding_dim)
        embedded_summed=torch.sum(embedded,dim=1)

        #2) apply non-linearity
        # (batch,embedding_dim) -> (batch,embedding_dim)
        projected=torch.tanh(embedded_summed) #Note how non-linearity is applied here and not when configuring the layer in __init__()
        # projected=embedded_summed ## If you need to bypass non-linearity, use this :)
        #3) and now apply the upper, output layer of the network
        # (batch,embedding_dim) -> (batch, num_of_classes i.e. 2 in our case)
        logits=self.output(projected)

        # ...and that's all there is to it!

        #print("input_ids.shape",input_ids.shape)
        #print("embedded.shape",embedded.shape)
        #print("embedded_summed.shape",embedded_summed.shape)
        #print("projected.shape",projected.shape)
        #print("logits.shape",logits.shape)

        # If we have labels, we ought to calculate the loss
        if labels is not None:

            # You run it as loss(model_output,correct_labels)
            return (self.loss(logits,labels),logits) #2-tuple, i.e. pair of values returned
        else:
            # No labels, so just return the logits
            return (logits,) #this weird syntax means 1-tuple

# %% [markdown]
# Configure the model

# %%
num_labels = len(NER2ID)

mlp_config = MLPConfig(
    vocab_size=len(tokenizer.vocab),
    hidden_size=20,
    nlabels=num_labels
)

print("mlp_config:", mlp_config)
# Out:
# mlp_config: MLPConfig {
#   "hidden_size": 20,
#   "nlabels": 9,
#   "transformers_version": "5.5.4",
#   "vocab_size": 15000
# }

# %% [markdown]
# ---
#
# # Train the model
#
# We will use the Hugging Face [Trainer](https://huggingface.co/docs/transformers/main_classes/trainer) class for training
#
# * Loads of arguments that control the training
# * Configurable metrics to evaluate performance
# * Data collator builds the batches
# * Early stopping callback stops when eval loss no longer improves
# * Model load/save
# * Good foundation for later deep learning course

# %% [markdown]
# First, let's create a [`TrainingArguments`](https://huggingface.co/docs/transformers/v4.17.0/en/main_classes/trainer#transformers.TrainingArguments) object to specify hyperparameters and various other settings for training.
#
# Printing this simple dataclass object will show not only the values we set, but also the defaults for all other arguments. Don't worry if you don't understand what all of these do! Many are not relevant to us here, and you can find the details in [`Trainer` documentation](https://huggingface.co/docs/transformers/main_classes/trainer) if you are interested.

# %%
trainer_args = transformers.TrainingArguments(
    "mlp_checkpoints", #save checkpoints here
    eval_strategy="steps",
    logging_strategy="steps",
    eval_steps=1000,
    logging_steps=1000,
    save_steps=1000,
    learning_rate=5e-4, #learning rate of the gradient descent
    max_steps=20000,
    load_best_model_at_end=True,
    per_device_train_batch_size=16
)

pprint(trainer_args)
# Out:
# TrainingArguments(
# accelerator_config={'split_batches': False, 'dispatch_batches': None, 'even_batches': True, 'use_seedable_sampler': True, 'non_blocking': False, 'gradient_accumulation_kwargs': None, 'use_configured_state': False},
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# average_tokens_across_devices=True,
# batch_eval_metrics=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_persistent_workers=False,
# dataloader_pin_memory=True,
# dataloader_prefetch_factor=None,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=False,
# enable_jit_checkpoint=False,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_do_concat_batches=True,
# eval_on_start=False,
# eval_steps=1000,
# eval_strategy=IntervalStrategy.STEPS,
# eval_use_gather_object=False,
# fp16=False,
# fp16_full_eval=False,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_v2': False, 'xla_fsdp_grad_ckpt': False},
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=False,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=None,
# hub_revision=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_for_metrics=[],
# include_num_input_tokens_seen=no,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=0.0005,
# length_column_name=length,
# liger_kernel_config=None,
# load_best_model_at_end=True,
# local_rank=-1,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=None,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=1000,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_kwargs=None,
# lr_scheduler_type=SchedulerType.LINEAR,
# max_grad_norm=1.0,
# max_steps=20000,
# metric_for_best_model=loss,
# neftune_noise_alpha=None,
# num_train_epochs=3.0,
# optim=OptimizerNames.ADAMW_TORCH_FUSED,
# optim_args=None,
# optim_target_modules=None,
# output_dir=mlp_checkpoints,
# parallelism_config=None,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=16,
# prediction_loss_only=False,
# project=huggingface,
# push_to_hub=False,
# remove_unused_columns=True,
# report_to=[],
# restore_callback_states_from_checkpoint=False,
# resume_from_checkpoint=None,
# run_name=None,
# save_on_each_node=False,
# save_only_model=False,
# save_steps=1000,
# save_strategy=SaveStrategy.STEPS,
# save_total_limit=None,
# seed=42,
# skip_memory_metrics=True,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torch_empty_cache_steps=None,
# trackio_space_id=trackio,
# train_sampling_strategy=random,
# use_cache=False,
# use_cpu=False,
# use_liger_kernel=False,
# warmup_ratio=None,
# warmup_steps=0,
# weight_decay=0.0,
# )

# %% [markdown]
# Next, let's create a metric for evaluating performance during and after training. We can use the convenience function [`load_metric`](https://huggingface.co/docs/datasets/about_metrics) to load one of many pre-made metrics and wrap this for use by the trainer.
#
# We can use the basic `accuracy` metric, defined as the proportion of correctly predicted labels out of all labels. This time, though, the data is not evenly split.

# %%
import numpy as np
import evaluate

accuracy = evaluate.load("accuracy")

def compute_accuracy(outputs_and_labels):
    outputs, labels = outputs_and_labels
    predictions = np.argmax(outputs, axis=-1) #pick the index of the "winning" label
    return accuracy.compute(predictions=predictions, references=labels)

# %% [markdown]
# We can then create the `Trainer` and train the model by invoking the [`Trainer.train`](https://huggingface.co/docs/transformers/main_classes/trainer#transformers.Trainer.train) function.
#
# In addition to the model, the settings passed in through the `TrainingArguments` object created above (`trainer_args`), the data, and the metric defined above, we create and pass the following to the `Trainer`:
#
# * [data collator](https://huggingface.co/docs/transformers/main_classes/data_collator): groups input into batches
# * [`EarlyStoppingCallback`](https://huggingface.co/docs/transformers/main_classes/callback#transformers.EarlyStoppingCallback): stops training when performance stops improving

# %%
# Make a new model
mlp = MLP(mlp_config)


# Argument gives the number of steps of patience before early stopping
# i.e. training is stopped when the evaluation loss fails to improve
# certain number of times
early_stopping = transformers.EarlyStoppingCallback(5)

trainer = transformers.Trainer(
    model=mlp,
    args=trainer_args,
    train_dataset=dset_tokenized["train"],
    eval_dataset=dset_tokenized["validation"].select(range(1000)),
    compute_metrics=compute_accuracy,
    data_collator=transformers.DataCollatorWithPadding(tokenizer),
    callbacks=[early_stopping]
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='20000' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20000/20000 01:42, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>0.685405</td>
#       <td>0.629079</td>
#       <td>0.784000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.365696</td>
#       <td>0.519779</td>
#       <td>0.839000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.305782</td>
#       <td>0.453580</td>
#       <td>0.864000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.260840</td>
#       <td>0.406701</td>
#       <td>0.877000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.229526</td>
#       <td>0.371389</td>
#       <td>0.889000</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.218379</td>
#       <td>0.336576</td>
#       <td>0.895000</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.184641</td>
#       <td>0.321637</td>
#       <td>0.894000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.184943</td>
#       <td>0.287097</td>
#       <td>0.900000</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.179080</td>
#       <td>0.272749</td>
#       <td>0.910000</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.163545</td>
#       <td>0.269946</td>
#       <td>0.912000</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.168226</td>
#       <td>0.254044</td>
#       <td>0.911000</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.163488</td>
#       <td>0.244891</td>
#       <td>0.919000</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.149963</td>
#       <td>0.239152</td>
#       <td>0.923000</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.136521</td>
#       <td>0.234175</td>
#       <td>0.922000</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.142752</td>
#       <td>0.229364</td>
#       <td>0.924000</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.133822</td>
#       <td>0.227797</td>
#       <td>0.926000</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.134131</td>
#       <td>0.221976</td>
#       <td>0.927000</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.134886</td>
#       <td>0.218606</td>
#       <td>0.927000</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.126736</td>
#       <td>0.217770</td>
#       <td>0.928000</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.131352</td>
#       <td>0.217287</td>
#       <td>0.928000</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# TrainOutput(global_step=20000, training_loss=0.20998566703796387, metrics={'train_runtime': 102.7314, 'train_samples_per_second': 3114.918, 'train_steps_per_second': 194.682, 'total_flos': 5369469588.0, 'train_loss': 0.20998566703796387, 'epoch': 1.571462245619549})

# %% [markdown]
# The NER tagging accuracy was as high as 93,1%. This indicates a reasonably good tagging performance.

# %% [markdown]
# ---
#
# # What has the model learned?
#
# * The embeddings should have some meaning to them
# * Similar features should have similar embeddings

# %%
# Grab the embedding matrix out of the trained model
# and drop the first row (padding 0)
# then we can treat the embeddings as vectors

weights=mlp.embedding.weight.detach().cpu().numpy()

# %%
import sklearn
qry_idx=tokenizer.vocab["token[0]=in"]
idx2feat={v:k for k,v in tokenizer.vocab.items()}

#calculate the distance of the "in" embedding to all other embeddings
distance_to_qry=sklearn.metrics.pairwise.euclidean_distances(weights[qry_idx:qry_idx+1,:],weights)
nearest_neighbors=np.argsort(distance_to_qry) #indices of words nearest to "in"
for nearest in nearest_neighbors[0,:20]:
    print(idx2feat[nearest])
# Out:
# token[0]=in
# token[0]=(
# pos[0]=(
# pos[-1]=PRP
# token[0]=military
# token[0]=early
# token[0]=Police
# token[0]=statement
# token[0]=good
# token[0]=due
# token[0]=northern
# token[0]=bank
# token[0]=national
# token[0]=previous
# token[0]=few
# token[0]=third
# token[0]=recent
# token[0]=week
# token[0]=political
# token[0]=state

# %% [markdown]
# * The embeddings indeed seem to reflect the task and capture aspects of the meaning of words relevant to the task
# * But now we have many classes, so we should take that into account too
# * We can take the dot-product of the feature embeddings with the output layer weight of the class we care about
# * When you think how the information propagates in the network, this will give us a single number reflecting each feature w.r.t. the selected label
# * Technically speaking, it is the prediction of an example which only has that one feature, with respect to that one class
# * Here is how we can implement it (here we rely on the fact that the model is linear, since we didn't include a nonlinearity earlier in the model's `forward()`

# %%
import numpy

embedding_weights=weights    #shape (features, embedding-dim)
output_weights=mlp.output.weight.detach().cpu().numpy()    #shape (num-labels, embedding-dim)

# We just matrix-multiply these together, since this gives us all the dot-products
weights_by_label=numpy.matmul(numpy.tanh(embedding_weights), output_weights.T)
weights_by_label.shape
# Out:
# (15000, 9)

# %%
def get_most_important_features_for_and_against(label):
    label_idx = NER2ID[label]
    feature_weights = weights_by_label[:,label_idx] #pick the column that interests us

    #The shape of feature_weights is (feature_vocab_size,) i.e. it is a vector
    features_weight_idx = numpy.argsort(-feature_weights) #sort in descending order, this will be vector of indices
    features_for = [idx2feat[feature_idx] for feature_idx in features_weight_idx[:30]]
    features_against = [idx2feat[feature_idx] for feature_idx in features_weight_idx[-30:][::-1]]
    return features_for, features_against

for label in (NER_TAG_NAMES):
    dt_plus,dt_minus=get_most_important_features_for_and_against(label)
    print(f"Most important features *for* label {label}:")
    pprint("   ".join(dt_plus))
    print()
    print(f"Most important features *against* label {label}:")
    pprint("   ".join(dt_minus))
    print("\n------\n")
# Out:
# Most important features *for* label O:
# ('token[0]=0   token[0]=to   token[0]=a   token[0]=AT   pos[0]=PRP   '
#  'token[0]=said   token[0]=which   token[0]=2   token[0]=$   pos[0]="   '
#  'token[0]="   token[0]=He   token[0]=Tuesday   token[0]=Thursday   '
#  'pos[0]=PRP$   token[0]=4   token[0]=who   token[0]=Monday   token[0]=July   '
#  'token[0]=President   token[0]=Minister   token[0]=Wednesday   pos[0]=:   '
#  'token[0]=It   token[0]=was   token[0]=June   token[0]=has   token[0]=3   '
#  'token[0]=.   token[0]=first')
#
# Most important features *against* label O:
# ('first-letter-capitalized   token[0]=de   token[0]=&   token[0]=German   '
#  'token[0]=Russian   token[0]=U.S.   token[0]=British   token[0]=French   '
#  'token[0]=Israeli   token[0]=Palestinian   token[0]=Iraqi   token[-1]=beat   '
#  'token[0]=European   token[3]=0   token[-1]=At   token[-1]=Lloyd   '
#  'token[0]=Dutch   token[1]=Oval   token[0]=RTRS   token[-1]=RUGBY   '
#  'token[0]=1,000   token[1]=Co   token[-1]=New   token[0]=Olympic   '
#  'token[0]=South   token[-1]=CDU   token[-1]=South   token[0]=Britain   '
#  'token[0]=Clinton   token[0]=Iraq')
#
# ------
#
# Most important features *for* label B-PER:
# ('token[-1]=President   token[-1]=Minister   token[0]=Clinton   token[-1]=b   '
#  'token[-1]=2.   token[-1]=3.   token[0]=Mark   token[-1]=6.   token[0]=M.   '
#  'token[-1]=1.   token[0]=John   token[0]=Michael   token[2]=c   '
#  'token[-1]=5.   token[0]=Yeltsin   token[0]=Paul   token[-1]=c   '
#  'token[0]=A.   token[0]=David   token[0]=Arafat   token[1]=Ahmed   '
#  'token[0]=Dole   token[-2]=Prime   token[0]=Dutroux   token[0]=Lebed   '
#  'token[-1]=champion   token[3]=France   token[-1]=4.   token[-1]=7.   '
#  'token[0]=Peter')
#
# Most important features *against* label B-PER:
# ('pos[0]=PRP   token[0]=to   token[0]=who   token[0]=which   token[0]="   '
#  'token[0]=AT   pos[0]="   token[0]=a   token[0]=0   token[0]=He   pos[0]=:   '
#  'token[0]=Thursday   token[0]=It   token[0]=Wednesday   token[0]=President   '
#  'token[0]=$   token[0]=Tuesday   token[0]=Monday   pos[0]=PRP$   '
#  'token[0]=was   token[0]=.   pos[0]=IN   token[0]=Minister   token[0]=July   '
#  'pos[1]=NNS   pos[0]=.   token[0]=has   token[0]=said   token[0]=that   '
#  'token[0]=he')
#
# ------
#
# Most important features *for* label I-PER:
# ('token[-2]=President   pos[-1]=NNP   token[-2]=Minister   token[-1]=M.   '
#  'token[-1]=Mark   token[-1]=John   token[2]=Spain   token[-1]=Paul   '
#  'token[-1]=Michael   token[0]=Ahmed   token[-3]=Prime   token[-2]=2.   '
#  'token[0]=Akram   token[-1]=A.   token[-2]=1.   token[-1]=David   '
#  'token[-2]=vs.   token[1]=through   token[1]=c   token[-1]=Peter   '
#  'token[3]=Newsroom   token[-2]=3.   token[-1]=Bill   token[-2]=champion   '
#  'token[-1]=Waqar   token[-1]=G.   token[-1]=Alexander   token[-2]=beat   '
#  'token[-1]=Steve   token[-1]=Wasim')
#
# Most important features *against* label I-PER:
# ('pos[0]=PRP   pos[0]=CD   token[0]=said   token[0]=AT   token[0]=0   '
#  'token[0]=to   token[0]=DIVISION   token[0]=3   token[0]=has   pos[0]=NNS   '
#  'token[0]=2   token[0]=4   token[0]=a   token[0]=was   token[0]=.   '
#  'pos[0]="   token[0]=Minister   token[0]="   token[0]=which   '
#  'token[0]=1996-08-28   pos[1]=NNP   pos[0]=VBD   token[0]=The   pos[0]=PRP$   '
#  'pos[0]=.   token[0]=He   token[0]=Monday   token[0]=$   token[0]=Tuesday   '
#  'pos[1]=NNS')
#
# ------
#
# Most important features *for* label B-ORG:
# ('token[0]=Reuters   token[-1]=v   token[1]=Newsroom   token[-1]=0   '
#  'token[0]=U.N.   token[-1]=told   first-letter-capitalized   token[1]=0   '
#  'token[-1]=1   token[1]=v   token[0]=Ajax   token[-1]=3   token[-1]=2   '
#  'token[3]=1   token[0]=St   token[0]=NATO   token[1]=Corp   token[3]=v   '
#  'token[0]=PSV   token[0]=PUK   token[3]=0   token[0]=EU   token[-3]=v   '
#  'token[1]=3   token[1]=2   token[1]=Union   token[0]=OSCE   token[2]=0   '
#  'token[1]=AT   token[2]=21')
#
# Most important features *against* label B-ORG:
# ('pos[-1]=NNP   token[0]=0   token[0]=1   token[0]=to   token[0]=2   '
#  'token[0]=a   pos[0]=:   token[0]=$   token[0]=which   token[0]=beat   '
#  'pos[0]="   token[0]="   token[0]=4   token[0]=AT   token[0]=He   '
#  'token[0]=who   token[0]=President   token[0]=Thursday   token[0]=It   '
#  'token[0]=Tuesday   pos[0]=PRP$   token[0]=July   pos[0]=CD   token[0]=3   '
#  'token[0]=Monday   token[0]=Wednesday   token[0]=September   '
#  'token[0]=government   token[0]=June   token[0]=said')
#
# ------
#
# Most important features *for* label I-ORG:
# ('token[0]=Inc   pos[-1]=NNP   token[0]=Newsroom   token[0]=Corp   '
#  'token[-1]=St   token[0]=Co   token[0]=Party   token[1]=0   token[1]=Inc   '
#  'token[0]=YORK   token[0]=Union   token[1]=4   token[1]=3   token[-1]=NEW   '
#  'token[0]=Commission   pos[-1]=NNPS   token[1]=Co   token[0]=of   '
#  'token[1]=Commission   token[-1]=New   token[-1]=&   token[-1]=SAN   '
#  'token[2]=0   token[1]=2   token[0]=Ltd   token[0]=Bank   token[3]=0   '
#  'token[-1]=National   token[1]=Ltd   token[0]=Exchange')
#
# Most important features *against* label I-ORG:
# ('token[0]=0   token[-1]=AT   token[0]=3   token[0]=2   token[0]=said   '
#  'token[0]=4   token[0]=to   token[0]=AT   pos[0]=CD   token[0]=1   '
#  'token[0]=was   token[0]=a   token[0]=has   pos[0]=PRP   token[0]=Minister   '
#  'token[0]=The   token[0]=LONDON   token[0]=1996-08-28   token[0]=which   '
#  'token[0]="   pos[0]="   pos[0]=VBD   token[0]=Britain   token[0]=He   '
#  'pos[0]=:   token[0]=$   token[0]=from   pos[0]=PRP$   pos[0]=VBN   '
#  'token[0]=But')
#
# ------
#
# Most important features *for* label B-LOC:
# ('token[0]=Britain   token[0]=England   token[-1]=AT   token[0]=Germany   '
#  'token[1]=1996-08-28   token[0]=U.S.   token[0]=Pakistan   '
#  'token[1]=1996-08-27   token[1]=1996-08-26   token[0]=China   '
#  'token[1]=1996-08-29   token[0]=Italy   token[1]=1996-08-23   '
#  'token[1]=1996-08-22   token[0]=Iraq   token[0]=Russia   token[0]=Australia   '
#  'token[1]=1996-08-25   token[0]=LONDON   token[0]=France   '
#  'token[1]=1996-08-24   token[0]=Belgium   token[0]=Israel   '
#  'token[1]=newsroom   token[0]=Sweden   token[0]=Spain   token[0]=Japan   '
#  'token[1]=States   token[0]=India   token[-1]=At')
#
# Most important features *against* label B-LOC:
# ('token[0]=a   token[0]=to   token[0]=AT   token[0]=Wednesday   '
#  'token[0]=July   token[0]=Tuesday   token[0]=Thursday   token[0]=which   '
#  'token[0]=$   token[0]=June   token[0]=Monday   pos[0]=PRP   token[0]=0   '
#  'pos[-1]=NNP   token[0]=President   pos[0]=PRP$   token[0]=He   '
#  'token[0]=Sunday   token[0]=September   token[0]=Friday   pos[0]=:   '
#  'token[0]=who   token[0]=It   token[0]=August   token[0]="   pos[0]="   '
#  'token[0]=Minister   token[0]=But   token[0]=first   token[0]=government')
#
# ------
#
# Most important features *for* label I-LOC:
# ('token[-1]=South   token[-1]=New   token[0]=YORK   pos[-1]=NNP   '
#  'token[-1]=NEW   token[0]=Africa   token[0]=States   token[-1]=West   '
#  'token[-1]=Hong   token[0]=Kong   token[0]=Republic   token[0]=Lanka   '
#  'token[-1]=United   token[-1]=Sri   token[-1]=Czech   token[0]=Zealand   '
#  'token[-1]=Costa   token[-1]=SAN   token[0]=York   token[0]=African   '
#  'token[-1]=San   token[0]=City   token[-2]=AT   token[0]=CITY   '
#  'token[0]=Rica   token[1]=1996-08-28   token[1]=1996-08-26   token[0]=of   '
#  'token[0]=Bank   token[-2]=at')
#
# Most important features *against* label I-LOC:
# ('token[0]=said   pos[0]=PRP   token[0]=to   token[0]=0   token[0]=AT   '
#  'token[0]=a   token[0]=3   token[0]=2   token[0]=4   token[0]=Minister   '
#  'token[0]=which   token[0]=was   token[0]=has   token[0]=$   pos[0]=PRP$   '
#  'token[0]=Tuesday   token[0]="   pos[0]="   token[0]=1996-08-28   '
#  'token[0]=Monday   token[0]=Thursday   token[0]=July   token[0]=He   '
#  'token[0]=But   token[0]=first   pos[0]=CD   token[0]=June   '
#  'token[0]=President   token[0]=.   token[0]=who')
#
# ------
#
# Most important features *for* label B-MISC:
# ('token[0]=Russian   token[0]=German   token[0]=GMT   pos[0]=$   '
#  'token[0]=Australian   token[1]=Open   token[1]=Cup   token[0]=British   '
#  'token[0]=French   token[0]=American   token[0]=Israeli   '
#  'first-letter-capitalized   token[1]=LEAGUE   token[1]=League   '
#  'token[0]=English   token[0]=Moslem   token[0]=Bosnian   token[0]=Iraqi   '
#  'token[0]=Olympic   token[2]=DIVISION   token[0]=Dutch   token[0]=Italian   '
#  'token[0]=European   token[0]=Cup   token[0]=Japanese   '
#  'token[0]=Palestinian   token[0]=Sudanese   token[0]=Chinese   '
#  'token[0]=Serb   token[0]=Iranian')
#
# Most important features *against* label B-MISC:
# ('token[0]=a   token[0]=to   token[0]=first   token[0]=0   token[0]=$   '
#  'token[0]=second   pos[0]="   token[0]="   token[0]=AT   token[0]=which   '
#  'pos[0]=PRP$   pos[0]=PRP   token[0]=last   token[0]=said   token[0]=He   '
#  'token[0]=Tuesday   token[0]=Thursday   token[0]=Wednesday   token[0]=who   '
#  'token[0]=was   token[0]=government   token[0]=It   token[0]=his   '
#  'token[0]=.   token[0]=Monday   token[0]=July   token[0]=President   '
#  'token[0]=an   token[0]=new   token[0]=But')
#
# ------
#
# Most important features *for* label I-MISC:
# ('token[0]=Cup   pos[-1]=NNP   token[-1]=South   token[0]=Open   '
#  'token[-1]=World   token[0]=League   token[0]=African   token[1]=Cup   '
#  'token[-1]=Grand   token[0]=OPEN   token[0]=CUP   token[-1]=NEW   '
#  'token[0]=LEAGUE   token[-2]=AT   token[-1]=MAJOR   token[-1]=Sri   '
#  'token[0]=YORK   token[2]=tournament   token[-1]=New   token[-1]=National   '
#  'token[0]=German   token[0]=Serb   token[-3]=RESULTS   token[0]=Russian   '
#  'token[0]=Kurdish   token[0]=GMT   token[0]=DIVISION   token[-1]=WESTERN   '
#  'pos[-3]=DT   token[0]=Korean')
#
# Most important features *against* label I-MISC:
# ('token[0]=said   token[0]=Reuters   pos[0]=PRP   token[0]=AT   token[0]=The   '
#  'token[0]=a   token[0]=to   token[-1]=2   token[0]=0   token[0]=1996-08-28   '
#  'token[-1]=3   token[-1]=1   pos[0]=VBN   token[0]=was   token[0]=Minister   '
#  'token[1]=AT   pos[0]=NN   token[0]=has   token[0]=3   token[0]=4   '
#  'pos[0]=PRP$   pos[0]=VBD   token[0]=first   token[0]=1996-08-22   '
#  'token[0]=1996-08-29   token[-1]=0   token[0]=which   token[0]=1996-08-27   '
#  'token[0]=$   token[-1]=AT')
#
# ------

# %% [markdown]
# PART B
#
# Before training the pos tags of each word and their relative position was given to the model. After training the most important features gave some interesting results. For example the features that were most important for outside included POS tag PRP and the contents had prepositions included. The most important against outside were first-letter-capitalized and many names of countries.
#
# For beginning words the most important features were names, numbers, first-letter-capitalized and dates. For beginning words the least important features were prepositions, weekdays, months and singular proper nouns.
#
# For inbetween words the most important features were singular proper nouns, names, plural proper nouns, country names and dates. The least important features were prepositions, weekdays and dates.
#
# From these observations the beginning and inbetween words seem to have more in common with each other than the outside words. Outside words seem to be more connective and less meaningfull than the beginning and outside words.
