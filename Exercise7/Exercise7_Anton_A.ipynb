# %% [markdown]
# # Sequence labeling (POS tagging) with MLP
#
# This notebook builds upon the [classification with MLP notebook](https://github.com/TurkuNLP/intro-to-nlp/blob/master/mlp_imdb_hf_dset_and_trainer.ipynb) and shows how to implement a basic sequence labeling method.

# %% [markdown]
# ---
#
# # Setup
#
# Install the required Python packages using [pip](https://en.wikipedia.org/wiki/Pip):
#
# * [`transformers`](https://huggingface.co/docs/transformers/index) is a popular deep learning package primarily on top of torch
# * [`datasets`](https://huggingface.co/docs/datasets/) provides support for loading, creating, and manipulating datasets
# * [`evaluate`](https://huggingface.co/docs/evaluate/index) is a library of performance metrics (like accuracy etc)

# %%
# !pip3 install --upgrade transformers[torch]
# !pip3 install -q evaluate
# Out:
# WARNING: Ignoring invalid distribution ~ransformers (/home/anton/venv/Data-Analysis/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/home/anton/venv/Data-Analysis/lib/python3.12/site-packages)
# Requirement already satisfied: transformers[torch] in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (5.5.4)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (1.7.2)
# Requirement already satisfied: numpy>=1.17 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (0.22.2)
# Requirement already satisfied: typer in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (4.67.3)
# Requirement already satisfied: torch>=2.4 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (2.10.0+cu126)
# Requirement already satisfied: accelerate>=1.1.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from transformers[torch]) (1.13.0)
# Requirement already satisfied: filelock>=3.10.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (2026.1.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers[torch]) (4.15.0)
# Requirement already satisfied: anyio in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (4.12.1)
# Requirement already satisfied: certifi in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (1.0.9)
# Requirement already satisfied: idna in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers[torch]) (0.16.0)
# Requirement already satisfied: psutil in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from accelerate>=1.1.0->transformers[torch]) (7.2.2)
# Requirement already satisfied: setuptools in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (3.6.1)
# Requirement already satisfied: jinja2 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (1.11.1.6)
# Requirement already satisfied: triton==3.6.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from cuda-bindings==12.9.4->torch>=2.4->transformers[torch]) (1.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.4->transformers[torch]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from jinja2->torch>=2.4->transformers[torch]) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from typer->transformers[torch]) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from typer->transformers[torch]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from typer->transformers[torch]) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from typer->transformers[torch]) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from rich>=12.3.0->typer->transformers[torch]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from rich>=12.3.0->typer->transformers[torch]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/anton/venv/Data-Analysis/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers[torch]) (0.1.2)
# WARNING: Ignoring invalid distribution ~ransformers (/home/anton/venv/Data-Analysis/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/home/anton/venv/Data-Analysis/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/home/anton/venv/Data-Analysis/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/home/anton/venv/Data-Analysis/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/home/anton/venv/Data-Analysis/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/home/anton/venv/Data-Analysis/lib/python3.12/site-packages)

# %%
import datasets
import evaluate
import transformers

# %% [markdown]
# ---
#
# # Get and prepare data
#
# *   Let us work with the venerable, if somewhat dated [CoNLL'03 shared task](https://aclanthology.org/W03-0419.pdf) English data
# *   These are English news articles, and have annotation for POS, syntactic chunks, and named entities (in the IOB format)
#
# The data as originally distributed for the 2003 shared task has the following format:
#
# ```
# Only RB B-NP O
# France NNP I-NP B-LOC
# and CC I-NP O
# Britain NNP I-NP B-LOC
# backed VBD B-VP O
# Fischler NNP B-NP B-PER
# 's POS I-NP O
# proposal NN I-NP O
# . . O O
# ```
#
# Here, the four space-separated columns are token text, POS tag, chunk tag, and NER tag. The goal of the original task is to predict the NER tags using the other information as features, but the dataset can be used to study predicting the other columns too.
#
# The dataset happens to be in the HF datasets collection, so we can grab it from there

# %%
import torch
import transformers
import datasets

from pprint import pprint    # pretty-print

dataset = datasets.load_dataset("dany0407/conll2003")

print(dataset)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 14041
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3250
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3453
#     })
# })

# %%
pprint(dataset["train"][12])
# Out:
# {'chunk_tags': [11, 12, 12, 12, 21, 11, 11, 12, 0],
#  'id': '12',
#  'ner_tags': [0, 5, 0, 5, 0, 1, 0, 0, 0],
#  'pos_tags': [30, 22, 10, 22, 38, 22, 27, 21, 7],
#  'tokens': ['Only',
#             'France',
#             'and',
#             'Britain',
#             'backed',
#             'Fischler',
#             "'s",
#             'proposal',
#             '.']}

# %% [markdown]
# As you can see above, the various labels (POS, NER and chunk tags) are converted into IDs in this dataset. We can access the textual labels of these tags through the dataset `features`:

# %%
POS_TAG_NAMES = dataset['train'].features['pos_tags'].feature.names
NER_TAG_NAMES = dataset['train'].features['ner_tags'].feature.names
CHUNK_TAG_NAMES = dataset['train'].features['chunk_tags'].feature.names

# %% [markdown]
# We can then create mappings from names to IDs and back as Python dictionaries:

# %%
POS2ID = { n: i for i, n in enumerate(POS_TAG_NAMES) }
ID2POS = { i: n for i, n in enumerate(POS_TAG_NAMES) }

NER2ID = { n: i for i, n in enumerate(NER_TAG_NAMES) }
ID2NER = { i: n for i, n in enumerate(NER_TAG_NAMES) }

CHUNK2ID = { n: i for i, n in enumerate(CHUNK_TAG_NAMES) }
ID2CHUNK = { i: n for i, n in enumerate(CHUNK_TAG_NAMES) }

# %% [markdown]
# This is what these mappings look like:

# %%
print(NER2ID)
# Out:
# {'O': 0, 'B-PER': 1, 'I-PER': 2, 'B-ORG': 3, 'I-ORG': 4, 'B-LOC': 5, 'I-LOC': 6, 'B-MISC': 7, 'I-MISC': 8}

# %%
print(ID2NER)
# Out:
# {0: 'O', 1: 'B-PER', 2: 'I-PER', 3: 'B-ORG', 4: 'I-ORG', 5: 'B-LOC', 6: 'I-LOC', 7: 'B-MISC', 8: 'I-MISC'}

# %% [markdown]
# Let's also add in explanations from Penn Treebank for the POS tags:

# %%
# From the documentation page and from here https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

POS2DESCRIPTION = {
    "CC": "Coordinating conjunction",
    "CD": "Cardinal number",
    "DT": "Determiner",
    "EX": "Existential there",
    "FW": "Foreign word",
    "IN": "Preposition or subordinating conjunction",
    "JJ": "Adjective",
    "JJR": "Adjective, comparative",
    "JJS": "Adjective, superlative",
    "LS": "List item marker",
    "MD": "Modal",
    "NN": "Noun, singular or mass",
    "NNS": "Noun, plural",
    "NNP": "Proper noun, singular",
    "NNPS": "Proper noun, plural",
    "PDT": "Predeterminer",
    "POS": "Possessive ending",
    "PRP": "Personal pronoun",
    "PRP$": "Possessive pronoun",
    "RB": "Adverb",
    "RBR": "Adverb, comparative",
    "RBS": "Adverb, superlative",
    "RP": "Particle",
    "SYM": "Symbol",
    "TO": "to",
    "UH": "Interjection",
    "VB": "Verb, base form",
    "VBD": "Verb, past tense",
    "VBG": "Verb, gerund or present participle",
    "VBN": "Verb, past participle",
    "VBP": "Verb, non-3rd person singular present",
    "VBZ": "Verb, 3rd person singular present",
    "WDT": "Wh-determiner",
    "WP": "Wh-pronoun",
    "WP$": "Possessive wh-pronoun",
    "WRB": "Wh-adverb"
}

# %% [markdown]
# We can now try to make sense of the tags:

# %%
import tabulate

e = dataset["train"][12]    # work on the same example

table = []
for token, pos_id, chunk_id, ner_id in zip(e["tokens"], e["pos_tags"], e["chunk_tags"], e["ner_tags"]):
    ner_tag = ID2NER[ner_id]
    chunk_tag = ID2CHUNK[chunk_id]
    pos_tag = ID2POS[pos_id]
    pos_def = POS2DESCRIPTION.get(pos_tag,pos_tag)
    table.append([token, ner_tag, chunk_tag, pos_tag, pos_def])

print(tabulate.tabulate(table,headers=["Token", "NER", "Chunk", "POS", "POS definition"]))
# Out:
# Token     NER    Chunk    POS    POS definition
# --------  -----  -------  -----  ------------------------
# Only      O      B-NP     RB     Adverb
# France    B-LOC  I-NP     NNP    Proper noun, singular
# and       O      I-NP     CC     Coordinating conjunction
# Britain   B-LOC  I-NP     NNP    Proper noun, singular
# backed    O      B-VP     VBD    Verb, past tense
# Fischler  B-PER  B-NP     NNP    Proper noun, singular
# 's        O      B-NP     POS    Possessive ending
# proposal  O      I-NP     NN     Noun, singular or mass
# .         O      O        .      .

# %% [markdown]
# Note that the data is organized into sentences.

# %% [markdown]
# ---
#
# # Create features
#
# We'll define a simple function that takes a token sequence, the index of the focus token, and a window size and generates a few basic explicit features relevant to the task.
#
# (Note that as we'll be predicting the POS tag, we won't look at the chunk or NER tags, which would typically only be predicted _after_ predicting POS in a "traditional" NLP pipeline)

# %%
def token_features(tokens, index, window_size):
    # Generate features for token in position `index` in given list of tokens
    features = []

    # Context window start and end
    window_start = max(0, index-window_size)
    window_end = min(index+window_size+1, len(tokens))    # note +1 for range

    for i in range(window_start, window_end):
        offset = i - index    # relative position 
        features.append(f"token[{offset}]={tokens[i]}")

        #if offset != 0:

        #features.append(f"token[{index}]={tokens[index]}")f
        #break      

    # Example custom feature: does focus token start with an upper-case letter?
    if tokens[index][0].isupper():
        features.append("first-letter-capitalized")

    return features

# %% [markdown]
# PART A
#
# Added line to check if the feature is the focus word. If it is then it is not passed to the feature. This means that all of the features are purely context dependent.
#
# Modified the feature generation to only pass the original word as a feature. This means that the POS tagger is only memorizing the words.

# %% [markdown]
# We can call this function for all tokens in a sentence like so:

# %%
def add_features_to_sentence(sentence):
    # Collect lists of features for all tokens here
    all_features = []

    tokens = sentence["tokens"]
    for index in range(len(tokens)):
        all_features.append(" ".join(token_features(tokens, index, window_size=3)))

    return { "features": all_features}

# %%
for feats in add_features_to_sentence(dataset["train"][12])["features"]:
    print(feats)
# Out:
# token[0]=Only token[1]=France token[2]=and token[3]=Britain first-letter-capitalized
# token[-1]=Only token[0]=France token[1]=and token[2]=Britain token[3]=backed first-letter-capitalized
# token[-2]=Only token[-1]=France token[0]=and token[1]=Britain token[2]=backed token[3]=Fischler
# token[-3]=Only token[-2]=France token[-1]=and token[0]=Britain token[1]=backed token[2]=Fischler token[3]='s first-letter-capitalized
# token[-3]=France token[-2]=and token[-1]=Britain token[0]=backed token[1]=Fischler token[2]='s token[3]=proposal
# token[-3]=and token[-2]=Britain token[-1]=backed token[0]=Fischler token[1]='s token[2]=proposal token[3]=. first-letter-capitalized
# token[-3]=Britain token[-2]=backed token[-1]=Fischler token[0]='s token[1]=proposal token[2]=.
# token[-3]=backed token[-2]=Fischler token[-1]='s token[0]=proposal token[1]=.
# token[-3]=Fischler token[-2]='s token[-1]=proposal token[0]=.

# %% [markdown]
# The dataset is organized into sentences, so we can use the above function to add features to the entire dataset as follows.
#
# **Note**: unlike e.g. the Python`map` function, [`Dataset.map`](https://huggingface.co/docs/datasets/package_reference/main_classes.html#datasets.Dataset.map) function _updates_ its argument dataset, keeping existing values.

# %%
dataset = dataset.map(add_features_to_sentence)
# Out:
# Map:   0%|          | 0/14041 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3250 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3453 [00:00<?, ? examples/s]

# %% [markdown]
# Let's check that one more time:

# %%
pprint(dataset["train"][12])
# Out:
# {'chunk_tags': [11, 12, 12, 12, 21, 11, 11, 12, 0],
#  'features': ['token[0]=Only token[1]=France token[2]=and token[3]=Britain '
#               'first-letter-capitalized',
#               'token[-1]=Only token[0]=France token[1]=and token[2]=Britain '
#               'token[3]=backed first-letter-capitalized',
#               'token[-2]=Only token[-1]=France token[0]=and token[1]=Britain '
#               'token[2]=backed token[3]=Fischler',
#               'token[-3]=Only token[-2]=France token[-1]=and token[0]=Britain '
#               "token[1]=backed token[2]=Fischler token[3]='s "
#               'first-letter-capitalized',
#               'token[-3]=France token[-2]=and token[-1]=Britain '
#               "token[0]=backed token[1]=Fischler token[2]='s token[3]=proposal",
#               'token[-3]=and token[-2]=Britain token[-1]=backed '
#               "token[0]=Fischler token[1]='s token[2]=proposal token[3]=. "
#               'first-letter-capitalized',
#               'token[-3]=Britain token[-2]=backed token[-1]=Fischler '
#               "token[0]='s token[1]=proposal token[2]=.",
#               "token[-3]=backed token[-2]=Fischler token[-1]='s "
#               'token[0]=proposal token[1]=.',
#               "token[-3]=Fischler token[-2]='s token[-1]=proposal token[0]=."],
#  'id': '12',
#  'ner_tags': [0, 5, 0, 5, 0, 1, 0, 0, 0],
#  'pos_tags': [30, 22, 10, 22, 38, 22, 27, 21, 7],
#  'tokens': ['Only',
#             'France',
#             'and',
#             'Britain',
#             'backed',
#             'Fischler',
#             "'s",
#             'proposal',
#             '.']}

# %% [markdown]
# ---
#
# # Flatten dataset
#
# The MLP code that we introduced previously expects each of the `train`, `validation` and `test` subsets of the data to consist of simple sequences of examples.
#
# Now that we have run the feature generation, we no longer need the sentence structure and can "flatten" the data, i.e. remove the "sentence" level of granularity.

# %%
def flatten(subset):
    # Keys for values to flatten
    keys = ["tokens", "pos_tags", "chunk_tags", "ner_tags", "features"]

    # Initialize to empty lists of tokens etc.
    flattened = { k: [] for k in keys }

    # Concatenate per-sentence lists of tokens etc.
    for sentence in subset:
        for key in keys:
            flattened[key].extend(sentence[key])

    # Return as Dataset object
    return datasets.Dataset.from_dict(flattened)

# %% [markdown]
# Call `flatten` for each of the subsets and make a new `DatasetDict` containing the flattened subsets:

# %%
flattened_dict = {
    "train": flatten(dataset["train"]),
    "validation": flatten(dataset["validation"]),
    "test": flatten(dataset["test"]),
}

flat_dataset = datasets.DatasetDict(flattened_dict)

# %% [markdown]
# Check that the new dataset looks OK:

# %%
flat_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'pos_tags', 'chunk_tags', 'ner_tags', 'features'],
#         num_rows: 203621
#     })
#     validation: Dataset({
#         features: ['tokens', 'pos_tags', 'chunk_tags', 'ner_tags', 'features'],
#         num_rows: 51362
#     })
#     test: Dataset({
#         features: ['tokens', 'pos_tags', 'chunk_tags', 'ner_tags', 'features'],
#         num_rows: 46435
#     })
# })

# %%
for i in range(10):
    token = flat_dataset["train"]["tokens"][i]
    pos_tag = ID2POS[flat_dataset["train"]["pos_tags"][i]]
    description = POS2DESCRIPTION.get(pos_tag, pos_tag)
    features = flat_dataset["train"]["features"][i]
    print(f"{token}\t{pos_tag}\t{description}\t{features}")
# Out:
# EU	NNP	Proper noun, singular	token[0]=EU token[1]=rejects token[2]=German token[3]=call first-letter-capitalized
# rejects	VBZ	Verb, 3rd person singular present	token[-1]=EU token[0]=rejects token[1]=German token[2]=call token[3]=to
# German	JJ	Adjective	token[-2]=EU token[-1]=rejects token[0]=German token[1]=call token[2]=to token[3]=boycott first-letter-capitalized
# call	NN	Noun, singular or mass	token[-3]=EU token[-2]=rejects token[-1]=German token[0]=call token[1]=to token[2]=boycott token[3]=British
# to	TO	to	token[-3]=rejects token[-2]=German token[-1]=call token[0]=to token[1]=boycott token[2]=British token[3]=lamb
# boycott	VB	Verb, base form	token[-3]=German token[-2]=call token[-1]=to token[0]=boycott token[1]=British token[2]=lamb token[3]=.
# British	JJ	Adjective	token[-3]=call token[-2]=to token[-1]=boycott token[0]=British token[1]=lamb token[2]=. first-letter-capitalized
# lamb	NN	Noun, singular or mass	token[-3]=to token[-2]=boycott token[-1]=British token[0]=lamb token[1]=.
# .	.	.	token[-3]=boycott token[-2]=British token[-1]=lamb token[0]=.
# Peter	NNP	Proper noun, singular	token[0]=Peter token[1]=Blackburn first-letter-capitalized

# %% [markdown]
# Note that this is now a single long dataset of tokens without sentence boundaries.

# %% [markdown]
# # Tokenization
#
# Tokenization needs a bit of thinking, so that we can keep things as simple as possible. We need to turn the strings of features into tokens so that we can then plug them into our MLP.
#
# This would be perfectly doable with the standard tokenizer if only we could convince it to simply tokenize on whitespace and leave everything else untouched.
#
# We cannot use the approach from the MLP lecture, because the pretrained tokenizers tend to modify the data in various ways. We need more control, i.e. we need to make our own tokenizer. Luckily, this is easier than it sounds.

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordLevel
from tokenizers.trainers import WordLevelTrainer
from tokenizers.pre_tokenizers import WhitespaceSplit
from transformers import PreTrainedTokenizerFast

def build_whitespace_tokenizer(dataset, vocab_size=None, min_frequency=2):
    tokenizer = Tokenizer(WordLevel(unk_token="[UNK]"))

    # Use pure whitespace splitting, no normalization or subwording
    tokenizer.normalizer = None #This is a step which happens before tokenization, we want nothing done. So setting to None.
    tokenizer.pre_tokenizer = WhitespaceSplit() #This is a pre-tokenization step, we want to strictly only use whitespace.

    # List [PAD] first, so it gets index 0
    special_tokens = ["[PAD]","[UNK]"]

    # WordLevelTrainer builds a word-level tokenizer, i.e. no subwords are used, no BPE algorithm, simply full words
    # Words that do not fit into the vocabulary will be replaced by [UNK], which is fine for our purposes
    trainer = WordLevelTrainer(
        vocab_size=vocab_size,
        min_frequency=min_frequency, #only consider tokens which appear this many times
        special_tokens=special_tokens,
    )
    # This is where the actual training happens
    iterator = (example["features"] for example in dataset)
    tokenizer.train_from_iterator(iterator, trainer=trainer)
    print(tokenizer)

    # And this then turns the tokenizer into something we can use
    hf_tokenizer = PreTrainedTokenizerFast(
        tokenizer_object=tokenizer,

        unk_token="[UNK]",
        pad_token="[PAD]",
    )

    return hf_tokenizer
tokenizer = build_whitespace_tokenizer(flat_dataset["train"], vocab_size=15000)
# Out:
# Tokenizer(version="1.0", truncation=None, padding=None, added_tokens=[{"id":0, "content":"[PAD]", "single_word":False, "lstrip":False, "rstrip":False, ...}, {"id":1, "content":"[UNK]", "single_word":False, "lstrip":False, "rstrip":False, ...}], normalizer=None, pre_tokenizer=WhitespaceSplit(), post_processor=None, decoder=None, model=WordLevel(vocab={"[PAD]":0, "[UNK]":1, "first-letter-capitalized":2, "token[0]=.":3, "token[1]=.":4, ...}, unk_token="[UNK]"))

# %%
tokenizer.vocab
# Out:
# {'token[-2]=militants': 14387,
#  'token[-2]=Craig': 10421,
#  'token[0]=gross': 11519,
#  'token[2]=shareholders': 11784,
#  'token[3]=night': 3444,
#  'token[-3]=build': 14541,
#  'token[-2]=fishermen': 13132,
#  'token[1]=Republican': 4502,
#  'token[3]=now': 1746,
#  'token[1]=6-0': 5175,
#  'token[1]=RBI': 10047,
#  'token[-3]=International': 6311,
#  'token[-1]=reserve': 12997,
#  'token[1]=St': 5178,
#  'token[0]=declared': 4355,
#  'token[-1]=delay': 14138,
#  'token[1]=KDP': 8864,
#  'token[-3]=stake': 11426,
#  'token[0]=big': 6068,
#  'token[3]=dealer': 10235,
#  'token[0]=1996-08-26': 956,
#  'token[-1]=lei': 12976,
#  'token[-2]=my': 2741,
#  'token[0]=Russell': 8785,
#  'token[2]=Slam': 13733,
#  'token[3]=shooting': 11058,
#  'token[1]=6': 351,
#  'token[0]=significant': 12478,
#  'token[3]=that': 171,
#  'token[-2]=Marseille': 10447,
#  'token[2]=policy': 5219,
#  'token[3]=failed': 4134,
#  'token[-1]=Benetton': 11922,
#  'token[-1]=Massachusetts': 14055,
#  'token[2]=truck': 8997,
#  'token[3]=account': 12771,
#  'token[-2]=advantage': 14323,
#  'token[3]=Aug': 6176,
#  'token[-2]=World': 2125,
#  'token[3]=rest': 9049,
#  'token[-2]=midfielder': 7690,
#  'token[1]=made': 1057,
#  'token[0]=Sanchez': 7788,
#  'token[0]=KANSAS': 6364,
#  'token[3]=poor': 6195,
#  'token[-3]=Malta': 14485,
#  'token[1]=accused': 3695,
#  'token[-1]=minority': 12028,
#  'token[2]=appeared': 8960,
#  'token[-1]=confirmed': 5256,
#  'token[2]=ministers': 13798,
#  'token[-3]=Croatia': 10532,
#  'token[-2]=clocked': 14342,
#  'token[1]=cost': 6756,
#  'token[0]=costs': 7387,
#  'token[1]=Jason': 14905,
#  'token[1]=exchange': 8348,
#  'token[0]=improve': 13462,
#  'token[-3]=2000': 13189,
#  'token[2]=c': 3850,
#  'token[-2]=system': 6636,
#  'token[1]=ANGELES': 7418,
#  'token[-1]=announcement': 10337,
#  'token[2]=Hong': 3707,
#  'token[-2]=ever': 14360,
#  'token[-3]=prefix': 11412,
#  'token[-3]=settlement': 7754,
#  'token[-2]=bill': 14332,
#  'token[3]=6-0': 5649,
#  'token[0]=traffic': 7833,
#  'token[-1]=keep': 5475,
#  'token[2]=8-6': 13697,
#  'token[-3]=3-1': 12202,
#  'token[3]=rebels': 3022,
#  'token[-3]=gave': 2299,
#  'token[-2]=cannot': 13109,
#  'token[2]=ruled': 10183,
#  'token[1]=former': 985,
#  'token[-1]=making': 5259,
#  'token[0]=direct': 12437,
#  'token[2]=v': 1539,
#  'token[2]=Saturday': 889,
#  'token[0]=Rica': 6710,
#  'token[-2]=newspaper': 2290,
#  'token[3]=England': 2005,
#  'token[3]=died': 5061,
#  'token[3]=began': 4128,
#  'token[0]=six': 903,
#  'token[-2]=wants': 11311,
#  'token[3]=as': 195,
#  'token[-3]=Other': 14498,
#  'token[-3]=cricket': 7737,
#  'token[-1]=at': 133,
#  'token[-1]=anything': 10338,
#  'token[2]=village': 6173,
#  'token[1]=ceasefire': 3966,
#  'token[0]=Greg': 10660,
#  'token[0]=Todd': 7019,
#  'token[-2]=Malaysia': 10446,
#  'token[-1]=across': 4155,
#  'token[3]=51': 9578,
#  'token[0]=minutes': 1606,
#  'token[1]=food': 7086,
#  'token[-1]=teams': 7639,
#  'token[-1]=Indian': 5461,
#  'token[-2]=James': 13066,
#  'token[1]=job': 9467,
#  'token[-2]=DIGEST': 5972,
#  'token[-2]=help': 3906,
#  'token[3]=squad': 5070,
#  'token[1]=AND': 7057,
#  'token[-3]=Maria': 11357,
#  'token[2]=stock': 4865,
#  'token[-2]=not': 228,
#  'token[-2]=Rotterdam': 11235,
#  'token[0]=flew': 13456,
#  'token[0]=average': 4070,
#  'token[-1]=BALTIMORE': 6863,
#  'token[1]=Doboj': 12510,
#  'token[2]=Khartoum': 12643,
#  'token[-1]=sex': 9739,
#  'token[2]=progress': 13809,
#  'token[-1]=7-6': 1807,
#  'token[-3]=any': 1394,
#  'token[2]=same': 2069,
#  'token[3]=Indonesia': 9587,
#  'token[2]=reserve': 13817,
#  'token[-1]=call': 4722,
#  'token[-3]=drugs': 8722,
#  'token[-1]=members': 4160,
#  'token[0]=demanding': 8811,
#  'token[0]=away': 3312,
#  'token[2]=expect': 8971,
#  'token[-1]=Mexico': 5696,
#  'token[-2]=Prime': 2284,
#  'token[-2]=operation': 10490,
#  'token[3]=title': 5680,
#  'token[2]=help': 4110,
#  'token[-3]=leaders': 3060,
#  'token[-1]=Melbourne': 11103,
#  'token[-2]=Major': 12095,
#  'token[3]=lower': 2215,
#  'token[-1]=administration': 9691,
#  'token[-3]=yet': 5145,
#  'token[-3]=arrested': 3299,
#  'token[-2]=university': 13179,
#  'token[0]=break': 6070,
#  'token[2]=Western': 9515,
#  'token[1]=accident': 11606,
#  'token[0]=seen': 3809,
#  'token[1]=ground': 5858,
#  'token[-3]=if': 1184,
#  'token[0]=or': 580,
#  'token[-3]=add': 14527,
#  'token[-2]=view': 14429,
#  'token[-2]=mostly': 9822,
#  'token[2]=groups': 5403,
#  'token[2]=halftime': 5888,
#  'token[0]=P.': 8252,
#  'token[0]=SOCCER': 779,
#  'token[0]=Richard': 7016,
#  'token[3]=given': 5435,
#  'token[1]=Cup': 1278,
#  'token[-2]=1,000': 5487,
#  'token[-1]=FC': 7210,
#  'token[-3]=all': 925,
#  'token[0]=Standings': 3604,
#  'token[-3]=debt': 10583,
#  'token[0]=Rating': 13396,
#  'token[1]=retired': 13663,
#  'token[1]=74': 2692,
#  'token[1]=pounds': 6448,
#  'token[2]=times': 5896,
#  'token[1]=division': 1642,
#  'token[1]=title': 5388,
#  'token[0]=how': 5165,
#  'token[3]=according': 6508,
#  'token[-1]=1991': 6210,
#  'token[-3]=hostage': 14574,
#  'token[1]=Reuters': 2150,
#  'token[-1]=ceasefire': 3880,
#  'token[-2]=10.': 4304,
#  'token[0]=really': 7043,
#  'token[1]=yen': 4839,
#  'token[0]=Party': 2760,
#  'token[-1]=clocked': 14127,
#  'token[-1]=dollar': 2440,
#  'token[-3]=new': 579,
#  'token[1]=Thursday': 432,
#  'token[-2]=stake': 11307,
#  'token[-1]=Scotland': 6873,
#  'token[-1]=rights': 3462,
#  'token[-1]=171': 6855,
#  'token[0]=share': 3231,
#  'token[-3]=Robert': 5126,
#  'token[1]=details': 4825,
#  'token[1]=Japan': 1421,
#  'token[0]=an': 246,
#  'token[2]=Saudi': 7488,
#  'token[3]=60': 3625,
#  'token[0]=Ministry': 4348,
#  'token[1]=unrest': 10871,
#  'token[-2]=near': 2456,
#  'token[1]=7-2': 13531,
#  'token[0]=Mother': 6365,
#  'token[-1]=Slovenia': 14090,
#  'token[0]=walk': 10752,
#  'token[-1]=2-6': 6212,
#  'token[0]=Diego': 9339,
#  'token[3]=Olympic': 4404,
#  'token[-3]=Christian': 14455,
#  'token[2]=international': 1901,
#  'token[-1]=DETROIT': 9071,
#  'token[-1]=ministry': 3276,
#  'token[1]=course': 6115,
#  'token[-1]=These': 6561,
#  'token[1]=P.': 10785,
#  'token[0]=front': 12446,
#  'token[-3]=organisers': 14592,
#  'token[-1]=Sri': 2577,
#  'token[1]=billion': 1279,
#  'token[-1]=70': 1177,
#  'token[-2]=eight': 2128,
#  'token[0]=issues': 7812,
#  'token[3]=British': 1779,
#  'token[2]=am': 11724,
#  'token[-2]=head': 3382,
#  'token[-2]=YORK': 4747,
#  'token[2]=land': 6800,
#  'token[0]=about': 591,
#  'token[2]=denotes': 8409,
#  'token[-2]=what': 2181,
#  'token[-3]=km': 2890,
#  'token[0]=from': 158,
#  'token[-1]=Colombia': 6546,
#  'token[3]=soccer': 4414,
#  'token[-3]=7.': 2957,
#  'token[-1]=Asif': 11918,
#  'token[-3]=-': 124,
#  'token[-1]=economy': 5946,
#  'token[0]=talk': 6402,
#  'token[2]=FOR': 6462,
#  'token[-1]=looking': 9720,
#  'token[-3]=news': 1579,
#  'token[-3]=Norman': 14491,
#  'token[-2]=distribution': 13124,
#  'token[2]=Lebanon': 10894,
#  'token[0]=services': 5579,
#  'token[3]=1994': 3355,
#  'token[-1]=price': 2446,
#  'token[-2]=convicted': 12135,
#  'token[2]=due': 1700,
#  'token[-3]=seconds': 4974,
#  'token[-1]=positive': 8067,
#  'token[0]=fears': 14794,
#  'token[-2]=Ahmed': 3894,
#  'token[-2]=unit': 8156,
#  'token[1]=Michael': 3158,
#  'token[-3]=weather': 13334,
#  'token[1]=stock': 4511,
#  'token[0]=Italian': 4068,
#  'token[-1]=fear': 14148,
#  'token[1]=BEAT': 8854,
#  'token[-2]=miles': 2589,
#  'token[-1]=same': 2012,
#  'token[0]=57': 7767,
#  'token[-1]=scoring': 12042,
#  'token[1]=looking': 10084,
#  'token[2]=does': 4107,
#  'token[3]=held': 1679,
#  'token[-3]=received': 4782,
#  'token[2]=vs.': 2377,
#  'token[1]=faces': 13619,
#  'token[0]=Austria': 3404,
#  'token[2]=Austria': 4101,
#  'token[-1]=Netanyahu': 5698,
#  'token[-3]=won': 701,
#  'token[-1]=Romania': 4291,
#  'token[2]=drawn': 3008,
#  'token[0]=wickets': 3955,
#  'token[0]=Fortuna': 8241,
#  'token[2]=gross': 12690,
#  'token[1]=39': 10760,
#  'token[0]=need': 6393,
#  'token[-1]=higher': 3116,
#  'token[-2]=girl': 8645,
#  'token[-1]=faces': 12956,
#  'token[-3]=barley': 13245,
#  'token[1]=so': 1699,
#  'token[-3]=starts': 12330,
#  'token[-2]=Mike': 12097,
#  'token[0]=customers': 14780,
#  'token[-1]=Feyenoord': 9660,
#  'token[-1]=analysts': 5079,
#  'token[-1]=7-1': 12852,
#  'token[-3]=violations': 14636,
#  'token[0]=1993': 8755,
#  'token[0]=division': 1320,
#  'token[-3]=American': 2462,
#  'token[-3]=Huber': 12236,
#  'token[0]=case': 3941,
#  'token[3]=sign': 8003,
#  'token[1]=broken': 11613,
#  'token[1]=presence': 10092,
#  'token[-2]=starting': 10505,
#  'token[0]=Johan': 14692,
#  'token[-1]=secretary': 8076,
#  'token[-1]=hits': 3458,
#  'token[2]=passed': 12705,
#  'token[2]=operating': 13805,
#  'token[0]=read': 14837,
#  "token[2]='": 758,
#  'token[3]=suffered': 11063,
#  'token[-2]=To': 9788,
#  'token[-1]=Result': 5934,
#  'token[-2]=Date': 10426,
#  'token[2]=parties': 6164,
#  'token[2]=Ian': 12639,
#  'token[0]=Dutroux': 3937,
#  'token[-1]=programme': 9129,
#  'token[0]=large': 10717,
#  'token[-2]=filed': 10479,
#  'token[-1]=employees': 12007,
#  'token[-3]=John': 2665,
#  'token[3]=slightly': 10268,
#  'token[1]=nation': 6765,
#  'token[2]=prime': 4860,
#  'token[1]=Foreign': 3235,
#  'token[-3]=use': 5788,
#  'token[1]=decide': 14979,
#  'token[-1]=Thursday': 427,
#  'token[-2]=Desk': 13050,
#  'token[0]=set': 1419,
#  'token[1]=industry': 4667,
#  'token[3]=3-0': 11804,
#  'token[-3]=of': 26,
#  'token[-1]=500': 14005,
#  'token[1]=money': 3418,
#  'token[2]=strike': 4000,
#  'token[-3]=calls': 14543,
#  'token[0]=Gajdos': 14685,
#  'token[2]=finished': 10157,
#  'token[-1]=seeded': 6257,
#  'token[1]=Oncins': 14925,
#  'token[-3]=described': 9885,
#  'token[0]=rate': 2251,
#  'token[-3]=violence': 6345,
#  'token[3]=asked': 4703,
#  'token[-1]=Windows': 9097,
#  'token[-1]=site': 12047,
#  'token[0]=number': 1607,
#  'token[-3]=lower': 2346,
#  'token[-2]=Olympic': 3379,
#  'token[2]=Yugoslavia': 10918,
#  'token[3]=winner': 7199,
#  'token[-1]=number': 1623,
#  'token[2]=house': 6481,
#  'token[0]=reported': 1277,
#  'token[-1]=built': 14117,
#  'token[1]=analyst': 7862,
#  'token[1]=State': 6109,
#  'token[0]=wounded': 10030,
#  'token[-2]=Arantxa': 13038,
#  'token[0]=cents': 2247,
#  'token[3]=share': 3559,
#  'token[1]=how': 5187,
#  'token[3]=trying': 4712,
#  'token[1]=tests': 13679,
#  'token[0]=Hill': 12375,
#  'token[-1]=NEW': 1041,
#  'token[-2]=called': 2127,
#  'token[1]=school': 7099,
#  'token[-1]=saw': 7635,
#  'token[-2]=secret': 10499,
#  'token[1]=St.': 13585,
#  'token[2]=European': 1614,
#  'token[-2]=towns': 14423,
#  'token[-2]=Zaire': 14319,
#  'token[0]=pound': 5354,
#  'token[-1]=Corser': 14024,
#  'token[-1]=work': 3040,
#  'token[-2]=bottom': 13104,
#  'token[2]=;': 2702,
#  'token[-1]=C': 10294,
#  'token[1]=old': 4830,
#  'token[-1]=Norway': 9674,
#  'token[-3]=might': 4059,
#  'token[1]=from': 159,
#  'token[2]=reform': 12712,
#  'token[1]=Tuesday': 540,
#  'token[3]=Yankees': 13896,
#  'token[2]=independence': 6157,
#  "token[-2]='m": 5731,
#  'token[-3]=supply': 12332,
#  'token[2]=agreed': 2559,
#  'token[0]=16': 2242,
#  'token[-2]=65': 3467,
#  'token[3]=bought': 9022,
#  'token[-1]=without': 3758,
#  'token[3]=landed': 9035,
#  'token[3]=making': 5913,
#  'token[2]=Cork': 11693,
#  'token[1]=mark': 7451,
#  'token[-3]=date': 6328,
#  'token[0]=held': 1485,
#  'token[1]=operating': 13650,
#  'token[-2]=play': 2020,
#  'token[-1]=61': 5453,
#  'token[-2]=brought': 4587,
#  'token[2]=months': 2705,
#  'token[-2]=efforts': 11264,
#  'token[2]=Europe': 3842,
#  'token[1]=secret': 10854,
#  'token[-1]=%': 6537,
#  'token[0]=children': 4354,
#  'token[3]=dealers': 7547,
#  'token[3]=biggest': 11015,
#  'token[-3]=month': 1885,
#  'token[-2]=investigators': 13140,
#  'token[-3]=broke': 6665,
#  'token[-3]=average': 4959,
#  'token[-3]=Barrick': 13201,
#  'token[2]=evening': 8970,
#  'token[2]=winners': 11798,
#  'token[1]=English': 4817,
#  'token[0]=ban': 3940,
#  'token[-2]=4.': 1913,
#  'token[-3]=price': 2970,
#  'token[2]=forced': 4852,
#  'token[-1]=Moscow': 2173,
#  'token[-1]=sector': 6901,
#  'token[-1]=matches': 1313,
#  'token[2]=financial': 5401,
#  'token[-2]=why': 14432,
#  'token[-3]=Chang': 9245,
#  'token[-2]=crisis': 14348,
#  'token[-1]=row': 14201,
#  'token[-3]=become': 7735,
#  'token[2]=10th': 7900,
#  'token[-3]=Zimbabwe': 10563,
#  'token[3]=major': 3867,
#  'token[1]=Paul': 2989,
#  'token[-2]=10th': 8088,
#  'token[2]=woman': 4866,
#  'token[0]=votes': 7414,
#  'token[-1]=measures': 9125,
#  'token[-1]=offered': 7625,
#  'token[1]=office': 2697,
#  'token[0]=tabulate': 4494,
#  'token[3]=break': 6513,
#  'token[1]=moment': 10085,
#  'token[-2]=tennis': 4449,
#  'token[-2]=championship': 3577,
#  'token[0]=It': 539,
#  'token[-3]=Kurdish': 4607,
#  'token[-1]=competition': 7613,
#  'token[2]=guerrillas': 5628,
#  'token[-2]=Attendance': 3041,
#  'token[3]=Sudanese': 7540,
#  'token[0]=home': 999,
#  'token[-3]=6.': 2461,
#  'token[-3]=Republican': 5310,
#  'token[0]=live': 10719,
#  'token[1]=face': 4663,
#  'token[0]=suffered': 8306,
#  'token[0]=Munich': 7782,
#  'token[-2]=Central': 5971,
#  'token[-3]=driver': 10585,
#  'token[1]=cattle': 12551,
#  'token[2]=Teresa': 10913,
#  'token[-1]=finished': 9120,
#  'token[-3]=Democrats': 9851,
#  'token[0]=Bulgaria': 12362,
#  'token[0]=56': 5338,
#  'token[3]=soldiers': 9054,
#  'token[-1]=majority': 9124,
#  'token[2]=political': 1741,
#  'token[1]=..': 14867,
#  'token[-1]=Iraq': 1809,
#  'token[-1]=shortly': 10385,
#  'token[3]=hope': 12806,
#  'token[-2]=surplus': 13171,
#  'token[-3]=ON': 12248,
#  'token[0]=officials': 836,
#  'token[-2]=chairman': 5282,
#  'token[3]=will': 376,
#  'token[3]=man': 3018,
#  'token[3]=G.': 10990,
#  'token[-3]=Marcelo': 9861,
#  'token[-1]=accident': 11127,
#  'token[-2]=seed': 4598,
#  'token[3]=draw': 4012,
#  'token[-1]=act': 10333,
#  'token[0]=drive': 14785,
#  'token[1]=after': 273,
#  'token[2]=Gaza': 9500,
#  'token[2]=Martin': 5395,
#  'token[-1]=a.m.': 9099,
#  'token[1]=president': 1207,
#  'token[0]=Series': 7381,
#  'token[3]=concern': 11849,
#  'token[3]=settlement': 7192,
#  'token[0]=SAN': 2682,
#  'token[-3]=despite': 4965,
#  'token[0]=among': 8802,
#  'token[-3]=Extras': 10536,
#  'token[0]=completed': 5565,
#  'token[-3]=ahead': 2964,
#  'token[1]=annual': 9448,
#  'token[-3]=has': 213,
#  'token[0]=interview': 11530,
#  'token[0]=jailed': 14812,
#  'token[3]=school': 7190,
#  'token[3]=African': 4005,
#  'token[2]=small': 5415,
#  'token[-3]=That': 4771,
#  'token[2]=10,000': 10879,
#  'token[1]=bonds': 4370,
#  'token[-1]=his': 217,
#  'token[2]=factions': 12686,
#  'token[-2]=began': 3286,
#  'token[-1]=Congress': 8500,
#  'token[1]=Taiwan': 5016,
#  'token[-1]=ruled': 9737,
#  'token[-3]=Lanka': 4954,
#  'token[-1]=African': 2516,
#  'token[2]=address': 11723,
#  'token[-3]=Waqar': 10560,
#  'token[-3]=Open': 2087,
#  'token[-3]=alleged': 13242,
#  'token[-3]=girls': 7742,
#  'token[2]=taking': 3013,
#  'token[1]=figure': 10070,
#  'token[-3]=improved': 13286,
#  'token[-2]=CYCLING': 10418,
#  'token[0]=26': 2974,
#  'token[0]=land': 6389,
#  'token[2]=would': 388,
#  'token[2]=hands': 13781,
#  'token[-2]=9': 1454,
#  'token[-3]=Scott': 8702,
#  'token[2]=streak': 10969,
#  'token[1]=however': 13630,
#  'token[-2]=who': 279,
#  'token[0]=working': 3813,
#  'token[-3]=bonds': 6965,
#  'token[0]=Australia': 751,
#  'token[-3]=Malaysia': 13223,
#  'token[-3]=failed': 4612,
#  'token[3]=52': 11807,
#  'token[0]=beginning': 9977,
#  'token[3]=total': 4892,
#  'token[1]=Jeff': 12516,
#  'token[0]=Played': 6366,
#  'token[2]=one': 480,
#  'token[-3]=however': 14575,
#  'token[1]=1996-08-25': 1373,
#  'token[3]=committee': 7544,
#  'token[1]=whole': 9490,
#  'token[2]=wickets': 4002,
#  'token[1]=buying': 11614,
#  'token[0]=went': 3233,
#  'token[1]=farmers': 7874,
#  'token[2]=died': 4387,
#  'token[-2]=Stich': 8621,
#  'token[2]=says': 3621,
#  'token[-1]=that': 153,
#  'token[0]=head': 3315,
#  'token[-3]=even': 6031,
#  'token[-3]=resume': 13309,
#  'token[-3]=evening': 8723,
#  'token[-2]=(': 53,
#  'token[-1]=However': 11096,
#  'token[0]=airports': 13425,
#  'token[-1]=cooperation': 9112,
#  'token[2]=October': 4383,
#  'token[3]=young': 6854,
#  'token[2]=season': 1496,
#  'token[-1]=killed': 1429,
#  'token[-1]=mixed': 12981,
#  'token[-1]=Iranian': 6222,
#  'token[3]=picked': 12826,
#  'token[-3]=Hill': 12234,
#  'token[0]=relations': 8297,
#  'token[-1]=deal': 2175,
#  'token[1]=Tendulkar': 14938,
#  'token[-2]=Scotland': 8617,
#  'token[0]=likely': 4802,
#  'token[1]=b': 1640,
#  'token[-1]=Fall': 9659,
#  'token[2]=England': 1188,
#  'token[1]=name': 7454,
#  'token[-2]=8': 1286,
#  'token[-1]=defence': 6883,
#  'token[-1]=400': 6858,
#  'token[3]=opening': 5066,
#  'token[3]=data': 12788,
#  'token[-2]=rebel': 5755,
#  'token[-3]=movement': 8208,
#  'token[0]=soon': 5172,
#  'token[2]=broken': 11732,
#  'token[-1]=With': 8531,
#  'token[1]=Brazilian': 8855,
#  'token[0]=Hampshire': 11454,
#  'token[1]=ninth': 6766,
#  'token[0]=once': 8827,
#  'token[-1]=career': 7611,
#  'token[0]=human': 4998,
#  'token[3]=allowing': 7970,
#  'token[2]=coming': 5623,
#  'token[-2]=7-5': 8092,
#  'token[-3]=rest': 8217,
#  'token[-1]=caused': 9109,
#  'token[1]=Slovakia': 4368,
#  'token[1]=seeding': 5606,
#  'token[-2]=wife': 6013,
#  'token[2]=20': 1311,
#  'token[0]=Slovenia': 14734,
#  'token[3]=markets': 5239,
#  'token[-2]=living': 13145,
#  'token[-1]=Britain': 793,
#  'token[-2]=63': 3575,
#  'token[-3]=foreign': 1986,
#  'token[-2]=telephone': 10509,
#  'token[0]=close': 2057,
#  'token[-2]=soldiers': 9222,
#  'token[2]=spokeswoman': 11786,
#  'token[1]=Saudi': 7070,
#  'token[-1]=crisis': 11998,
#  'token[0]=Gloucestershire': 13369,
#  'token[-1]=Arab': 6862,
#  'token[1]=OF': 2257,
#  'token[-3]=Britain': 1271,
#  'token[0]=most': 1762,
#  'token[-3]=unable': 11427,
#  'token[-1]=deputy': 8548,
#  'token[-1]=thing': 12055,
#  'token[-3]=allowing': 7731,
#  'token[-3]=killing': 7341,
#  'token[0]=arrested': 2683,
#  'token[1]=control': 3826,
#  'token[-3]=arms': 7734,
#  'token[0]=PITTSBURGH': 8781,
#  'token[1]=European': 1437,
#  'token[3]=needed': 7184,
#  'token[-3]=away': 3491,
#  'token[3]=conference': 4268,
#  'token[1]=per': 1770,
#  'token[-3]=Deputy': 14460,
#  'token[1]=other': 791,
#  'token[-3]=2-1': 8161,
#  'token[3]=trade': 2929,
#  'token[3]=farm': 10245,
#  'token[-2]=barrels': 14328,
#  'token[-2]=started': 4047,
#  'token[-1]=scheduled': 5264,
#  'token[-1]=Bosnia': 4285,
#  'token[-3]=Atlanta': 6018,
#  'token[1]=even': 5856,
#  'token[-3]=conflict': 13259,
#  'token[0]=shot': 4361,
#  'token[0]=77': 6055,
#  'token[-1]=record': 2521,
#  'token[3]=invited': 11869,
#  'token[1]=Meri': 9427,
#  'token[-1]=opposition': 2338,
#  'token[1]=41': 8851,
#  'token[1]=eastern': 7083,
#  'token[-3]=stocks': 7353,
#  'token[3]=if': 1284,
#  'token[-1]=means': 12979,
#  'token[3]=Egypt': 9008,
#  'token[-2]=Indonesia': 7656,
#  'token[-2]=surgery': 12185,
#  'token[-1]=guerrilla': 10359,
#  'token[3]=spokeswoman': 12840,
#  'token[-2]=OM': 12100,
#  'token[1]=kph': 10838,
#  'token[-1]=504': 10284,
#  'token[3]=or': 583,
#  'token[2]=charges': 5207,
#  'token[-2]=HONG': 8102,
#  'token[0]=CHAMPIONSHIP': 9939,
#  'token[1]=Barcelona': 12501,
#  'token[-1]=meeting': 1357,
#  'token[-3]=does': 3929,
#  'token[-1]=coalition': 7228,
#  'token[3]=costs': 9608,
#  'token[-1]=200': 7201,
#  'token[-2]=People': 9168,
#  'token[-1]=Yasser': 11978,
#  'token[2]=possible': 4522,
#  'token[3]=telephone': 9636,
#  'token[0]=remained': 7821,
#  'token[2]=San': 7487,
#  'token[-3]=announcement': 10568,
#  'token[2]=lost': 1303,
#  'token[-3]=start': 2673,
#  'token[1]=responsible': 11658,
#  'token[0]=Total': 5344,
#  'token[0]=coast': 12427,
#  'token[0]=effect': 10701,
#  'token[2]=order': 4391,
#  'token[-2]=plan': 2883,
#  'token[1]=match': 881,
#  'token[-2]=Hong': 2451,
#  'token[1]=Hungary': 7853,
#  'token[1]=Thai': 9437,
#  'token[-3]=unrest': 14632,
#  'token[0]=results': 1672,
#  'token[-2]=Yellow': 10458,
#  'token[0]=Mayfair': 14703,
#  'token[0]=former': 982,
#  'token[-2]=increased': 7685,
#  'token[0]=ANGELES': 7359,
#  'token[-3]=Kurdistan': 8174,
#  'token[2]=Amsterdam': 7905,
#  'token[0]=Fox': 12373,
#  'token[-1]=poll': 6255,
#  'token[0]=halftime': 5163,
#  'token[3]=Newsroom': 5232,
#  'token[0]=Coast': 11447,
#  'token[-2]=companies': 5285,
#  'token[-3]=Atletico': 11323,
#  'token[-1]=three': 559,
#  'token[1]=United': 1032,
#  'token[0]=AMSTERDAM': 5549,
#  'token[3]=customs': 13920,
#  'token[-2]=such': 3484,
#  'token[0]=study': 14851,
#  'token[0]=Ferreira': 13367,
#  'token[1]=jail': 8353,
#  'token[1]=previous': 3700,
#  'token[3]=give': 4409,
#  'token[-2]=gained': 13136,
#  'token[-1]=tonnes': 1430,
#  'token[-1]=face': 4565,
#  'token[-2]=beaten': 14329,
#  'token[-2]=little': 3907,
#  'token[2]=winning': 3858,
#  'token[1]=strike': 3703,
#  'token[3]=girl': 11028,
#  'token[1]=PSV': 7430,
#  'token[1]=scores': 10853,
#  'token[1]=included': 7449,
#  'token[-1]=BEAT': 8495,
#  'token[-1]=Bank': 1590,
#  'token[3]=guilders': 7177,
#  'token[-2]=M.': 3044,
#  'token[-3]=fighting': 3492,
#  'token[0]=effective': 14786,
#  'token[-2]=Yugoslavia': 10459,
#  'token[-3]=N.': 7319,
#  'token[1]=C': 10770,
#  'token[2]=ended': 2704,
#  'token[0]=34': 7002,
#  'token[3]=four': 963,
#  'token[0]=Tim': 9968,
#  'token[-2]=Ijaz': 9769,
#  'token[-1]=Division': 6218,
#  'token[3]=California': 9581,
#  'token[-2]=was': 120,
#  'token[-2]=Information': 9770,
#  'token[2]=Greece': 12637,
#  'token[-2]=common': 9797,
#  'token[-2]=times': 5759,
#  'token[-3]=director': 6030,
#  'token[0]=7-6': 1633,
#  'token[2]=tough': 13834,
#  'token[2]=striker': 9563,
#  'token[-2]=conditions': 6285,
#  'token[0]=markets': 4487,
#  'token[1]=never': 6444,
#  'token[1]=.': 4,
#  'token[1]=68': 1766,
#  'token[0]=tonnes': 1436,
#  'token[-1]=things': 9137,
#  'token[2]=elections': 1586,
#  'token[1]=Raymond': 14929,
#  'token[-1]=show': 12045,
#  'token[0]=singles': 2143,
#  'token[0]=GMT': 2757,
#  'token[0]=servants': 13498,
#  'token[-2]=Diana': 9763,
#  'token[-1]=separatist': 8575,
#  'token[1]=1-1': 6407,
#  'token[1]=deal': 2199,
#  'token[2]=movement': 7512,
#  'token[-2]=Greek': 12083,
#  'token[-2]=western': 6640,
#  'token[-3]=In': 611,
#  'token[-3]=scattered': 14610,
#  'token[-2]=CDU': 13045,
#  'token[-3]=OAKLAND': 13227,
#  'token[2]=arrived': 6145,
#  'token[-2]=relief': 14401,
#  'token[-2]=%': 8586,
#  'token[0]=capital': 1602,
#  'token[0]=great': 6077,
#  'token[-2]=27': 8589,
#  'token[-1]=HOUSTON': 9663,
#  'token[0]=people': 604,
#  'token[-3]=bank': 2668,
#  'token[-2]=full': 5992,
#  'token[-1]=Toyota': 10331,
#  'token[-1]=do': 1004,
#  'token[1]=daughter': 12558,
#  'token[1]=that': 155,
#  'token[0]=special': 9403,
#  'token[-1]=Bradford': 12867,
#  'token[2]=community': 9527,
#  'token[0]=IVAC': 13375,
#  'token[0]=look': 10720,
#  'token[1]=also': 527,
#  'token[-2]=body': 10469,
#  'token[3]=May': 2921,
#  'token[-1]=73': 2931,
#  'token[0]=New': 647,
#  'token[3]=6-': 13852,
#  'token[-1]=given': 4297,
#  'token[0]=Williams': 6066,
#  'token[-1]=vs': 3122,
#  'token[3]=put': 2574,
#  'token[3]=Ireland': 5056,
#  'token[2]=current': 3709,
#  'token[-3]=sign': 7755,
#  'token[3]=2-6': 6498,
#  'token[2]=born': 13756,
#  'token[-2]=bank': 2286,
#  'token[-1]=Andre': 12858,
#  'token[1]=gains': 8903,
#  'token[0]=National': 1554,
#  'token[-2]=defence': 7288,
#  'token[-1]=life': 8060,
#  'token[0]=MINNESOTA': 6707,
#  'token[1]=convention': 5377,
#  'token[1]=service': 4233,
#  'token[2]=Windows': 10916,
#  'token[-2]=candidate': 13108,
#  'token[3]=matches': 2716,
#  'token[0]=production': 4216,
#  'token[-3]=lack': 13292,
#  'token[-1]=known': 4570,
#  'token[1]=water': 9489,
#  'token[1]=Spanish': 13584,
#  'token[2]=NEW': 8392,
#  'token[-2]=4-1': 14231,
#  'token[0]=longer': 14820,
#  'token[-2]=Association': 5970,
#  'token[1]=Martin': 4367,
#  'token[0]=ST': 6711,
#  'token[-3]=SOCCER': 788,
#  'token[-3]=losses': 11405,
#  'token[1]=seeded': 6449,
#  'token[-3]=a': 47,
#  'token[-1]=Colombo': 14022,
#  'token[-1]=Alexander': 6216,
#  'token[3]=diplomatic': 12794,
#  'token[-1]=BRUSSELS': 9062,
#  'token[-3]=Commonwealth': 10530,
#  'token[-3]=built': 14542,
#  'token[1]=what': 2158,
#  'token[-1]=thought': 8581,
#  'token[-3]=share': 4196,
#  'token[2]=Mushtaq': 6786,
#  'token[3]=67': 3721,
#  'token[3]=rising': 12833,
#  'token[-1]=protests': 9732,
#  'token[-1]=Zaire': 11981,
#  'token[3]=earlier': 1780,
#  'token[1]=deals': 8894,
#  'token[1]=led': 3831,
#  'token[-2]=gains': 11271,
#  'token[-2]=Plc': 14295,
#  'token[3]=front': 12803,
#  'token[2]=net': 2503,
#  'token[2]=days': 1651,
#  'token[3]=involving': 12810,
#  'token[0]=12': 1072,
#  'token[2]=ON': 10899,
#  'token[-3]=agreement': 3780,
#  'token[-3]=within': 5336,
#  "token[2]='ve": 11676,
#  'token[-3]=ninth': 7344,
#  'token[1]=earnings': 5181,
#  'token[3]=village': 6206,
#  'token[2]=AUGUST': 7120,
#  'token[2]=division': 2162,
#  'token[2]=orders': 7933,
#  'token[1]=did': 1033,
#  'token[-1]=closed': 3114,
#  'token[0]=Turkish': 6065,
#  'token[-1]=fell': 2939,
#  'token[3]=46': 8442,
#  'token[3]=side': 4277,
#  'token[2]=turned': 7156,
#  'token[-3]=rounds': 14608,
#  'token[0]=lap': 9388,
#  'token[1]=stages': 11664,
#  'token[-3]=Nations': 5527,
#  'token[-1]=promised': 12992,
#  'token[-2]=were': 229,
#  'token[1]=61-2': 11567,
#  'token[-3]=Gloucestershire': 14470,
#  'token[3]=with': 148,
#  'token[1]=Mullally': 5842,
#  'token[-2]=captain': 5281,
#  'token[3]=Mullally': 6824,
#  'token[0]=war': 2031,
#  'token[1]=PKK': 13575,
#  'token[2]=activity': 10921,
#  'token[3]=Honda': 7962,
#  'token[-3]=early': 1923,
#  'token[-3]=9': 2537,
#  'token[0]=However': 11459,
#  'token[3]=offered': 9039,
#  'token[2]=law': 4690,
#  'token[0]=child': 8268,
#  'token[-1]=who': 278,
#  'token[-2]=month': 1850,
#  'token[1]=Singer': 13582,
#  'token[2]=negotiations': 7149,
#  'token[0]=13': 880,
#  'token[2]=St': 6466,
#  'token[0]=tight': 10746,
#  'token[-2]=hits': 3654,
#  'token[1]=years': 764,
#  'token[0]=73': 2543,
#  'token[1]=Commission': 2907,
#  'token[1]=always': 7435,
#  'token[-1]=10th': 7575,
#  'token[3]=plans': 3557,
#  'token[-1]=lifted': 14175,
#  'token[0]=will': 290,
#  'token[2]=fiscal': 10939,
#  'token[0]=league': 1928,
#  'token[-3]=mother': 14589,
#  'token[-1]=CHAMPIONSHIP': 9652,
#  'token[-1]=should': 1520,
#  'token[0]=if': 1153,
#  'token[-1]=living': 12977,
#  'token[3]=victims': 11067,
#  'token[-1]=against': 488,
#  'token[-3]=find': 7740,
#  'token[-2]=Red': 7276,
#  'token[-1]=COLORADO': 9653,
#  'token[2]=visit': 1902,
#  'token[2]=need': 7148,
#  'token[-1]=stock': 4431,
#  'token[0]=growth': 3607,
#  'token[-1]=cut': 4023,
#  'token[-1]=build': 14116,
#  'token[1]=China': 1697,
#  'token[0]=500': 14651,
#  'token[-1]=Council': 6217,
#  'token[-1]=East': 3565,
#  'token[2]=right': 3998,
#  'token[0]=Some': 6713,
#  'token[1]=cases': 10818,
#  'token[3]=Soviet': 12762,
#  'token[-3]=whether': 3066,
#  'token[-1]=there': 846,
#  'token[-2]=hour': 10481,
#  'token[0]=326': 6352,
#  'token[-3]=inside': 12309,
#  'token[3]=an': 267,
#  'token[-1]=spokesman': 1019,
#  'token[3]=effect': 12798,
#  'token[-1]=Co': 3737,
#  'token[-1]=was': 118,
#  'token[1]=information': 11641,
#  'token[1]=Gore': 13551,
#  'token[-1]=flew': 12962,
#  'token[1]=Venezuela': 10801,
#  'token[2]=out': 426,
#  'token[1]=82': 11569,
#  'token[-2]=alleged': 13098,
#  'token[-1]=policemen': 14186,
#  'token[-2]=include': 12155,
#  'token[3]=)': 60,
#  'token[3]=promised': 13965,
#  'token[3]=Windows': 11008,
#  'token[-3]=child': 9277,
#  'token[-2]=Africa': 2081,
#  'token[-3]=At': 1417,
#  'token[2]=rebel': 6489,
#  'token[-2]=so': 1715,
#  'token[2]=Exchange': 5394,
#  'token[-3]=they': 423,
#  'token[-1]=wants': 11185,
#  'token[-3]=There': 2296,
#  'token[-3]=much': 3596,
#  'token[-1]=statement': 1044,
#  'token[1]=Rica': 6750,
#  'token[0]=winning': 3688,
#  'token[0]=earlier': 1418,
#  'token[1]=Teresa': 7074,
#  'token[3]=M.': 5058,
#  'token[3]=questioned': 13969,
#  'token[-1]=father': 12011,
#  ...}

# %%
print(flat_dataset["train"][0]["features"])
tokenizer(flat_dataset["train"][0]["features"])
# Out:
# token[0]=EU token[1]=rejects token[2]=German token[3]=call first-letter-capitalized
# {'input_ids': [6058, 1, 1896, 5233, 2], 'attention_mask': [1, 1, 1, 1, 1]}

# %%
def encode(examples):
    return tokenizer(examples['features'])

dset_tokenized = flat_dataset.map(encode,batched=True,num_proc=4)

for key,val in dset_tokenized["train"][0].items():
    print(key,":",val)
# Out:
# Map (num_proc=4):   0%|          | 0/203621 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/51362 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/46435 [00:00<?, ? examples/s]
# tokens : EU
# pos_tags : 22
# chunk_tags : 11
# ner_tags : 3
# features : token[0]=EU token[1]=rejects token[2]=German token[3]=call first-letter-capitalized
# input_ids : [6058, 1, 1896, 5233, 2]
# attention_mask : [1, 1, 1, 1, 1]

# %% [markdown]
# # Labels
#
# There are three tasks in this dataset (POS, chunks, NER). So we want to choose one of them and create the "labels" key used by the trainer. So let's pick the POS task.

# %%
def assign_labels(ex):
    return {"labels":ex["pos_tags"]}
dset_tokenized=dset_tokenized.map(assign_labels,batched=True)
# Out:
# Map:   0%|          | 0/203621 [00:00<?, ? examples/s]
# Map:   0%|          | 0/51362 [00:00<?, ? examples/s]
# Map:   0%|          | 0/46435 [00:00<?, ? examples/s]

# %%
dset_tokenized["train"][0]
# Out:
# {'tokens': 'EU',
#  'pos_tags': 22,
#  'chunk_tags': 11,
#  'ner_tags': 3,
#  'features': 'token[0]=EU token[1]=rejects token[2]=German token[3]=call first-letter-capitalized',
#  'input_ids': [6058, 1, 1896, 5233, 2],
#  'attention_mask': [1, 1, 1, 1, 1],
#  'labels': 22}

# %% [markdown]
# ---
#
# # MLP model
#
# With the data now ready, we'll build the MLP model. Note that this is _identical_ to the MLP model we used for text classification: the only difference between the two applications is in the data.
#
# The model class in its simplest form has `__init__()` which instantiates the layers and `forward()` which implements the actual computation. For more information on these, please see the [PyTorch turorial](https://pytorch.org/tutorials/beginner/introyt/modelsyt_tutorial.html).

# %%
# A Transformers library model wants a config,
# I can simply inherit from the base
# class for pretrained configs
# We don't really need to do anything very special
class MLPConfig(transformers.PretrainedConfig):
    pass

# This is the model
class MLP(transformers.PreTrainedModel):

    config_class=MLPConfig

    # In the initialization method, one instantiates the layers
    # these will be, for the most part the trained parameters of the model
    def __init__(self,config):
        super().__init__(config)
        self.all_tied_weights_keys = {} #Annoying bug in Transformers, must have this here or else we crash on saved model load
        #### HERE WE CREATE THE MODEL'S LAYERS:
        self.vocab_size=config.vocab_size #embedding matrix row count
        # Build and initialize embedding of vocab size x hidden size
        assert tokenizer.vocab["[PAD]"]==0 #let's make sure our assumption of pad==0 holds!

        self.embedding=torch.nn.Embedding(num_embeddings=self.vocab_size,embedding_dim=config.hidden_size,padding_idx=0)
        # Initialize the embeddings to random values
        # Note! This function is relatively clever and keeps the embedding for 0, the padding, pure zeros
        torch.nn.init.uniform_(self.embedding.weight.data,-0.001,0.001) #initialize the embeddings with small random values

        # This takes care of the lower half of the network, now the upper half
        # Output layer: hidden size x output size
        self.output=torch.nn.Linear(in_features=config.hidden_size,out_features=config.nlabels)
        # Now we have the parameters of the model
        self.loss=torch.nn.CrossEntropyLoss() #This loss is meant for classification, so let's use it


    # The computation of the model is put into the forward() function
    # it receives a batch of data and optionally the correct `labels`
    #
    # If given `labels` it returns (loss,output)
    # if not, then it returns (output,)
    def forward(self,input_ids,labels=None,**kwargs):
        #1) sum up the embeddings of the items
        embedded=self.embedding(input_ids) #(batch,ids)->(batch,ids,embedding_dim)
        # Since the Embedding keeps the first row of the matrix pure zeros, we don't need to worry about the padding
        # so next we sum the embeddings across the word dimension
        # (batch,ids,embedding_dim) -> (batch,embedding_dim)
        embedded_summed=torch.sum(embedded,dim=1)

        #2) apply non-linearity
        # (batch,embedding_dim) -> (batch,embedding_dim)
        projected=torch.tanh(embedded_summed) #Note how non-linearity is applied here and not when configuring the layer in __init__()
        # projected=embedded_summed ## If you need to bypass non-linearity, use this :)
        #3) and now apply the upper, output layer of the network
        # (batch,embedding_dim) -> (batch, num_of_classes i.e. 2 in our case)
        logits=self.output(projected)

        # ...and that's all there is to it!

        #print("input_ids.shape",input_ids.shape)
        #print("embedded.shape",embedded.shape)
        #print("embedded_summed.shape",embedded_summed.shape)
        #print("projected.shape",projected.shape)
        #print("logits.shape",logits.shape)

        # If we have labels, we ought to calculate the loss
        if labels is not None:

            # You run it as loss(model_output,correct_labels)
            return (self.loss(logits,labels),logits) #2-tuple, i.e. pair of values returned
        else:
            # No labels, so just return the logits
            return (logits,) #this weird syntax means 1-tuple

# %% [markdown]
# Configure the model

# %%
num_labels = len(POS2ID)

mlp_config = MLPConfig(
    vocab_size=len(tokenizer.vocab),
    hidden_size=20,
    nlabels=num_labels
)

print("mlp_config:", mlp_config)
# Out:
# mlp_config: MLPConfig {
#   "hidden_size": 20,
#   "nlabels": 47,
#   "transformers_version": "5.5.4",
#   "vocab_size": 15000
# }

# %% [markdown]
# ---
#
# # Train the model
#
# We will use the Hugging Face [Trainer](https://huggingface.co/docs/transformers/main_classes/trainer) class for training
#
# * Loads of arguments that control the training
# * Configurable metrics to evaluate performance
# * Data collator builds the batches
# * Early stopping callback stops when eval loss no longer improves
# * Model load/save
# * Good foundation for later deep learning course

# %% [markdown]
# First, let's create a [`TrainingArguments`](https://huggingface.co/docs/transformers/v4.17.0/en/main_classes/trainer#transformers.TrainingArguments) object to specify hyperparameters and various other settings for training.
#
# Printing this simple dataclass object will show not only the values we set, but also the defaults for all other arguments. Don't worry if you don't understand what all of these do! Many are not relevant to us here, and you can find the details in [`Trainer` documentation](https://huggingface.co/docs/transformers/main_classes/trainer) if you are interested.

# %%
trainer_args = transformers.TrainingArguments(
    "mlp_checkpoints", #save checkpoints here
    eval_strategy="steps",
    logging_strategy="steps",
    eval_steps=1000,
    logging_steps=1000,
    save_steps=1000,
    learning_rate=5e-4, #learning rate of the gradient descent
    max_steps=20000,
    load_best_model_at_end=True,
    per_device_train_batch_size=16
)

pprint(trainer_args)
# Out:
# TrainingArguments(
# accelerator_config={'split_batches': False, 'dispatch_batches': None, 'even_batches': True, 'use_seedable_sampler': True, 'non_blocking': False, 'gradient_accumulation_kwargs': None, 'use_configured_state': False},
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# average_tokens_across_devices=True,
# batch_eval_metrics=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_persistent_workers=False,
# dataloader_pin_memory=True,
# dataloader_prefetch_factor=None,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=False,
# enable_jit_checkpoint=False,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_do_concat_batches=True,
# eval_on_start=False,
# eval_steps=1000,
# eval_strategy=IntervalStrategy.STEPS,
# eval_use_gather_object=False,
# fp16=False,
# fp16_full_eval=False,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_v2': False, 'xla_fsdp_grad_ckpt': False},
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=False,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=None,
# hub_revision=None,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_for_metrics=[],
# include_num_input_tokens_seen=no,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=0.0005,
# length_column_name=length,
# liger_kernel_config=None,
# load_best_model_at_end=True,
# local_rank=-1,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=None,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=1000,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_kwargs=None,
# lr_scheduler_type=SchedulerType.LINEAR,
# max_grad_norm=1.0,
# max_steps=20000,
# metric_for_best_model=loss,
# neftune_noise_alpha=None,
# num_train_epochs=3.0,
# optim=OptimizerNames.ADAMW_TORCH_FUSED,
# optim_args=None,
# optim_target_modules=None,
# output_dir=mlp_checkpoints,
# parallelism_config=None,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=16,
# prediction_loss_only=False,
# project=huggingface,
# push_to_hub=False,
# remove_unused_columns=True,
# report_to=[],
# restore_callback_states_from_checkpoint=False,
# resume_from_checkpoint=None,
# run_name=None,
# save_on_each_node=False,
# save_only_model=False,
# save_steps=1000,
# save_strategy=SaveStrategy.STEPS,
# save_total_limit=None,
# seed=42,
# skip_memory_metrics=True,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torch_empty_cache_steps=None,
# trackio_space_id=trackio,
# train_sampling_strategy=random,
# use_cache=False,
# use_cpu=False,
# use_liger_kernel=False,
# warmup_ratio=None,
# warmup_steps=0,
# weight_decay=0.0,
# )

# %% [markdown]
# Next, let's create a metric for evaluating performance during and after training. We can use the convenience function [`load_metric`](https://huggingface.co/docs/datasets/about_metrics) to load one of many pre-made metrics and wrap this for use by the trainer.
#
# We can use the basic `accuracy` metric, defined as the proportion of correctly predicted labels out of all labels. This time, though, the data is not evenly split.

# %%
import numpy as np
import evaluate

accuracy = evaluate.load("accuracy")

def compute_accuracy(outputs_and_labels):
    outputs, labels = outputs_and_labels
    predictions = np.argmax(outputs, axis=-1) #pick the index of the "winning" label
    return accuracy.compute(predictions=predictions, references=labels)

# %% [markdown]
# We can then create the `Trainer` and train the model by invoking the [`Trainer.train`](https://huggingface.co/docs/transformers/main_classes/trainer#transformers.Trainer.train) function.
#
# In addition to the model, the settings passed in through the `TrainingArguments` object created above (`trainer_args`), the data, and the metric defined above, we create and pass the following to the `Trainer`:
#
# * [data collator](https://huggingface.co/docs/transformers/main_classes/data_collator): groups input into batches
# * [`EarlyStoppingCallback`](https://huggingface.co/docs/transformers/main_classes/callback#transformers.EarlyStoppingCallback): stops training when performance stops improving

# %%
# Make a new model
mlp = MLP(mlp_config)


# Argument gives the number of steps of patience before early stopping
# i.e. training is stopped when the evaluation loss fails to improve
# certain number of times
early_stopping = transformers.EarlyStoppingCallback(5)

trainer = transformers.Trainer(
    model=mlp,
    args=trainer_args,
    train_dataset=dset_tokenized["train"],
    eval_dataset=dset_tokenized["validation"].select(range(1000)),
    compute_metrics=compute_accuracy,
    data_collator=transformers.DataCollatorWithPadding(tokenizer),
    callbacks=[early_stopping]
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='20000' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [20000/20000 01:36, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>2.805667</td>
#       <td>2.067291</td>
#       <td>0.541000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.719986</td>
#       <td>1.363542</td>
#       <td>0.716000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.235324</td>
#       <td>1.073837</td>
#       <td>0.770000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.987144</td>
#       <td>0.909886</td>
#       <td>0.793000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.862657</td>
#       <td>0.800872</td>
#       <td>0.822000</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.772114</td>
#       <td>0.718788</td>
#       <td>0.840000</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.687426</td>
#       <td>0.662975</td>
#       <td>0.845000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.623977</td>
#       <td>0.622465</td>
#       <td>0.856000</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.602455</td>
#       <td>0.585361</td>
#       <td>0.860000</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.558981</td>
#       <td>0.559161</td>
#       <td>0.858000</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.544537</td>
#       <td>0.544668</td>
#       <td>0.863000</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.511565</td>
#       <td>0.532127</td>
#       <td>0.869000</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.489700</td>
#       <td>0.515986</td>
#       <td>0.876000</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.459231</td>
#       <td>0.507709</td>
#       <td>0.880000</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.443400</td>
#       <td>0.499205</td>
#       <td>0.876000</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.428325</td>
#       <td>0.493910</td>
#       <td>0.878000</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.439214</td>
#       <td>0.488212</td>
#       <td>0.880000</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.416572</td>
#       <td>0.485565</td>
#       <td>0.882000</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.426055</td>
#       <td>0.483626</td>
#       <td>0.882000</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.421253</td>
#       <td>0.482034</td>
#       <td>0.883000</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# TrainOutput(global_step=20000, training_loss=0.7717792068481445, metrics={'train_runtime': 96.7556, 'train_samples_per_second': 3307.303, 'train_steps_per_second': 206.706, 'total_flos': 14775739398.0, 'train_loss': 0.7717792068481445, 'epoch': 1.571462245619549})

# %% [markdown]
# That's pretty poor performance for a task as simple as POS tagging where state-of-the-art accuracies are generally 97-99%. (The approach demonstrated in this notebook should be considered more of a teaching tool than a serious tagger implementation.)
#
# However, the result is certainly much better than random, so we can conclude that the model is learning something about the task.

# %% [markdown]
# PART A
#
# The training accuracy for the original model is 87,5%.
#
# The training accuracy without context of the original word is 60,5%. This is significantly worse than the original result.
#
# The training accuracy for memorization only is 68,1%. This is still worse than the original but it is better compared to the out of context model.

# %% [markdown]
# ---
#
# # What has the model learned?
#
# * The embeddings should have some meaning to them
# * Similar features should have similar embeddings

# %%
# Grab the embedding matrix out of the trained model
# and drop the first row (padding 0)
# then we can treat the embeddings as vectors

weights=mlp.embedding.weight.detach().cpu().numpy()

# %%
import sklearn
qry_idx=tokenizer.vocab["token[0]=in"]
idx2feat={v:k for k,v in tokenizer.vocab.items()}

#calculate the distance of the "in" embedding to all other embeddings
distance_to_qry=sklearn.metrics.pairwise.euclidean_distances(weights[qry_idx:qry_idx+1,:],weights)
nearest_neighbors=np.argsort(distance_to_qry) #indices of words nearest to "in"
for nearest in nearest_neighbors[0,:20]:
    print(idx2feat[nearest])
# Out:
# token[0]=in
# token[0]=after
# token[0]=by
# token[0]=from
# token[0]=on
# token[0]=at
# token[0]=with
# token[0]=In
# token[0]=into
# token[0]=between
# token[0]=for
# token[0]=under
# token[0]=than
# token[0]=since
# token[0]=through
# token[0]=if
# token[0]=At
# token[0]=before
# token[0]=while
# token[0]=as

# %% [markdown]
# * The embeddings indeed seem to reflect the task and capture aspects of the meaning of words relevant to the task
# * But now we have many classes, so we should take that into account too
# * We can take the dot-product of the feature embeddings with the output layer weight of the class we care about
# * When you think how the information propagates in the network, this will give us a single number reflecting each feature w.r.t. the selected label
# * Technically speaking, it is the prediction of an example which only has that one feature, with respect to that one class
# * Here is how we can implement it (here we rely on the fact that the model is linear, since we didn't include a nonlinearity earlier in the model's `forward()`

# %%
import numpy

embedding_weights=weights    #shape (features, embedding-dim)
output_weights=mlp.output.weight.detach().cpu().numpy()    #shape (num-labels, embedding-dim)

# We just matrix-multiply these together, since this gives us all the dot-products
weights_by_label=numpy.matmul(numpy.tanh(embedding_weights), output_weights.T)
weights_by_label.shape
# Out:
# (15000, 47)

# %%
def get_most_important_features_for_and_against(label):
    label_idx = POS2ID[label]
    feature_weights = weights_by_label[:,label_idx] #pick the column that interests us

    #The shape of feature_weights is (feature_vocab_size,) i.e. it is a vector
    features_weight_idx = numpy.argsort(-feature_weights) #sort in descending order, this will be vector of indices
    features_for = [idx2feat[feature_idx] for feature_idx in features_weight_idx[:30]]
    features_against = [idx2feat[feature_idx] for feature_idx in features_weight_idx[-30:][::-1]]
    return features_for, features_against

for label in ("DT", "NN", "VB"):
    dt_plus,dt_minus=get_most_important_features_for_and_against(label)
    print(f"{label}: {POS2DESCRIPTION[label]}")
    print(f"Most important features *for* label {label}:")
    pprint("   ".join(dt_plus))
    print()
    print(f"Most important features *against* label {label}:")
    pprint("   ".join(dt_minus))
    print("\n------\n")
# Out:
# DT: Determiner
# Most important features *for* label DT:
# ('token[0]=the   token[0]=a   token[0]=The   token[0]=an   token[0]=this   '
#  'token[0]=some   token[0]=A   token[0]=no   token[0]=any   token[0]=all   '
#  'token[0]=both   token[0]=those   token[0]=another   token[0]=who   '
#  'token[0]=This   token[0]=No   token[0]=these   token[0]=each   token[0]="   '
#  'token[0]=An   token[0]=Some   token[0]=to   token[0]=that   token[0]=These   '
#  "token[0]=That   token[0]='s   token[-1]=has   token[-1]=were   "
#  'token[-1]=had   token[1]=year')
#
# Most important features *against* label DT:
# ('token[0]=he   token[0]=it   token[0]=I   token[0]=He   token[0]=they   '
#  'token[0]=It   token[0]=We   token[0]=/   token[0]=would   token[0]=we   '
#  'token[0]=will   token[0]=Results   token[0]=him   token[0]=she   '
#  'token[0]=(   token[0]=people   token[0]=They   token[0]=them   '
#  'token[0]=years   token[0]=are   token[0]=RESULTS   token[0]=officials   '
#  'token[0]=you   token[0]=Women   token[0]=,   token[1]=were   '
#  'token[0]=could   token[0]=seconds   token[0]=talks   token[0]=shares')
#
# ------
#
# NN: Noun, singular or mass
# Most important features *for* label NN:
# ('token[0]=percent   token[0]=government   token[0]=year   token[0]=SOCCER   '
#  'token[0]=week   token[0]=state   token[0]=company   token[0]=group   '
#  'token[0]=time   token[0]=market   token[0]=spokesman   token[0]=world   '
#  'token[0]=president   token[0]=team   token[0]=home   token[0]=peace   '
#  'token[0]=division   token[0]=police   token[0]=statement   token[0]=soccer   '
#  'token[0]=party   token[0]=day   token[0]=news   token[0]=part   '
#  'token[0]=newsroom   token[0]=month   token[0]=opposition   token[0]=season   '
#  'token[0]=capital   token[0]=leader')
#
# Most important features *against* label NN:
# ('token[0]=(   token[0]=when   token[0]=who   token[0]=most   token[0]=and   '
#  'token[0]=\'s   token[0]=\'   token[0]=)   token[0]=where   token[0]="   '
#  'token[0]=$   token[0]=best   token[0]=there   token[0]=/   '
#  'token[0]=earlier   token[0]=what   token[0]=There   token[0]=latest   '
#  'token[0]=or   token[0]=is   token[0]=has   token[0]=but   token[0]=more   '
#  'token[0]=his   token[0]=lower   token[0]=its   token[0]=whose   '
#  'token[0]=how   token[0]=.   token[0]=their')
#
# ------
#
# VB: Verb, base form
# Most important features *for* label VB:
# ('token[0]=be   token[-1]=will   token[-1]=would   token[-1]=to   '
#  'token[0]=have   token[0]=who   token[-1]=could   token[0]=beat   '
#  'token[-1]=should   token[0]=take   token[-1]=can   token[-2]=did   '
#  "token[-1]=n't   token[0]=go   token[0]=make   token[0]=meet   "
#  'token[-1]=may   token[0]=do   token[0]=are   token[-1]=not   token[0]=get   '
#  'token[-1]=might   token[0]=play   token[0]=Halftime   token[0]=run   '
#  'token[-1]=must   token[-2]=do   token[0]=hold   token[-2]=able   '
#  'token[-2]=trying')
#
# Most important features *against* label VB:
# ('token[0]=was   token[0]=said   token[0]=were   token[0]=had   token[0]=and   '
#  'token[0]=)   token[0]=did   token[0]=but   token[0]=But   token[0]=his   '
#  'token[0]=took   token[0]=or   token[0]=told   token[0]=not   '
#  'token[0]=their   token[0]=gave   token[0]=its   token[0]=won   '
#  'token[0]=fell   token[0]=added   token[0]=began   token[0]=went   '
#  'token[0]=came   token[0]=reported   token[0]=lost   token[0]=also   '
#  'token[0]=rose   token[-1]=He   token[0]=ended   token[0]=left')
#
# ------

# %% [markdown]
# PART A
#
# Many of the original features are of type token[0]="someword".
#
# Many of the out of context features are of type token[-2 - 2]="someword" The words are more specific and less general, which means that the labeling has led to worse important features as they are too specific to be of use in generalization.
#
# Many of the memorized context features are of type token[x]="end char" The important features are pretty much meaningless as the model has learned the correlation with end symbols and connecting characters instead of words.
